# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# from google.colab import auth
# auth.authenticate_user()
# from oauth2client.client import GoogleCredentials
# creds = GoogleCredentials.get_application_default()
# import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
# vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p Drive
# !google-drive-ocamlfuse Drive

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/Drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from itertools import product

os.chdir('/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder')
# os.chdir('/content/Drive/My Drive/labeling_cowork_folder')
os.getcwd()
# Out:
# '/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder'

# %% [markdown]
# # Runtime Environment
# * python >= 3.6
# * pytorch >= 1.0
# * pandas
# * nltk
# * numpy
# * sklearn
# * pickle
# * tqdm
# * json

# %% [markdown]
# # Data processing

# %% [markdown]
# ## 刪除多於資訊 (Remove redundant information)
# 我們在資料集中保留了許多額外資訊供大家使用，但是在這次的教學中我們並沒有用到全部資訊，因此先將多餘的部分先抽走。
# In dataset, we reserved lots of information. But in this tutorial, we don't need them, so we need to discard them.

# %%
import pandas as pd

dataset = pd.read_csv('raw_data/task1_trainset.csv', dtype=str)
dataset.head()
# Out:
#        Id  ...                                             Task 1
# 0  D00001  ...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1  D00002  ...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2  D00003  ...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3  D00004  ...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4  D00005  ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
#
# [5 rows x 7 columns]

# %%
# 句子有一些換行沒處理好
dataset["Abstract"] = dataset["Abstract"].str.replace("- ", "")

dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)

# %% [markdown]
# ## 資料切割  (Partition)
# 在訓練時，我們需要有個方法去檢驗訓練結果的好壞，因此需要將訓練資料切成training/validataion set。
#
# **- Need 5-fold cv to validate training result**

# %%
from sklearn.model_selection import StratifiedKFold, KFold

trainset_folds = []
trainset_folds = []

valset_folds = []
valset_folds = []

tmp_train = {}
tmp_val = {}

X = dataset["Abstract"]
y = dataset["Task 1"]

# 用GROUP K-FOLD分類別? 先改用K-Fold

K_folder = KFold(n_splits=10, random_state=42, shuffle=False)
for i, (train_index, val_index) in enumerate(K_folder.split(X, y)):

    tmp_train['Abstract'] = X[train_index]
    tmp_train['Label'] = y[train_index]

    tmp_val['Abstract'] = X[val_index]
    tmp_val['Label'] = y[val_index]

    # 有一個split會反過來 (Stratified K-Fold)
    # if i == 0:
    #   continue

    trainset_folds.append(pd.DataFrame(data=tmp_train))
    valset_folds.append(pd.DataFrame(data=tmp_val))

    # print("Stratified Train Index:", train_index)
    # print("Stratified Test Index:", test_index)
    # print("Stratified y_train:", y[train_index])
    # print("Stratified y_test:", y[test_index],'\n')

# train_test_split(dataset, test_size=0.2, random_state=42)

# %%
trainset_folds[9]
# Out:
#                                                Abstract                                              Label
# 0     Rapid popularity of Internet of Things (IoT) a...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1     In this paper, we address the problem of compu...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2     High quality upsampling of sparse 3D point clo...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3     Internet is the main source of information now...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4     Automated Facial Expression Recognition (FER) ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
# ...                                                 ...                                                ...
# 6295  Activity detection is a fundamental problem in...  BACKGROUND BACKGROUND OBJECTIVES METHODS METHO...
# 6296  We address the problem of using hand-drawn ske...  BACKGROUND/OBJECTIVES METHODS METHODS METHODS ...
# 6297  This article extends the Generalized Asypmtoti...                         OBJECTIVES METHODS RESULTS
# 6298  We consider generation and comprehension of na...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 6299  The task of classifying videos of natural dyna...  BACKGROUND BACKGROUND OBJECTIVES METHODS CONCL...
#
# [6300 rows x 2 columns]

# %%
def save_k_fold_data(data, name="train_data_fold", fold=10):
  """
  X_data: list of DF
  y_data: list of DF
  """
  for i in range(fold):
    data[i].to_csv("K_fold_data/" + name + "_" + str(i) + ".csv", index=None)
fold=10
# save_k_fold_data(data=trainset_folds, name="train_data_fold", fold=fold)
# save_k_fold_data(data=valset_folds, name="valid_data_fold", fold=fold)

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
trainset, validset = train_test_split(dataset, test_size=0.1, random_state=42)

# trainset.to_csv('train_test_split_data/trainset.csv',index=False)
# validset.to_csv('train_test_split_data/validset.csv',index=False)

# %% [markdown]
# ### For test data (在這裡替換private set的testing data路徑!)

# %%
dataset = pd.read_csv('raw_data/task1_private_testset.csv', dtype=str)  ## -> 路徑在這裡替換

dataset["Abstract"] = dataset["Abstract"].str.replace("- ", "")
dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)
dataset.to_csv('train_test_split_data/private_testset.csv',index=False)

# %% [markdown]
# ### 統計單字 (Count words)
# 在訓練時，不能直接將單字直接餵入model，因為它只看得懂數字，因此我們必須把所有的單字抽取出來，並將它們打上編號，做出一個字典來對它們做轉換。
# We can't feed "word" into model directly, since it can only recognize number. So, we need to know the total number of word, and give every word a unique number.

# %% [markdown]
# 在這裡，我們需要借助`nltk`這個library來幫忙做文字切割。當然，你也可以選擇自己寫規則來切割(通常上不建議搞死自己)。
# 另外，我們也使用了`multiprocessing`來加速處理。
# In here, we split words by using `nltk library`. You can write your own rules and split it by yourself, but you won't want to do that, trust me.
# Also, we use `multiprocessing` to accelerate the process.

# %%
import pandas as pd
from multiprocessing import Pool
from nltk.tokenize import word_tokenize

def tokenize_by_space(sentence):
    return sentence.split(' ')

def collect_words(data_path=None, n_workers=4, dataset=None):
    if dataset is None:
      df = pd.read_csv(data_path, dtype=str)
    else:
      df = dataset
      
        
    sent_list = []
    for i in df.iterrows():
        sent_list += i[1]['Abstract'].split('$$$')

    chunks = [
        ' '.join(sent_list[i:i + len(sent_list) // n_workers])
        for i in range(0, len(sent_list), len(sent_list) // n_workers)
    ]
    with Pool(n_workers) as pool:
        chunks = pool.map_async(word_tokenize, chunks)
        # chunks = pool.map_async(tokenize_by_space, chunks)
        words = set(sum(chunks.get(), []))

    return words

def get_first_word(sentence_list):
    return [sent.split(" ")[0] for sent in sentence_list]

def collect_sentence_first_words(data_path=None, n_workers=4, dataset=None):
    if dataset is None:
      df = pd.read_csv(data_path, dtype=str)
    else:
      df = dataset
    
    first_words = []
    for i in df.iterrows():
        first_words.extend(get_first_word(i[1]['Abstract'].split('$$$')))

    return first_words
  
def get_proprietary(word_list):
    p = []
    for word in word_list:
        if np.sum([w.isupper() for w in word]) >= 2:
            p.append(word)
    return p

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
words = set()
# testset_w = pd.read_csv("train_test_split_data/testset.csv", index_col=None)
# trainset_w = pd.read_csv("train_test_split_data/trainset.csv", index_col=None)
# all_data = pd.concat([trainset_w, testset_w])
words |= collect_words('raw_data/task1_trainset.csv')
# words |= collect_words(dataset=all_data)

# %%
from collections import Counter

first_word_list_train = collect_sentence_first_words("raw_data/task1_trainset.csv")
first_word_list_test = collect_sentence_first_words('raw_data/task1_public_testset.csv')

# 如果詞出現頻率大於1、大寫數目小於2、沒有dash在裡面，才認為是普通的句首字
first_word_list = first_word_list_train + first_word_list_test
first_words_dict = dict(Counter(first_word_list))

first_words = [word for word, freq in first_words_dict.items() if (freq > 1) and 
               (np.sum([w.isupper() for w in word]) < 2) and 
               ('-' not in word)]

# %%
first_words
# Out:
# ['Rapid',
#  'To',
#  'This',
#  'The',
#  'In',
#  'With',
#  'Given',
#  'We',
#  'High',
#  'Our',
#  'Finally,',
#  'Results',
#  'Internet',
#  'These',
#  'That',
#  'There',
#  'Therefore,',
#  'Automated',
#  'Many',
#  'Recently',
#  'Experiments',
#  'It',
#  'Through',
#  'Existing',
#  'Such',
#  'Deep',
#  'Subjective',
#  'Offline',
#  'They',
#  'How',
#  'A',
#  'Any',
#  'Mobile',
#  'Hence,',
#  'Specifically,',
#  'Based',
#  'Inspired',
#  'Though',
#  'Scene',
#  'Combined',
#  'Moreover,',
#  'Generative',
#  'Network',
#  'Numerical',
#  'Dimensionality',
#  'By',
#  'Comparisons',
#  'As',
#  'Successful',
#  'Meanwhile,',
#  'Representation',
#  'However,',
#  'Further,',
#  'For',
#  'Publishing',
#  'Centrality',
#  'Even',
#  'Reconstruction',
#  'Recurrent',
#  'Thus,',
#  'One',
#  'Note',
#  'Combining',
#  'Software',
#  'But,',
#  'Although',
#  'Static',
#  'First,',
#  'Second,',
#  'Third,',
#  'While',
#  'Unfortunately,',
#  'More',
#  'Then,',
#  'On',
#  'Yet',
#  'Indeed,',
#  'If',
#  'Modern',
#  'Spatial',
#  'Recently,',
#  'Few',
#  'Application',
#  'Built',
#  'At',
#  'Several',
#  'Thus',
#  'Power',
#  'Policy',
#  'Relations',
#  'Hence',
#  'Countries',
#  'Furthermore,',
#  'Behavior',
#  'Comparison',
#  'Other',
#  'Both',
#  'Metrics',
#  'Identifying',
#  'Despite',
#  'Efforts',
#  'Experimentally,',
#  'Translating',
#  'Being',
#  'Distribution',
#  'Current',
#  'Analyzing',
#  'When',
#  'Traditionally,',
#  'Each',
#  'Social',
#  'Using',
#  'Thereby,',
#  'An',
#  'Following',
#  'Two',
#  'Convolutional',
#  "'s",
#  'Whether',
#  'Motivated',
#  'Computational',
#  'Acute',
#  'Smart',
#  'Artificial',
#  'Regularizing',
#  'Solar',
#  'Robotic',
#  'Also,',
#  'Feedback',
#  'Firstly,',
#  'Secondly,',
#  'Objects',
#  'Strategies',
#  'Due',
#  'First',
#  'Among',
#  'Previous',
#  'Factorization',
#  'Regarding',
#  'Experimental',
#  'Information',
#  'Most',
#  'Sparse',
#  'However',
#  'Furthermore',
#  'Thanks',
#  'Unlike',
#  'Machine',
#  'Architectures',
#  'During',
#  'Since',
#  'Relaxing',
#  'Here,',
#  'Geometric',
#  'Models',
#  'Secure',
#  'Along',
#  'Interesting',
#  'Objective:',
#  'Main',
#  'Conclusion:',
#  'Going',
#  'Crowdsourcing',
#  'Empirical',
#  'Extreme',
#  'Compared',
#  'Additionally,',
#  'Connection',
#  'Cooperative',
#  'Computer',
#  'But',
#  'So',
#  'Optical',
#  'Conventionally,',
#  'Considering',
#  'Simulation',
#  'Research',
#  'Context:',
#  'Method:',
#  'Results:',
#  'Fortunately,',
#  'Evolution',
#  'Integrating',
#  'Conventional',
#  'Less',
#  'Simulations',
#  'Increasing',
#  'Some',
#  'Neural',
#  'Gaussian,',
#  'Leveraging',
#  'Convergence',
#  'Surprisingly,',
#  'Also',
#  'Consequently,',
#  'From',
#  'Acoustic',
#  'Further',
#  'Noise',
#  'Rather',
#  'Users',
#  'And',
#  'Supervised',
#  'Without',
#  'Zooming',
#  'Localized',
#  'Understanding',
#  'Image',
#  'Algorithms',
#  'Three',
#  'Determining',
#  'Fundamental',
#  'Density',
#  'Motivation:',
#  'Additional',
#  'Availability:',
#  'Traditional',
#  'Physical',
#  'Taking',
#  'Boolean',
#  'Robustness',
#  'Word',
#  'Instead,',
#  'Explaining',
#  'Various',
#  'Four',
#  'System',
#  'Intuitively',
#  'Autonomous',
#  'Standard',
#  'Generalized',
#  'Advanced',
#  'Chemical',
#  'Their',
#  'Code',
#  'Business',
#  'Under',
#  'Learning',
#  'Clinical',
#  'Recent',
#  'Excessive',
#  'Over',
#  '(2)',
#  '(3)',
#  '(4)',
#  '(5)',
#  'Similarly,',
#  'According',
#  'Ranking',
#  'Citations',
#  'Until',
#  'Thompson',
#  'Thirdly,',
#  'Recognizing',
#  'Here',
#  'Collective',
#  'Massive',
#  'Generally,',
#  'All',
#  'Efficiency',
#  'Benefit',
#  'Fuzzy',
#  'Different',
#  'And,',
#  'Because',
#  'Inference',
#  'Multiple',
#  'Computation',
#  'Nevertheless,',
#  'Classifying',
#  'Abstract',
#  'Adversarial',
#  'Instead',
#  'Extensive',
#  'Rate',
#  'Grid',
#  'Chord',
#  'Plenty',
#  'Binary',
#  'Another',
#  'Besides,',
#  'Lastly,',
#  'Building',
#  'After',
#  'Besides',
#  'Then',
#  'Discriminative',
#  'Spatially',
#  'Personal',
#  'Finding',
#  'Together',
#  'Distant',
#  'Surrogate',
#  'Optimal',
#  'Dealing',
#  'Assuming',
#  'Foreground',
#  'Numerous',
#  'Not',
#  'Quality',
#  'Simple',
#  'Genetic',
#  'Majority',
#  'Often',
#  'Super',
#  'Resulting',
#  'Deliberate',
#  'Conversely,',
#  'Estimating',
#  'Wireless',
#  'Clustering',
#  'Cluster',
#  'Optimized',
#  'Effective',
#  'Visualization',
#  'Yet,',
#  'Subsequently,',
#  'Hashing',
#  'Low',
#  'Level',
#  'Simplified',
#  'Monocular',
#  'Synthetic',
#  'Utilizing',
#  'Training',
#  'Weakly',
#  'Rigid',
#  'Integrated',
#  'Comprehensive',
#  'No',
#  'Parallel',
#  'Vulnerability',
#  'Subjects',
#  'Driven',
#  'Approaches',
#  'Applied',
#  'Spoken',
#  'Methods',
#  'Search',
#  'Achieving',
#  'Bearing',
#  'Quantitative',
#  'Namely,',
#  'Qualitative',
#  'Combination',
#  'Higher',
#  'Finally',
#  'Glaucoma',
#  'Estimation',
#  'Speech',
#  'Especially,',
#  'Validated',
#  'Technological',
#  'Differently',
#  'Big',
#  'Examples',
#  'Classification',
#  'Label',
#  'Grounding',
#  'Lossless',
#  'Practical',
#  'Would',
#  'Experts',
#  'Compressed',
#  'Forming',
#  'Type',
#  'Formal',
#  'Analysis',
#  'Industrial',
#  'Once',
#  'Knowledge',
#  'Nowadays',
#  'Questions',
#  'in',
#  'gave',
#  'Monte',
#  'Online',
#  'Scheduling',
#  'Eliminating',
#  'Sentiment',
#  'Control',
#  'Effectively,',
#  'Soon',
#  'Sequential',
#  'Markov',
#  'Generally',
#  'Visualizations',
#  'Suggestions',
#  'Automatic',
#  'Open',
#  'Efficiently',
#  'Improving',
#  'Currently,',
#  'Ontologies',
#  'Extended',
#  'Bayesian',
#  'Alternative',
#  'Diagnosis',
#  'This,',
#  'Surface',
#  'Correlation',
#  'Its',
#  'Head',
#  'Facial',
#  'Now',
#  'Books',
#  'Model',
#  'Concurrently,',
#  'Comparing',
#  'Usually,',
#  'Efficient',
#  'Background:',
#  'Aims:',
#  'Conclusions:',
#  'Modeling',
#  'Complex',
#  'Typically,',
#  'Natural',
#  'Early',
#  'Measuring',
#  'Detailed',
#  'Proxies',
#  'Critical',
#  'Twelve',
#  'Next,',
#  'Anonymous',
#  'Caricature',
#  '(ii)',
#  '(iii)',
#  '(iv)',
#  'Augmented',
#  'Data',
#  'Observing',
#  'Unsupervised',
#  'Requirements',
#  'Apparently,',
#  'Scenarios',
#  'Digital',
#  'Variants',
#  'Samples',
#  'Face',
#  'Actually,',
#  'Community',
#  'Algorithm',
#  'Contracts',
#  'Advances',
#  'Useful',
#  'Quite',
#  'Sensitive',
#  'Individual',
#  'Serious',
#  'Interestingly,',
#  'Resource',
#  'Contrary',
#  'I',
#  'Towards',
#  'Particularly,',
#  'Designing',
#  'Apriori',
#  'Factors',
#  'Considered',
#  'Ambient',
#  'Developing',
#  'Cardiac',
#  'Ablation',
#  'Coupled',
#  'Peak',
#  'Mixture',
#  'Keywords:',
#  'Future',
#  'Random',
#  'Stack',
#  'Persistent',
#  'Still,',
#  'Physically',
#  'Traffic',
#  'Accurate',
#  'Gaussian',
#  'Exponential',
#  'Classical',
#  'Pedestrian',
#  'Nowadays,',
#  'Next',
#  'Proper',
#  'Obtaining',
#  'Exploiting',
#  'Simulators',
#  'Dynamic',
#  'Applying',
#  'Focusing',
#  'Historically,',
#  'Distributed',
#  'Classifiers',
#  'Self',
#  'Preconditioned',
#  'India',
#  'Scripts',
#  'Benchmark',
#  'Depending',
#  'Dense',
#  'Specialized',
#  'Scalable',
#  'Ubiquitous',
#  'Of',
#  'Quantitatively,',
#  'Evaluating',
#  'Presumably,',
#  'Human',
#  'Owing',
#  'Graph',
#  'Importantly,',
#  '"How',
#  '(The',
#  'Cell',
#  'Formulas',
#  'Thereby',
#  'Only',
#  'Departing',
#  'User',
#  'Relational',
#  'Local',
#  'Extending',
#  'Conditions',
#  'Vehicle',
#  'Book',
#  'Creating',
#  'Signals',
#  'Experiment',
#  'Essential',
#  'Survival',
#  'Indirect',
#  'Semantic',
#  'Conditional',
#  'Energy',
#  'Intuitively,',
#  'Relevant',
#  'Relying',
#  'Stream',
#  'Remarkably,',
#  'Blockchain',
#  'Decentralized',
#  'Stochastic',
#  'Bilinear',
#  'Spectral',
#  'Volumetric',
#  'Optimization',
#  'Cloud',
#  'Systems',
#  'Feature',
#  'Theoretically,',
#  'Multimedia',
#  'Reinforcement',
#  'Linear',
#  'Author',
#  'Tested',
#  'Magnetic',
#  'Typical',
#  'Especially',
#  'Theoretical',
#  'when',
#  'Graphs',
#  'graphs',
#  'Quantizers',
#  'Reading',
#  "It's",
#  'Music',
#  'Preliminary',
#  'Improved',
#  'Regardless',
#  'Performance',
#  'Controllers',
#  'Patches',
#  'Discussions',
#  'Segmentation',
#  'Solutions',
#  'Weighted',
#  'Consider',
#  'Making',
#  'Optimizing',
#  'Implementing',
#  'Manual',
#  'Much',
#  '),',
#  'Long',
#  'Orthogonal',
#  'Therefore',
#  'Applicability',
#  'Today',
#  'Value',
#  'Object',
#  'Predicted',
#  'Success',
#  'Differently,',
#  'Augmenting',
#  'Can',
#  'New',
#  'Basic',
#  'Signal',
#  'Detecting',
#  'Manifold',
#  'Letting',
#  'Ultimately,',
#  'Legged',
#  'Either',
#  'Otherwise,',
#  'Correct',
#  'Initially',
#  'Ideas',
#  'Evidence',
#  'Implications',
#  'Conclusions',
#  'Chinese',
#  'Evaluated',
#  'Policies',
#  'Counting',
#  'Getting',
#  'Fractional',
#  'Evolutionary',
#  'Beside',
#  'Privacy',
#  'Querying',
#  'Planning',
#  'Prior',
#  'Multipath',
#  'Gradients',
#  'Beyond',
#  'Working',
#  'Eye',
#  'Foundations',
#  '9,',
#  'Whereas',
#  'Similarity',
#  'Reduction',
#  'Employing',
#  'Restricted',
#  'Binarization',
#  'Diagrammatic',
#  '(2017).',
#  'Like',
#  'Foggy',
#  'Part',
#  'Function',
#  'Poor',
#  'Unmanned',
#  'Offloading',
#  'Analytic',
#  'What',
#  'Adaptability',
#  'Every',
#  'Use',
#  'Contemporary',
#  'Slow',
#  'Nonetheless,',
#  'Testing',
#  'Compositional',
#  'Participants',
#  'Proposals',
#  'Computationally',
#  'Collecting',
#  'Robust',
#  'Cybercrime',
#  'Categorical',
#  'Customers',
#  'People',
#  'Android',
#  'Alternatively,',
#  'Researchers',
#  'Drawing',
#  'Stereo',
#  'Statistical',
#  'Categories',
#  'Wikipedia',
#  'Health',
#  'Objectives:',
#  'Methods:',
#  'Findings:',
#  'Vertex',
#  'Outlier',
#  'Interpretation',
#  'Programmers',
#  'Source',
#  'Growing',
#  'Supporting',
#  'Sampling',
#  'Writing',
#  'Web',
#  'Evaluations',
#  'Visual',
#  'Agents',
#  'Within',
#  'Just',
#  'Aerial',
#  'Predicting',
#  'Extracting',
#  'Text',
#  'Phase',
#  'Relative',
#  'Trajectory',
#  'Explicitly',
#  'Vector',
#  'Delay',
#  'Iris',
#  'Fusion',
#  'Dataset',
#  'Pulse',
#  'Special',
#  'Passive',
#  'Are',
#  'You',
#  'Should',
#  'Virtual',
#  'Biological',
#  'Access',
#  'Overall,',
#  'Lexical',
#  'Close',
#  'b)',
#  'Nodes',
#  'Properties',
#  'Biclustering',
#  'Proposed',
#  'Usefulness',
#  'So,',
#  'Costs',
#  'Objective',
#  'Psychological',
#  'Monoidal',
#  'Urban',
#  'Empirically,',
#  'Proliferation',
#  'Naive',
#  'Similar',
#  'Functioning',
#  'Automatically',
#  'Extracted',
#  'Specially',
#  'Inferring',
#  'Sharing',
#  'Roughly',
#  'Gibbs',
#  'Path',
#  'Verbs',
#  'Related',
#  'Generating',
#  'Particularly',
#  'Missing',
#  'Adversaries',
#  'Similarly',
#  'Controller',
#  'Constructing',
#  'Consistent',
#  'Parameters',
#  'Accuracy',
#  'Later,',
#  'Additionally',
#  'Interaction',
#  'Why',
#  'Named',
#  'Unseen',
#  'Granular',
#  'Her',
#  'Validation',
#  'Embarrassingly',
#  'Basically,',
#  'Molecular',
#  'Recall',
#  'Automating',
#  'Regularity',
#  'Active',
#  'Opportunistic',
#  'Independently',
#  'We,',
#  'Bitcoin',
#  'Cellular',
#  'Liquids',
#  'Key',
#  'Land',
#  'Knowing',
#  'Now,',
#  'Gender',
#  'Decision',
#  'Increased',
#  'Major',
#  'Joint',
#  'Game',
#  'Logical',
#  'Anomaly',
#  'Ideally,',
#  'Process',
#  'Map',
#  'Accordingly,',
#  'Basing',
#  'Advertisers',
#  'Capitalizing',
#  'Will',
#  'Participatory',
#  'Examining',
#  'Overall',
#  'Important',
#  'Classic',
#  'Crucially,',
#  'Breast',
#  'Hematoxylin',
#  'Development',
#  'Defect',
#  'Since,',
#  'Identity',
#  'Humans',
#  'Series',
#  'Later',
#  'Fog',
#  'Analytical',
#  'Tropical',
#  'Applications',
#  'Accelerated',
#  'Which',
#  'Project',
#  'Consumers',
#  'Point',
#  'Aboria',
#  'Everything',
#  'Coexistence',
#  'Scale',
#  'Linked',
#  'Adapted',
#  'Beginning',
#  'Nonnegative',
#  'Upper',
#  'Moving',
#  'Number',
#  'Algorithmic',
#  'Question',
#  'Recognition',
#  'Hierarchical',
#  'Inverse',
#  'Progressive',
#  'Amongst',
#  'Structure',
#  'Notably,',
#  'Notwithstanding,',
#  'Case',
#  'Handwritten',
#  'Enterprise',
#  'Authoring',
#  'Selecting',
#  'Do',
#  'Curiously,',
#  'Language',
#  'Facing',
#  'Nearly',
#  'Evaluation',
#  'Kernel',
#  'Churn',
#  'Anonymization',
#  'Devising',
#  'Availability',
#  'Tasks',
#  'Today,',
#  'Sometimes',
#  'Intelligent',
#  'Neuroblastoma',
#  'Surprisingly',
#  'Complementary',
#  'Across',
#  'Transfer',
#  'Content',
#  'Theories',
#  'Connectivity',
#  'Taken',
#  'Projective',
#  'Probabilities',
#  'Recommender',
#  'Mr.',
#  'Operators',
#  'Six',
#  'Increasingly',
#  'Flow',
#  'Computing',
#  'Disjunctive',
#  'Literature',
#  'Recommendation',
#  'Cases',
#  '(2014)',
#  'Split',
#  '(2017)',
#  'Incorporating',
#  'Very',
#  'Keywords',
#  "Today's",
#  'Bandwidth',
#  'Let',
#  'Frame',
#  'Constraint',
#  'Apart',
#  'Indexing',
#  'Presently,',
#  'Gaining',
#  'Lack',
#  'Issues',
#  'Finite',
#  'Implementation',
#  'Indeed',
#  'Cyber',
#  'Widespread',
#  'Hybrid',
#  'Univariate',
#  'Agile',
#  'Principles',
#  'Smoothed',
#  'Tensegrity',
#  'Discriminant',
#  'Second',
#  'Flexible',
#  'Watermark',
#  'Extraction',
#  'Completeness',
#  'Volume',
#  'Medical',
#  'Used',
#  'Mining',
#  'Message',
#  'Recognising',
#  'Mapping',
#  'Resources',
#  'Single',
#  'Home',
#  'Describing',
#  'Prediction',
#  'Mel',
#  'Everyday',
#  'Assigning',
#  'Approximate',
#  'Deformable',
#  'Discrete',
#  'Characterizing',
#  'Aiming',
#  'Submodular',
#  'Hardware',
#  'Adaptive',
#  'Electronic',
#  'Diffusion',
#  'Videos',
#  'Heretofore,',
#  'Predictive',
#  'Who',
#  'Volunteer',
#  'Redundancy',
#  'Multiagent',
#  'Heuristic',
#  'Fast',
#  'Differing',
#  'Perfect',
#  'Popularity',
#  'Individuals',
#  'Iterative',
#  'Benchmarking',
#  'Previously,',
#  'Fault',
#  'Skin',
#  'Permutation',
#  'Last',
#  'Subject',
#  'Memories',
#  'Multi',
#  'Implemented',
#  'Small',
#  'Varying',
#  'Coherent',
#  'Free',
#  'Impact',
#  'Weather',
#  'Microscopic',
#  'Loop',
#  'Query',
#  'Conversational',
#  'Alongside',
#  'Popular',
#  'Together,',
#  'Symmetric',
#  ';',
#  'There,',
#  'Technically,',
#  'Inside',
#  'Those',
#  '(1)',
#  'Performing',
#  'Concepts',
#  'Methodology',
#  'General',
#  'Papers',
#  'Researchers,',
#  'Terms',
#  'Performances',
#  'Matrix',
#  'Cryptocurrencies',
#  'Outside',
#  'Provably',
#  'Problem',
#  'Mobility',
#  'Allowing',
#  ...]

# %%
words
# Out:
# {'newest',
#  'inhibitor',
#  'diminished',
#  'an',
#  'shoppers',
#  'bot',
#  'Output',
#  'Jaccard',
#  'inter-link',
#  'DBLP',
#  'Lyndon',
#  'Ph-CNN',
#  'outperform',
#  '71',
#  'akin',
#  'occuring',
#  'Essence',
#  'augment',
#  'Expert',
#  'manifestations',
#  'freedoms',
#  'RUs',
#  'HTTP',
#  'Migration',
#  'Bi-LSTM',
#  'acoustics',
#  'serves',
#  'Controlled-NOT',
#  'extending',
#  'cost-sensitive',
#  'KSMM',
#  'bit-error',
#  'greedily',
#  'vending',
#  'leaderboards',
#  'Outback',
#  'NGC',
#  'Peridynamics',
#  'state-changing',
#  'nearest',
#  '68.10',
#  'life-long',
#  'Hash',
#  '0.35',
#  'value-network',
#  'ad-hoc',
#  'linguistically',
#  'domain-agnostic',
#  'soft-weighted',
#  'accessed',
#  'multi-client',
#  'coreference',
#  'CLFD',
#  'opinion-focused',
#  'miminum',
#  'Exception',
#  'Ever',
#  'minute-long',
#  'printed',
#  'EC3',
#  'DSTC2',
#  'DGS',
#  'monogamous',
#  '320x320',
#  'scanner',
#  'historic',
#  'V/HTS',
#  'questionnaires',
#  'EH',
#  'Deciding',
#  'cake',
#  'LED',
#  '//faculty.pieas.edu.pk/fayyaz/software.html',
#  'obstacles',
#  'disambiguate',
#  'Put',
#  'human-oriented',
#  'dictation',
#  'flasks',
#  'X-basis',
#  'SIT',
#  'hyper-graph',
#  'region-sequences',
#  'Deteriorate',
#  'cycles/paths',
#  '2-DOF',
#  'RCPO',
#  'conceptualize',
#  'stipulated',
#  'dissuade',
#  'S-Boxes',
#  'PRMs',
#  'unethical',
#  'disaggregated',
#  'Transaction',
#  'thinner',
#  're-examined',
#  'grades',
#  'changes',
#  'I/O',
#  'Mura',
#  'logit',
#  'G-code',
#  'began',
#  'declined',
#  'non-anonymized',
#  'Amulet',
#  'state-action-features',
#  'intra-city',
#  'Temple',
#  'SLNs',
#  'SINR-optimal',
#  'asynchrony',
#  'G-SGD',
#  'monoidal',
#  'frequency-domain',
#  'C-LSTM',
#  'Ratchet',
#  'append',
#  '2,096',
#  'apartments',
#  'colony.Furthermore',
#  'potent',
#  'discounted',
#  'demographic-based',
#  'A*',
#  'Query-Reduction',
#  'Express',
#  'outlying',
#  'unfoldings',
#  'LDPD',
#  'xxx^R',
#  'output-based',
#  'ODE',
#  'TRD',
#  'policy-gradient',
#  'Socially',
#  'action-based',
#  'Founsure',
#  'Gottesman-Knill',
#  'trapezium',
#  'joint',
#  'Chamfer',
#  'Properties',
#  'W.',
#  'UML-compliant',
#  'flooded',
#  'Javascript',
#  'non-memoryless',
#  'KQ-Learning',
#  'unfamiliar',
#  'e.g',
#  'produced',
#  'visualizing',
#  'outperforms',
#  'lab',
#  'cancer',
#  'h-index',
#  'meta-information',
#  'MS/MS',
#  'Non-Terrestrial',
#  'resection',
#  'R-Tree',
#  'sub-problems',
#  'Frame',
#  'non-colluding',
#  'bug-finding',
#  'workers',
#  'enforcing',
#  'Cepstral',
#  'resemble',
#  '123',
#  'mixed-autonomy',
#  'national',
#  'recusing',
#  'Acquiring',
#  'dissolution',
#  'time-invariant',
#  'hypothesis-testing',
#  'migrations',
#  'Keshav',
#  'EigenPro',
#  'Pyramidal',
#  'self-paced',
#  'transliterable',
#  'exacerbating',
#  'Femtocell',
#  'compensable',
#  'performance-conscious',
#  'CKS',
#  'SPARK',
#  'Sclerosis',
#  'Sway',
#  'accept',
#  'scaffold',
#  'multi-labelled',
#  'confident',
#  'lot-splitting',
#  'pencil',
#  'Concerning',
#  'Whereas',
#  'state-of-the-',
#  'AQM',
#  '4.7',
#  'mathematic',
#  'Cover',
#  'reflectivity',
#  'multi-constrained',
#  'Kafka',
#  'non-elementary',
#  'consistence',
#  'subsample',
#  'Backpropagation',
#  'beacons',
#  'healthcare-',
#  'purchasing',
#  'ASVspoof2015',
#  'world-level',
#  'NHMC',
#  'Symbolic',
#  'Datalog',
#  'Singularity',
#  'candidates',
#  'derandomisation',
#  'hoaxes',
#  'non-native',
#  'high',
#  'insights',
#  'time-',
#  'Oudalov',
#  '1175-fold',
#  'Windows/x86',
#  'anyons',
#  'ultra-high-speed',
#  '697',
#  'non-vanishing',
#  'Self-Paced',
#  'rotation',
#  'FakeNews',
#  'intercepts',
#  'TRANCOS',
#  '98.40',
#  'odd-degreed',
#  'IIK',
#  'Lankan',
#  'in-order',
#  '4146',
#  'splitting',
#  'locating',
#  'LiDAR-based',
#  'qualitatively',
#  'Naturally',
#  'Birth',
#  'OS',
#  'AFL',
#  'SW-UCB',
#  'exemplify',
#  'MPU',
#  'PnPAdaNet',
#  'Hamming-like',
#  'IRNNs',
#  'MMC',
#  'end-of-classes',
#  'penalized',
#  'thin-plate',
#  'coexists',
#  'source-to-relay',
#  'cryoEM',
#  'dynamic-programming',
#  'debugged',
#  'flow-sensitive',
#  '13.1',
#  'Earthquakes',
#  'performers',
#  'shell',
#  'made',
#  'applicability',
#  'nonnegativity',
#  'PLI',
#  'F',
#  'deg',
#  'metameric',
#  'RecipeQA',
#  'GSs',
#  'cloud',
#  "'yes",
#  'self-citations',
#  'high-dimensional',
#  '8x2-fold',
#  'DNNand',
#  'inspector',
#  'Z1',
#  'DE',
#  'DAE',
#  'agreeably',
#  'Potsdam',
#  'single-input-single-output',
#  'Mansilla',
#  'signal-to-noise-and-distortion-ratio',
#  'plague',
#  'Few-shot',
#  '52,694.8',
#  'incorrectly',
#  'KCS',
#  'Watermarked',
#  'unreached',
#  'Number',
#  'Metastability',
#  'real-robot',
#  'LN',
#  'credible',
#  'E-waste',
#  'SVRG',
#  'requirements',
#  'symmetry-breaking',
#  'Deep-neural-network',
#  'WWW',
#  'versioning',
#  'performant',
#  'big-O',
#  'ECHO',
#  'visitors',
#  'three-pass',
#  'warden',
#  'shortcuts',
#  'inappropriateness',
#  'accelerometers',
#  'cardinalities',
#  'strategize',
#  'DLaaS',
#  'scalably',
#  'resorting',
#  'erasion',
#  'toss',
#  'laboratories',
#  'multi-core',
#  'PWM',
#  'surplus',
#  'Scalable',
#  'imperatively',
#  'non-trivial',
#  'multiarmed',
#  'Feature-wise',
#  'staying',
#  'congenital',
#  'NL',
#  'Descent',
#  'VELO',
#  'photodetector',
#  'Logarithmic',
#  'grain',
#  'endpoint',
#  'SDLogic',
#  'idealized',
#  'AI',
#  'adversaries',
#  '!',
#  'AUC=99.99',
#  'Blowfish',
#  'n-ary',
#  'worksheet',
#  'query-answering',
#  'rectangle',
#  'circumvent',
#  'semi-decides',
#  'Imputing',
#  'contended',
#  'GrabCut',
#  'Thompson',
#  'Muslims',
#  'fully-configured',
#  'discretizing',
#  'cuPC',
#  'binary-quantized',
#  'ACT',
#  'Lyapunov',
#  'vocalised',
#  'referrals',
#  'mispredicted',
#  'nuclei',
#  'transcribing',
#  'coarse-to-fine',
#  'Levoy',
#  '70',
#  'DP-16QAM',
#  'clear-cut',
#  'Programmers',
#  'informally',
#  '24000',
#  'Kinetic',
#  'songwriter',
#  'corrupted',
#  'boundary-seeking',
#  "NAACL'18",
#  'Sunday',
#  'multi-GPU',
#  'computation-',
#  'predict/improve',
#  'probabilistically',
#  'FMIFS-LSSVM-IDS',
#  'MLR',
#  "'The",
#  'satisfying',
#  'learning-as-a-service',
#  'Majority',
#  'SimPowerSystems',
#  'redefining',
#  'Differences',
#  '`DDFFNet',
#  'individuality',
#  'reproducibility',
#  'pseudorandomly',
#  'phenotype',
#  'GE',
#  'coauthorship',
#  'recovers',
#  'Audio2Vec',
#  'observables',
#  'packet',
#  'translational',
#  'prominent',
#  'albeit',
#  'Income',
#  'post-test',
#  'remarkably',
#  'concerning',
#  'attained',
#  'regardless',
#  'Einstein-like',
#  'AMF',
#  'myPDDL',
#  'sub-domain',
#  'Han',
#  'Brandenburger',
#  'multi-instances',
#  'bite',
#  '2q',
#  'ill-defined',
#  'at-tacks',
#  'increases',
#  'blocks',
#  'DeepMind',
#  'angle-delay',
#  'ep-pair',
#  'Rotational',
#  'Image-to-Image',
#  'nerve',
#  'under-sampled',
#  'subjective',
#  'femto',
#  'portfolios',
#  'microcapsule',
#  'Fogs',
#  'fair',
#  'Ferrers',
#  'ABAQUS',
#  '83.5',
#  'indicates',
#  'radiative',
#  'impossibility',
#  'VGB',
#  'renderings',
#  'C-Log',
#  'differ',
#  '97.8',
#  'enegineering',
#  'happens-before',
#  'FPR',
#  '//github.com/YuliangXiu/PoseFlow',
#  'biologist',
#  'RSP',
#  'likely',
#  'Vivado',
#  'animates',
#  'particularities',
#  'untrusted',
#  'gracefully',
#  'TISLF',
#  'head-word',
#  '78.5',
#  'artifice',
#  'giant',
#  'modification',
#  'own',
#  'sanitization',
#  'enhances',
#  'CCD',
#  'stack',
#  'PLT',
#  'Finzer',
#  'continuous-to-discrete',
#  'airtime',
#  'unrepeatable',
#  'TPE',
#  'hyperplane',
#  'Informed',
#  '-5',
#  'dilemma',
#  'substantiated',
#  'authenticate',
#  'extensional',
#  'JT',
#  'implicants',
#  'evenness',
#  'planning/street',
#  'facilitators',
#  'neurophysiologists',
#  '42,000',
#  'part-labels',
#  'MU-MISO',
#  'semialgebraic',
#  'sitting',
#  'Inversion',
#  'KNSC-Ncut',
#  'fast',
#  'Normalization',
#  'JavaBeans',
#  'microfluidics',
#  'orthodox',
#  'Pareto',
#  'nanotube',
#  'multidomain',
#  'synthesizable',
#  '10.6',
#  'IIIT-5k',
#  'Islamist',
#  'transfered',
#  '-polymatrix',
#  'finances',
#  'nanoscience',
#  '95.5',
#  'behavior.We',
#  'Dantzig',
#  'RegionNet',
#  'hobby',
#  'strenuous',
#  'DSCSP',
#  'desert',
#  'inter-dominant',
#  'Shape',
#  'concatenative',
#  'specie',
#  'adaptivity',
#  'facto',
#  'endeavors',
#  'dam',
#  'ROUGE-2',
#  'Harnessing',
#  'chal-',
#  'intersecting',
#  'high-stakes',
#  'Urology',
#  'sub-KT/bit',
#  'image-',
#  'look-ahead',
#  'Hz',
#  'Linprog',
#  'MITM',
#  'retention',
#  'transmits',
#  'braking',
#  'lines',
#  'axis',
#  'PLC',
#  'automatized',
#  'tlenecks',
#  'Balanced',
#  'GPS-level',
#  'non-normality',
#  'Sintel',
#  'ridge',
#  'II',
#  'SH',
#  'mesh',
#  'Live.me',
#  'neurological',
#  'aeronautical',
#  'tactile',
#  'maximize',
#  'technologically',
#  'Spider',
#  'expanses',
#  'phase-boundaries',
#  'excite',
#  'Laplace',
#  'microalgae',
#  'Currie',
#  'SideRand',
#  'pleasant',
#  '58.44',
#  'freehand',
#  'threads',
#  'Progress',
#  'intercept',
#  'CSIQ~and',
#  'HELIOS2016',
#  'severity',
#  'Recurring',
#  'macro-average',
#  'A2-RL',
#  'Mellin',
#  'GRO-indexes',
#  '1024-dimensional',
#  'batteries',
#  '1930',
#  'PubFig83',
#  '7.2',
#  'Hand',
#  'SLN',
#  'continuity',
#  'multi-sided',
#  'MSI',
#  'interfere',
#  'Repovs',
#  'HardScope',
#  'bitrates',
#  'thermal',
#  'IA',
#  'cause',
#  'SPPAM',
#  'wisdom',
#  'time-shifted',
#  'picks',
#  'compiles',
#  'club',
#  'groups',
#  'ubiquity',
#  'NGI-based',
#  'load-proportional',
#  'dispersed',
#  'outsole',
#  'interference-safe',
#  'INR',
#  'UIO',
#  'instance',
#  'MSC',
#  '77',
#  'sub-channel',
#  'E2E',
#  'CMI',
#  'set-up',
#  'forte',
#  'Transactions',
#  'n-qubit',
#  'stadium',
#  'advances',
#  'automata-theoretic',
#  'deficient',
#  'Aurora-4',
#  'crowdedness',
#  'Robot',
#  'Decorrelation',
#  'sung',
#  'Preference',
#  'billion',
#  'recognize',
#  'proof',
#  'Effort',
#  'well-formed',
#  'AlertMix',
#  'MOPs',
#  '433K',
#  'textbook',
#  'Dem',
#  'NUMA',
#  'size-dependent',
#  'iPhone',
#  'Magnatagatune',
#  'considers',
#  'polygonal',
#  'SERs',
#  'HDP',
#  'two-hop',
#  'inter-connect',
#  'MOEA/D-Tree',
#  'overclose',
#  'multi-graph',
#  'catering',
#  '30k',
#  'PDFs',
#  '//hepdata.cedar.ac.uk',
#  'dealing',
#  'oceanic',
#  'extent',
#  'stitching',
#  'stellar',
#  'omnicrawler',
#  'central-moment-relaxation',
#  'treebank',
#  'counterexample',
#  'nano-objects',
#  'Interval',
#  'neonates',
#  'nor',
#  'apertures',
#  'BGANs',
#  'batteryoperated',
#  'Multi-granularity',
#  'touted',
#  'conductance',
#  'monetise',
#  'Dunn/Belnap',
#  'forecasted',
#  'stigmergic',
#  'Bennett-Brassard',
#  'PSS/E',
#  'DFFW-CRBM',
#  'complement',
#  'CD',
#  'power-temperature',
#  'temporoparietal',
#  'Atomic',
#  'non-flat',
#  'VIP-GAN',
#  'assertions',
#  'BFs',
#  'RaaS',
#  'morphable',
#  'dead',
#  'non-switching',
#  'pseudo-metrics',
#  'YouTube',
#  'VRPTW',
#  'co-occurrences',
#  'many-core',
#  'DLZ',
#  '3D-based',
#  '25',
#  'SWAY',
#  'size-k',
#  'Gray-Level',
#  'cochlear',
#  'Instructions',
#  'multi-brain',
#  'homogeneous',
#  'well-structured',
#  'defense-in-depth',
#  '1.49',
#  'trainees',
#  'out-of-order',
#  'biomarkers',
#  'fixed-based',
#  'H2',
#  'enforcement',
#  'TeachNet',
#  'Hash-based',
#  'uA',
#  'ResNets',
#  'Covering',
#  'one-half',
#  'VC-dimension',
#  'COCO-QA',
#  'fragment',
#  'quote',
#  'CycleGAN',
#  'outlined',
#  'KRR',
#  'colour-suppressed',
#  'Coherent',
#  'semi-group',
#  'cone',
#  'PowerSign',
#  '2.6',
#  'secondly',
#  'Ensemble',
#  'Frequency-Invariant',
#  'aspects',
#  'unruled',
#  'Striving',
#  'Unsquared',
#  'GLD',
#  'perturbs',
#  'oVER',
#  'communicated',
#  'underlining',
#  'Mallat',
#  'insensitive',
#  'multisensory',
#  'meaning',
#  'web-application',
#  'drills',
#  'WSN',
#  'pre-trained',
#  'L_2-heavy',
#  'bind',
#  'cleartext',
#  '-smart',
#  'CMM',
#  'EMRs',
#  'meta-heuristics',
#  'pre-ISIS',
#  'wide-reaching',
#  'hopcounts',
#  'SOMs',
#  'averse',
#  'MC',
#  'robot-object',
#  '14.76',
#  'non-orthogonal',
#  'Allegory',
#  'node-differentially',
#  'single-path',
#  'HEMI',
#  'SurveyMan',
#  'non-excitable',
#  'Priming',
#  'appears',
#  'dappled',
#  'IPP',
#  'secret-key',
#  'Thesaurus',
#  'GS-ADMM',
#  'tun-',
#  'dub',
#  'incentive',
#  'undiscovered',
#  'PIE',
#  'Clenshaw',
#  'order-theoretic',
#  'CUAVE',
#  'serving',
#  'ally',
#  'prosthetic',
#  'typing',
#  'dimensional',
#  'Branch',
#  'task-related',
#  'including',
#  'artworks',
#  'Matrix-Tensor',
#  'refined',
#  'sketch-based',
#  'valleys',
#  'Shifting',
#  'multi-site',
#  'bicyclists',
#  'Perspectives',
#  'sonnet-generation',
#  'guess',
#  're-identify',
#  'Computing',
#  'isometry-equivariant',
#  'SMFL',
#  'angles',
#  'EBSN',
#  'inspect',
#  'row',
#  'OR',
#  'Dexter',
#  'fully-charged',
#  'activation-dependent',
#  'GPS',
#  'Singapore',
#  'fluents',
#  'lane',
#  'JPEG2000',
#  'SPS',
#  'ITR',
#  'SISO',
#  'Biot',
#  'terminologies',
#  'p-value',
#  'Multi-kernel',
#  'votes',
#  'drain',
#  'ROS',
#  'Havel-Hakimi',
#  'seismol-ogy',
#  'IC',
#  '80.5',
#  'Provisioning',
#  'imagined',
#  'two-file',
#  'log-normal',
#  'radiomics',
#  'weakened',
#  'discovered',
#  'subfamilies',
#  'recorder',
#  'itself',
#  '//layek.khu.ac.kr/CEQI',
#  'end-effectors',
#  'Brain-related',
#  'all-terrain',
#  'Werzanski',
#  'sensitivity',
#  'XG',
#  'DilatedRNN',
#  '1779',
#  'TRSM',
#  'code-specific',
#  'Top-K',
#  'polyiamonds',
#  'pellet',
#  'palindromes',
#  'gateway',
#  'centralized',
#  'Power',
#  'Conserving',
#  'Robinhood',
#  'Fox',
#  'Ghost',
#  'examining',
#  'respective',
#  'test-suite',
#  'compromises',
#  'equa-',
#  'assessments',
#  'intuitions',
#  'multipleantenna',
#  'multi-spectral',
#  'collapsing',
#  'LIVR',
#  'C-like',
#  'information',
#  'Grad-CAM',
#  'randomly-generated',
#  'bit/time',
#  'Curriculum',
#  'l.',
#  'worldview',
#  'cybernetic',
#  'problem-solving',
#  'summary-based',
#  'Metaheuristic',
#  'Substrate',
#  '//github.com/davidcraft/SimKern',
#  'homothety',
#  'entity-set',
#  '~linkable',
#  'experimentalists',
#  'under-determined',
#  'Barabasi-Albert',
#  'PMSM',
#  'Billion',
#  '//sites.google.com/view/mimedataset',
#  'synonyms',
#  'hashtag',
#  'multi-socket',
#  'WordNet',
#  'almost-size-universal',
#  '-Uniform',
#  'hospitals',
#  'harmful',
#  'entire',
#  'TRAnsforms',
#  'HDM05',
#  'SCAS-2',
#  'part-set',
#  'unstable',
#  'Alternative',
#  'disturbing',
#  're-link',
#  'handoffs',
#  '10.4x',
#  'S2S',
#  'neck',
#  '95.6',
#  'learner-centred',
#  'disillusioning',
#  'catch',
#  'multibond',
#  'TREC',
#  'highlights',
#  'enterprise-scale',
#  'non-orientable',
#  'silicon',
#  'Associative',
#  'manners',
#  'theta-basis',
#  'annihilating',
#  '38291',
#  'Attack',
#  '-optimizing',
#  'programming',
#  'BM',
#  'spellcheckers',
#  'Smartphone',
#  'wrapping',
#  'PDE',
#  'degree-degree',
#  'SymbioCity',
#  'highly-optimized',
#  'Cut',
#  'iii',
#  'perceptron',
#  'endowed',
#  'Cylindrical',
#  'under-fitting',
#  'NTGA',
#  'transcript',
#  'scattershot',
#  'understandable',
#  '293K',
#  'RCoF',
#  'TCLN',
#  'detector',
#  '41',
#  'non-monotonic',
#  'Variants',
#  ...}

# %% [markdown]
# ### 爬品牌名稱來對照

# %%
import requests
from bs4 import BeautifulSoup
import json

r = requests.get("https://brandirectory.com/rankings/global-500-2018") #將網頁資料GET下來
soup = BeautifulSoup(r.text, "html.parser") # 將網頁資料以html.parser
# sel = soup.select("a.tight-text") # 取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
# sel
text = soup.find_all("script", type="application/ld+json")[0]
contents_dict = json.loads(text.contents[0])
# type(contents_dict)
brand_names = [d["item"]["name"] for d in contents_dict["itemListElement"]]
brand_names[:6]
# Out:
# ['Amazon', 'Apple', 'Google', 'Samsung', 'AT&T', 'Microsoft']

# %%
import string
import re

punctuations = ''.join([s for s in string.punctuation if s not in ('<', '>', '-')]) #  斜線冒號留著for Others label

def word_preprocess(word):

  # remove punctuations
  word = word.translate(str.maketrans('', '', punctuations))

  # remove numbers
  if '-' not in word:
    word = re.sub(r'\d+', '', word)

  if '-' in word:
    if (np.sum([w.isdigit() for w in word]) / len(word)) > 0.8:
      word = '<numbers>'
    else:
      word = '<cool-abr>'

  # brands
  if word in brand_names:
    word = '<brand>'

  # proprietary 1
  # if len(word) > 1:
  #   if (list(word)[0] == '(') and (list(word)[-1] == ')'):
  #     word = '<abr>'

  # all uppercase
  if len(word) > 1:
    if (np.sum([w.isupper() for w in word]) >= 1) and (word not in first_words):
      word = '<pry>'
  
  # URL
  if word in ["http", "github", "com"]:
      word = '<url>'


  # lemmatization
  # lemma = nltk.wordnet.WordNetLemmatizer()
  # word = lemma.lemmatize(word)

  # remove single character
  # if len(list(word)) < 2:
  #   word = ""

  return word # .lower() 換成小寫分數差很多?

# %%
from nltk.corpus import stopwords

with Pool() as pool:
  result = pool.map(word_preprocess, words)

words_pre = set(result)

print(stopwords.words('english'))
# words_pre = set([w.lower() for w in words_pre])
# words_pre = words_pre - set(stopwords.words('english'))

words_pre = words_pre - {''}
words_pre
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# {'newest',
#  'inhibitor',
#  'diminished',
#  'an',
#  'discrete',
#  'shoppers',
#  'bot',
#  'Output',
#  'Jaccard',
#  'composition',
#  'Evolutionary',
#  'harmonization',
#  'issuing',
#  'surfel',
#  'panoramic',
#  'sacrifice',
#  'outperform',
#  'renewables',
#  'akin',
#  'occuring',
#  'schemata',
#  'explained',
#  'traps',
#  'emotions',
#  'augment',
#  'Expert',
#  'agricultural',
#  'manifestations',
#  'furthermore',
#  'Migration',
#  'freedoms',
#  'gaps',
#  'acoustics',
#  'serves',
#  'pericardial',
#  'identificationverification',
#  'generationprediction',
#  'extending',
#  'greedily',
#  'vending',
#  'permutohedral',
#  'leaderboards',
#  'juniors',
#  'commuting',
#  'insiders',
#  'Peridynamics',
#  'cardinals',
#  'tell',
#  'confounder',
#  'communication',
#  'nearest',
#  'Topological',
#  'Hash',
#  'linguistically',
#  'decrypted',
#  'accessed',
#  'Provenance',
#  'coreference',
#  'pill',
#  'implement',
#  'firstresults',
#  'miminum',
#  'Molecular',
#  'summoned',
#  'price',
#  'fluobactrackerinrialpesfr',
#  'Ever',
#  'printed',
#  'monogamous',
#  'elucidated',
#  'mandated',
#  'scanner',
#  'historic',
#  'boarding',
#  'questionnaires',
#  'animations',
#  'search',
#  'Deciding',
#  'cake',
#  'keep',
#  'obstacles',
#  'disambiguate',
#  'dictation',
#  'Bias',
#  'synchrosqueezing',
#  'flasks',
#  'engage',
#  'collaborations',
#  'videographers',
#  'conceptualize',
#  'sealed',
#  'cup',
#  'front',
#  'stipulated',
#  'dissuade',
#  'endangerment',
#  'unethical',
#  'henceforth',
#  'disaggregated',
#  'thinner',
#  'grades',
#  'changes',
#  'logit',
#  'began',
#  'declined',
#  'decoder',
#  'asynchrony',
#  'monoidal',
#  'append',
#  'quantified',
#  'apartments',
#  'stabilization',
#  'potent',
#  'p',
#  'discounted',
#  'outlying',
#  'unfoldings',
#  'Videos',
#  'retractions',
#  'resulting',
#  'Founsure',
#  'obesity',
#  'consequently',
#  'trapezium',
#  'joint',
#  'undisclosed',
#  'Properties',
#  'bytecharacter',
#  'flooded',
#  'convention',
#  'sac',
#  'hinder',
#  'unfamiliar',
#  'Snapshot',
#  'produced',
#  'visualizing',
#  'modularization',
#  'outperforms',
#  'lab',
#  'cancer',
#  'resection',
#  'bittime',
#  'knob',
#  'Frame',
#  'workers',
#  'enforcing',
#  'prioritising',
#  'resemble',
#  'national',
#  'cine',
#  'recusing',
#  'conjunction',
#  'transversals',
#  'representing',
#  'Expressive',
#  'cosmic',
#  'Acquiring',
#  'venations',
#  'aesthetically',
#  'dissolution',
#  'biharmonic',
#  'stroke',
#  'drawings',
#  'migrations',
#  'Nowadays',
#  'If',
#  'noncoherent',
#  'wikify',
#  'terpreting',
#  'transliterable',
#  'exacerbating',
#  'pregnancy',
#  'dialogues',
#  'compensable',
#  'speciesclasses',
#  'Edges',
#  'restatement',
#  'accept',
#  'scaffold',
#  'Inferences',
#  'confident',
#  'pencil',
#  'Concerning',
#  'Whereas',
#  'adjusts',
#  'Private',
#  'microbiota',
#  'ozone',
#  'mathematic',
#  'Cover',
#  'Recognising',
#  'vaccination',
#  'reflectivity',
#  'mpstego',
#  'inspiration',
#  'chiefly',
#  'consistence',
#  'subsample',
#  'Backpropagation',
#  'beacons',
#  'interestingness',
#  'purchasing',
#  'panel',
#  'Symbolic',
#  'candidates',
#  'derandomisation',
#  'redundantly',
#  'Predicted',
#  'hoaxes',
#  'high',
#  'insights',
#  'autopilot',
#  'gadolinium',
#  'efficientcomputation',
#  'diagnosability',
#  'anyons',
#  'facultypieasedupkfayyazsoftwarehtml',
#  'diamonds',
#  'graphemes',
#  'rotation',
#  'scopes',
#  'intercepts',
#  'al',
#  'socialbots',
#  'Armed',
#  'Prepositions',
#  'subprobability',
#  'sdlog',
#  'splitting',
#  'histories',
#  'locating',
#  'qualitatively',
#  'headway',
#  'exemplify',
#  'correspondences',
#  'hepdatacedaracuk',
#  'Ads',
#  'directivity',
#  'Protection',
#  'dbp',
#  'penalized',
#  'coexists',
#  'scars',
#  'initializations',
#  'divisor',
#  'debugged',
#  'closely',
#  'nullspace',
#  'fuzzify',
#  'impairment',
#  'performers',
#  'shell',
#  'made',
#  'applicability',
#  'nonnegativity',
#  'compendium',
#  'proliferated',
#  'F',
#  'deg',
#  'oppose',
#  'metameric',
#  'discussion',
#  'summarising',
#  'cloud',
#  'title',
#  'pipelined',
#  'exams',
#  'shortfalls',
#  'vg',
#  'statistics',
#  'inspector',
#  'agreeably',
#  'connects',
#  'plague',
#  'Speaker',
#  'incorrectly',
#  'consented',
#  'Watermarked',
#  'unreached',
#  'Number',
#  'possibilities',
#  'credible',
#  'smooth',
#  'Initial',
#  'drum',
#  'Engineering',
#  'requirements',
#  'datascape',
#  'eloped',
#  'onset',
#  'versioning',
#  'performant',
#  'accounts',
#  'irregularities',
#  'boiler',
#  'binarizing',
#  'donors',
#  'genetically',
#  'visitors',
#  'economical',
#  'warden',
#  'shortcuts',
#  'inappropriateness',
#  'province',
#  'fruitfully',
#  'accelerometers',
#  'cardinalities',
#  'strategize',
#  'scalably',
#  'Experience',
#  'resorting',
#  'anthropomimetic',
#  'validate',
#  'erasion',
#  'toss',
#  'jaw',
#  'laboratories',
#  'practically',
#  'just',
#  'surplus',
#  'Scalable',
#  'imperatively',
#  'multiarmed',
#  'midsagittal',
#  'staying',
#  'congenital',
#  'photodetector',
#  'informs',
#  'grain',
#  'endpoint',
#  'moot',
#  'consumes',
#  'evolutionary',
#  'idealized',
#  'adversaries',
#  'leaks',
#  'irrationally',
#  'worksheet',
#  'joined',
#  'centrality',
#  'rectangle',
#  'ramp',
#  'particularize',
#  'deductions',
#  'circumvent',
#  'questioning',
#  'contended',
#  'Thompson',
#  'reparametrization',
#  'original',
#  'replay',
#  'discretizing',
#  'checkpointing',
#  'capsule',
#  'film',
#  'vocalised',
#  'referrals',
#  'mispredicted',
#  'daedalus',
#  'Fast',
#  'nuclei',
#  'transcribing',
#  'tracked',
#  'incompressibility',
#  'Programmers',
#  'informally',
#  'Kinetic',
#  'operand',
#  'songwriter',
#  'corrupted',
#  'outputs',
#  'intrinsically',
#  'autopoiesis',
#  'probabilistically',
#  'satisfying',
#  'Constructive',
#  'Majority',
#  'redefining',
#  'Differences',
#  'individuality',
#  'resonator',
#  'reproducibility',
#  'pseudorandomly',
#  'phenotype',
#  'coauthorship',
#  'recovers',
#  'leak',
#  'observables',
#  'biosphere',
#  'packet',
#  'translational',
#  'prominent',
#  'albeit',
#  'remarkably',
#  'concerning',
#  'attained',
#  'polycrystalline',
#  'regardless',
#  'maximiser',
#  'bite',
#  'realize',
#  'conjugates',
#  'increases',
#  'blocks',
#  'Experts',
#  'vacant',
#  'nerve',
#  'emoji',
#  'subjective',
#  'femto',
#  'portfolios',
#  'hotspot',
#  'expressively',
#  'microcapsule',
#  'breakpoint',
#  'fair',
#  'kilobits',
#  'Development',
#  'indicates',
#  'radiative',
#  'impossibility',
#  'pooling',
#  'catheter',
#  'renderings',
#  'differ',
#  'approximately',
#  'enegineering',
#  'downstream',
#  'biologist',
#  'amalgamation',
#  'likely',
#  'suicide',
#  'exchanges',
#  'backlogs',
#  'animates',
#  'executing',
#  'particularities',
#  'per',
#  'untrusted',
#  'gracefully',
#  'decorrelator',
#  'w',
#  'disassembled',
#  'artifice',
#  'giant',
#  'modification',
#  'own',
#  'sanitization',
#  'enhances',
#  'airtime',
#  'stack',
#  'unrepeatable',
#  'hyperplane',
#  'Informed',
#  'dilemma',
#  'substantiated',
#  'sequel',
#  'sections',
#  'authenticate',
#  'advisement',
#  'subpar',
#  'extensional',
#  'gated',
#  'hit',
#  'cosmological',
#  'implicants',
#  'consumer',
#  'proneness',
#  'evenness',
#  'Frequency',
#  'facilitators',
#  'neurophysiologists',
#  'multicell',
#  'aside',
#  'Aware',
#  'notification',
#  'Wide',
#  'semialgebraic',
#  'amended',
#  'sitting',
#  'tutorials',
#  'pertaining',
#  'fast',
#  'phonemes',
#  'Normalization',
#  'refreshed',
#  'microfluidics',
#  'accumulators',
#  'orthodox',
#  'nanotube',
#  'multidomain',
#  'percolation',
#  'synthesizable',
#  'happiest',
#  'transfered',
#  'nanoscience',
#  'finances',
#  'hobby',
#  'strenuous',
#  'isometry',
#  'desert',
#  'Shape',
#  'communicative',
#  'combinations',
#  'concatenative',
#  'fixated',
#  'specie',
#  'intake',
#  'adaptivity',
#  'hemiplegia',
#  'Up',
#  'nxn',
#  'facto',
#  'systematizes',
#  'endeavors',
#  'dam',
#  'staffing',
#  'Vast',
#  'contextualization',
#  'tagged',
#  'stabilizer',
#  'intersecting',
#  'Does',
#  'actuators',
#  'stationarity',
#  'gives',
#  'rebalancing',
#  'retention',
#  'transmits',
#  'braking',
#  'lines',
#  'axis',
#  'automatized',
#  'shorten',
#  'coder',
#  'tlenecks',
#  'ridge',
#  'tion',
#  'mesh',
#  'nonexact',
#  'neurological',
#  'aeronautical',
#  'tactile',
#  'parked',
#  'maximize',
#  'technologically',
#  'analyze',
#  'pervasiveness',
#  'delineates',
#  'Spider',
#  'expanses',
#  'Noisy',
#  'excite',
#  'illustrates',
#  'Laplace',
#  'microalgae',
#  'pleasant',
#  'vaccinated',
#  'subgraphs',
#  'freehand',
#  'threads',
#  'Progress',
#  'intercept',
#  'Empirically',
#  'multiple',
#  'severity',
#  'pods',
#  'batteries',
#  'applicants',
#  'endurance',
#  'arrangement',
#  'reissue',
#  'overcoming',
#  'complete',
#  'Hand',
#  'anchoring',
#  'continuity',
#  'interfere',
#  'bitrates',
#  'wishing',
#  'thermal',
#  'cause',
#  'highest',
#  'wisdom',
#  'deceived',
#  'picks',
#  'compiles',
#  'club',
#  'groups',
#  'ubiquity',
#  'differing',
#  'midst',
#  'idiosyncracies',
#  'dispersed',
#  'outsole',
#  'elaborations',
#  'dependable',
#  'convergent',
#  'censored',
#  'instance',
#  'facie',
#  'patrolling',
#  'arbitrage',
#  'record',
#  'fetching',
#  'provably',
#  'forte',
#  'Polynomial',
#  'mixture',
#  'stadium',
#  'advances',
#  'outright',
#  'interneuron',
#  'generalizable',
#  'deficient',
#  'crowdedness',
#  'der',
#  'Robot',
#  'sung',
#  'billion',
#  'recognize',
#  'proof',
#  'adviser',
#  'intermittent',
#  'Procedures',
#  'factoring',
#  'reviewing',
#  'microworlds',
#  'textbook',
#  'certain',
#  'considers',
#  'polygonal',
#  'associations',
#  'overclose',
#  'catering',
#  'inseparable',
#  'perpetrated',
#  'dealing',
#  'oceanic',
#  'extent',
#  'tomograms',
#  'stitching',
#  'stellar',
#  'omnicrawler',
#  'treebank',
#  'counterexample',
#  'edition',
#  'Interval',
#  'neonates',
#  'syntaxes',
#  'nor',
#  'Another',
#  'security',
#  'intends',
#  'apertures',
#  'relevancy',
#  'batteryoperated',
#  'touted',
#  'conductance',
#  'monetise',
#  'forecasted',
#  'stigmergic',
#  'staticdynamic',
#  'complement',
#  'temporoparietal',
#  'Atomic',
#  'alternatively',
#  'utilizations',
#  'measuring',
#  'assertions',
#  'systematic',
#  'transliteration',
#  'morphable',
#  'dead',
#  'compressive',
#  'Vulnerability',
#  'raga',
#  'spaghetti',
#  'sitesgooglecomviewnipsintentiongan',
#  'cochlear',
#  'homogeneous',
#  'fluxes',
#  'Achieving',
#  'allocate',
#  'communicates',
#  'trainees',
#  'logdet',
#  'biomarkers',
#  'subtyping',
#  'Heavy',
#  'enforcement',
#  'deduced',
#  'memorability',
#  'Layout',
#  'craniomaxillofacial',
#  'Covering',
#  'conjointly',
#  'Simulators',
#  'irrigation',
#  'fragment',
#  'universality',
#  'quote',
#  'served',
#  'outlined',
#  'password',
#  'Coherent',
#  'cone',
#  'prevalent',
#  'web',
#  'secondly',
#  'Ensemble',
#  'Striving',
#  'aspects',
#  'unruled',
#  'sessionscompared',
#  'perturbs',
#  'communicated',
#  'underlining',
#  'insensitive',
#  'multisensory',
#  'meaning',
#  'drills',
#  'bind',
#  'cleartext',
#  'flexible',
#  'leaps',
#  'Nearly',
#  'dress',
#  'payments',
#  'hopcounts',
#  'semigroup',
#  'continue',
#  'microscopic',
#  'shaky',
#  'averse',
#  'Outcomes',
#  'appears',
#  'dappled',
#  'recovered',
#  'dub',
#  'incentive',
#  'undiscovered',
#  'foreground',
#  'artist',
#  'serving',
#  'ally',
#  'prosthetic',
#  'typing',
#  'dimensional',
#  'greedy',
#  'democratize',
#  'transcriptomics',
#  'Visualization',
#  'including',
#  'Bearing',
#  'artworks',
#  'pruned',
#  'refined',
#  'unipartite',
#  'valleys',
#  'Shifting',
#  'useof',
#  'undecided',
#  'dblp',
#  'bicyclists',
#  'representations',
#  'Prediction',
#  'topology',
#  'guess',
#  'Computing',
#  'principally',
#  'bioinformatic',
#  'encompassing',
#  'angles',
#  'inspect',
#  'row',
#  'Databases',
#  'transthoracic',
#  'fluents',
#  'lane',
#  'meetings',
#  'terminologies',
#  'votes',
#  'history',
#  'drain',
#  'Provisioning',
#  'socialize',
#  'typable',
#  'imagined',
#  'appreciated',
#  'radiomics',
#  'weakened',
#  'discovered',
#  '<cool-abr>',
#  'subfamilies',
#  'recorder',
#  'Later',
#  'itself',
#  'loopedmeshed',
#  'sensitivity',
#  'hero',
#  'downscaling',
#  'polyiamonds',
#  'pellet',
#  'Accelerated',
#  'sometime',
#  'palindromes',
#  'gateway',
#  'centralized',
#  'Power',
#  'controllability',
#  'encyclopedia',
#  'populace',
#  'examining',
#  'respective',
#  'compromises',
#  'assessments',
#  'intuitions',
#  'harder',
#  'multipleantenna',
#  'contextuality',
#  'collapsing',
#  'watertight',
#  'reactor',
#  'information',
#  'stairs',
#  'worldview',
#  'cybernetic',
#  'demise',
#  'third',
#  'homothety',
#  'habilitation',
#  'experimentalists',
#  'reorganized',
#  'spool',
#  'synonyms',
#  'infected',
#  'notes',
#  'biochemical',
#  'loseit',
#  'cohesive',
#  'hashtag',
#  'paraconsistency',
#  'primacy',
#  'coordination',
#  'rankings',
#  'crucially',
#  'wavelets',
#  'arriving',
#  'Without',
#  'hospitals',
#  'harmful',
#  'learners',
#  'entire',
#  'oxygen',
#  'unstable',
#  'recycle',
#  'Alternative',
#  'gensim',
#  'disturbing',
#  'Individuals',
#  'handoffs',
#  'Complexity',
#  'neck',
#  'perceived',
#  'Differential',
#  'forbidden',
#  'interleaves',
#  'fuzzy',
#  'disillusioning',
#  'catch',
#  'multibond',
#  'progresses',
#  'highlights',
#  'symplecticity',
#  'silicon',
#  'Associative',
#  'manners',
#  'annihilating',
#  'french',
#  'lazy',
#  'threaded',
#  'programming',
#  'spellcheckers',
#  'Smartphone',
#  'wrapping',
#  'redesigned',
#  'exhibits',
#  'foremost',
#  'leaves',
#  'iii',
#  'perceptron',
#  'slate',
#  'resentation',
#  'ofanarchy',
#  'streamsviews',
#  'endowed',
#  'Cylindrical',
#  'transcript',
#  'scattershot',
#  'understandable',
#  'testable',
#  'psycholinguistic',
#  'pole',
#  'pictogram',
#  'interlinked',
#  'detector',
#  'tail',
#  'realms',
#  'Variants',
#  'multispin',
#  'smooths',
#  'threats',
#  'verificationidentification',
#  'repulsive',
#  'unambiguously',
#  'enter',
#  'Could',
#  'meaningfulness',
#  'airstrikes',
#  'aggregate',
#  'inputoutputs',
#  'persistency',
#  'mosaic',
#  'equalizers',
#  'interpreting',
#  'deficiency',
#  'excitability',
#  'rival',
#  'pedestrians',
#  'regress',
#  'counted',
#  'wildcarding',
#  'reinforcements',
#  'discerns',
#  'apex',
#  'clocks',
#  'psychological',
#  'oral',
#  'confusion',
#  'discontinuity',
#  'interrelations',
#  'spheroid',
#  'walkability',
#  'wwwappliedmathgrouporg',
#  'kissing',
#  'deployment',
#  'taxonomic',
#  'television',
#  'steganalyzers',
#  'Opportunistic',
#  'transferring',
#  'node',
#  'recalling',
#  'relevant',
#  'philosophically',
#  'surging',
#  'disabled',
#  'dimensions',
#  'invert',
#  'inexpert',
#  'overfits',
#  'outset',
#  'records',
#  'judging',
#  'exoplanets',
#  'piezoscanner',
#  'demolishes',
#  'hypervectors',
#  'sticky',
#  'equal',
#  'trivalent',
#  'dubbed',
#  'stigmergy',
#  'firmer',
#  'parable',
#  'interface',
#  'misses',
#  'shipped',
#  'sign',
#  'bistatic',
#  'convergence',
#  'Phishing',
#  'reclaim',
#  'cfocl',
#  'takeoff',
#  'unboxing',
#  'cruising',
#  'clustered',
#  'indifferent',
#  'subtypes',
#  'vegetation',
#  'Business',
#  'differentiating',
#  'polyadic',
#  'overviewed',
#  'conventions',
#  'bibliographic',
#  'skulls',
#  'sixty',
#  ...}

# %%
len(words_pre)
# Out:
# 20497

# %%
'<pry>' in words_pre
# Out:
# True

# %% [markdown]
# pad: for padding
# unk: for word that didn't in our dicitonary

# %%
PAD_TOKEN = 0
UNK_TOKEN = 1
word_dict = {'<pad>':PAD_TOKEN,'<unk>':UNK_TOKEN}
for word in words_pre:
    word_dict[word]=len(word_dict)

# %%
import pickle
with open('other_data/dicitonary_words_pre_v8_first_word.pkl','wb') as f:
    pickle.dump(word_dict, f)

# %%
len(word_dict)
# Out:
# 20499

# %% [markdown]
# ### 資料格式化 (Data formatting)
# 有了字典後，接下來我們要把資料整理成一筆一筆，把input的句子轉成數字，把答案轉成onehot的形式。
# 這裡，我們一樣使用`multiprocessing`來加入進行。
# After building dictionary, that's mapping our sentences into number array, and convert answers to onehot format.

# %%
from tqdm import tqdm_notebook as tqdm
def label_to_onehot(labels):
    """ Convert label to onehot .
        Args:
            labels (string): sentence's labels.
        Return:
            outputs (onehot list): sentence's onehot label.
    """
    label_dict = {'BACKGROUND':0, 'OBJECTIVES':1, 'METHODS':2, 'RESULTS':3, 'CONCLUSIONS':4, 'OTHERS':5}
    onehot = [0,0,0,0,0,0]
    for l in labels.split('/'):
        onehot[label_dict[l]] = 1
    return onehot
        
def sentence_to_indices(sentence, word_dict):
    """ Convert sentence to its word indices.
    Args:
        sentence (str): One string.
    Return:
        indices (list of int): List of word indices.
    """
    # 這邊的字也要前處理~
    return [word_dict.get(word_preprocess(word), UNK_TOKEN) for word in word_tokenize(sentence)]
    
def get_dataset(data_path, word_dict, n_workers=4):
    """ Load data and return dataset for training and validating.

    Args:
        data_path (str): Path to the data.
    """
    dataset = pd.read_csv(data_path, dtype=str)

    results = [None] * n_workers
    with Pool(processes=n_workers) as pool:
        for i in range(n_workers):
            batch_start = (len(dataset) // n_workers) * i
            if i == n_workers - 1:
                batch_end = len(dataset)
            else:
                batch_end = (len(dataset) // n_workers) * (i + 1)
            
            batch = dataset[batch_start: batch_end]
            results[i] = pool.apply_async(preprocess_samples, args=(batch,word_dict))
        
        # 有with基本上不用這個
        pool.close()
        pool.join()

    processed = []
    for result in results:
        processed += result.get()
    return processed

def preprocess_samples(dataset, word_dict):
    """ Worker function.

    Args:
        dataset (list of dict)
    Returns:
        list of processed dict.
    """
    processed = []
    for sample in tqdm(dataset.iterrows(), total=len(dataset)):
        processed.append(preprocess_sample(sample[1], word_dict))

    return processed

def preprocess_sample(data, word_dict):
    """
    Args:
        data (dict)
    Returns:
        dict
    """
    processed = {}
    processed['Abstract'] = [sentence_to_indices(sent, word_dict) for sent in data['Abstract'].split('$$$')]
    if 'Task 1' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Task 1'].split(' ')]
    if 'Label' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Label'].split(' ')]
    
    return processed

# %%
print('[INFO] Start processing trainset...')
train = get_dataset('train_test_split_data/trainset.csv', word_dict, n_workers=4)
print('[INFO] Start processing validset...')
valid = get_dataset('train_test_split_data/validset.csv', word_dict, n_workers=4)

# private_testset
print('[INFO] Start processing private_testset...')
test = get_dataset('train_test_split_data/private_testset.csv', word_dict, n_workers=4)
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing private_testset...

# %% [markdown]
# #### Preprosses K-fold data

# %%
train_folds=[]
valid_folds=[]

for i in range(fold):
  print('[INFO] Start processing trainset...')
  train_folds.append(get_dataset("K_fold_data/" + "train_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
  print('[INFO] Start processing validset...')
  valid_folds.append(get_dataset("K_fold_data/" + "valid_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...

# %% [markdown]
# ## 資料封裝 (Data packing)

# %% [markdown]
# 為了更方便的進行batch training，我們將會借助[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)。
# 而要將資料放入dataloader，我們需要繼承[torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)，撰寫適合這份dataset的class。
# `collate_fn`用於batch data的後處理，在`dataloder`將選出的data放進list後會呼叫collate_fn，而我們會在此把sentence padding到同樣的長度，才能夠放入torch tensor (tensor必須為矩陣)。

# %% [markdown]
# To easily training in batch, we'll use `dataloader`, which is a function built in Pytorch[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)
# To use datalaoder, we need to packing our data into class `dataset` [torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)
# `collate_fn` is used for data processing.

# %%
from torch.utils.data import Dataset
import torch
class AbstractDataset(Dataset):
    def __init__(self, data, pad_idx, max_len = 500):
        self.data = data
        self.pad_idx = pad_idx
        self.max_len = max_len
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]
        
    def collate_fn(self, datas):
        # get max length in this batch
        max_sent = max([len(data['Abstract']) for data in datas])
        max_len = max([min(len(sentence), self.max_len) for data in datas for sentence in data['Abstract']])
        batch_abstract = []
        batch_label = []
        sent_len = []
        for data in datas:
            # padding abstract to make them in same length
            pad_abstract = []
            for sentence in data['Abstract']:
                if len(sentence) > max_len:
                    pad_abstract.append(sentence[:max_len])
                else:
                    pad_abstract.append(sentence+[self.pad_idx]*(max_len-len(sentence)))
            sent_len.append(len(pad_abstract))
            pad_abstract.extend([[self.pad_idx]*max_len]*(max_sent-len(pad_abstract)))
            batch_abstract.append(pad_abstract)
            # gather labels
            if 'Label' in data:
                pad_label = data['Label']
                pad_label.extend([[0]*6]*(max_sent-len(pad_label)))
                
                batch_label.append(pad_label)
        return torch.LongTensor(batch_abstract), torch.FloatTensor(batch_label), sent_len

# %%
# TODO: 改max_len
trainData = AbstractDataset(train, PAD_TOKEN, max_len=64)
validData = AbstractDataset(valid, PAD_TOKEN, max_len=64)
testData = AbstractDataset(test, PAD_TOKEN, max_len=64)

# %%
## 5 fold data

trainData_folds = []
validData_folds = []

for i in range(fold):
    trainData_folds.append(AbstractDataset(train_folds[i], PAD_TOKEN, max_len=64))
    validData_folds.append(AbstractDataset(valid_folds[i], PAD_TOKEN, max_len=64))

# %% [markdown]
# # Model

# %% [markdown]
# 資料處理完成後，接下來就是最重要的核心部分：`Model`。
# 此次範例中我們以簡單的一層RNN + 兩層Linear layer作為示範。
# 而為了解決每次的句子長度不一的問題(`linear layer必須是fixed input size`)，因此我們把所有字的hidden_state做平均，讓這一個vector代表這句話。

# %% [markdown]
# In this tutorial, we're going to implement a simple model, which contain one RNN layer and two fully connected layers (Linear layer). Of course you can make it "deep".
# To solve variant sentence length problem (`input size in linear layer must be fixed`), we can average all hidden_states, and become one vector. (Perfect!)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class simpleNet(nn.Module):
    def __init__(self, vocabulary_size):
        super(simpleNet, self).__init__()
        self.embedding_size = 200  # 改embedding
        self.hidden_dim = 512
        self.embedding = nn.Embedding(vocabulary_size, self.embedding_size)
        
        self.sent_lstm = nn.LSTM(self.embedding_size,
                                 self.hidden_dim,
                                 num_layers=1,
                                 bidirectional=True,
                                 batch_first=True,
                                 # dropout=0.5
                                 )
        self.sent_gru = nn.GRU(self.hidden_dim * 2,
                               self.hidden_dim,
                               num_layers=1,
                               bidirectional=True,
                               batch_first=True,
                               # dropout=0.2
                              )
        # 加上LSTM & dropout試試看 & batch norm
        self.batch_norm = nn.BatchNorm1d(self.hidden_dim, momentum=0.5)
        self.l1 = nn.Linear(self.hidden_dim * 2, self.hidden_dim)
        self.l2 = nn.Linear(self.hidden_dim, 6)
        self.dropout = nn.Dropout(0.5)

        # orthogonal initialization
        # for weight in self.sent_lstm.parameters():
        #     if len(weight.size()) > 1:
        #         # print(123)
        #         nn.init.orthogonal_(weight.data)

        # for weight in self.sent_gru.parameters():
        #     if len(weight.size()) > 1:
        #         # print(456)
        #         nn.init.orthogonal_(weight.data)
        
        # # bias initialization
        # for names in self.sent_lstm._all_weights:
        #     for name in filter(lambda n: "bias" in n,  names):
        #         bias = getattr(self.sent_lstm, name)
        #         n = bias.size(0)
        #         start, end = n//4, n//2
        #         bias.data[start:end].fill_(0.)

        # for names in self.sent_gru._all_weights:
        #     for name in filter(lambda n: "bias" in n,  names):
        #         bias = getattr(self.sent_gru, name)
        #         n = bias.size(0)
        #         start, end = n//4, n//2
        #         bias.data[start:end].fill_(0.)

    def forward(self, x):
        x = self.embedding(x)
        # https://discuss.pytorch.org/t/spatial-dropout-in-pytorch/21400
        # https://pytorch.org/docs/stable/nn.html#dropout2d
        # Spatial Dropout after embedding layer
        # x = F.dropout2d(x.permute(0, 2, 1, 3), 0.5).permute(0, 2, 1, 3)
        batch_size, sent_len, word_dim, embed_dim = x.shape
        x = x.view(batch_size, sent_len * word_dim, embed_dim)  # batch, time, features
        x, __ = self.sent_lstm(x)
        # x, __ = self.sent_lstm2(x)
        x, __ = self.sent_gru(x)
        x = x.view(batch_size, sent_len, word_dim, -1)
        x = torch.max(x, dim=2)[0]  # 選整句最大值
        # x = torch.mean(x, dim=2, keepdim=True).squeeze()  # 改成平均
        x = torch.relu(self.l1(x))
        # x = x.permute(0, 2, 1)
        # x = self.batch_norm(x)  # 加一個channel維度?
        # x = x.permute(0, 2, 1)
        # x = self.dropout(x)
        x = torch.sigmoid(self.l2(x))
        return x

# %% [markdown]
# # Training

# %% [markdown]
# 指定使用的運算裝置
# Designate running device.

# %%
import torch

device='cuda' #'cuda'
SEED = 42
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# 定義一個算分公式, 讓我們在training能快速了解model的效能
# Define score function, let us easily observe model performance while training.

# %%
class F1():
    def __init__(self):
        self.threshold = 0.5
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0
        self.name = 'F1'

    def reset(self):
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0

    def update(self, predicts, groundTruth):
        predicts = predicts > self.threshold
        self.n_precision += torch.sum(predicts).data.item()
        self.n_recall += torch.sum(groundTruth).data.item()
        self.n_corrects += torch.sum(groundTruth.type(torch.uint8) * predicts).data.item()

    def get_score(self):
        recall = self.n_corrects / self.n_recall
        precision = self.n_corrects / (self.n_precision + 1e-20) #prevent divided by zero
        return 2 * (recall * precision) / (recall + precision + 1e-20)

    def print_score(self):
        score = self.get_score()
        return '{:.5f}'.format(score)

# %%
import os
import sys

def _run_epoch(data, epoch, training):
    model.train(training)
    if training:
        description = 'Train'
        # dataset = trainData
        dataset = data
        shuffle = True
    else:
        description = 'Valid'
        # dataset = validData
        dataset = data
        shuffle = False
    dataloader = DataLoader(dataset=dataset,
                            batch_size=64,
                            shuffle=shuffle,
                            collate_fn=dataset.collate_fn,
                            num_workers=4)

    trange = tqdm(enumerate(dataloader), total=len(dataloader), desc=description)
    loss = 0
    f1_score = F1()
    for i, (x, y, sent_len) in trange:
        o_labels, batch_loss = _run_iter(x,y)
        if training:
            opt.zero_grad()
            batch_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
            opt.step()

        loss += batch_loss.item()
        f1_score.update(o_labels.cpu(), y)

        trange.set_postfix(
            loss=loss / (i + 1), f1=f1_score.print_score())
    if training:
        history['train'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})
    else:
        history['valid'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})

def _run_iter(x, y):
    abstract = x.to(device)
    labels = y.to(device)
    # o_labels = model(abstract)
    o_labels = model(abstract)
    l_loss = criteria(o_labels, labels)
    return o_labels, l_loss

def save(epoch, name, cv=False):
    if not os.path.exists('model'):
        os.makedirs('model')
    if not os.path.exists('model/cv'):
        os.makedirs('model/cv')
    if cv:
      torch.save(model.state_dict(), 'model/cv/model_cv_' + name + '.pkl.'+str(epoch))
      with open('model/cv/history_cv_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)
    else:
      torch.save(model.state_dict(), 'model/model_' + name + '.pkl.'+str(epoch))
      with open('model/history_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)

# %% [markdown]
# ## Run Model

# %% [markdown]
# #### 這邊直接run cv mode即可! -> 每次的model_name要調整喔

# %%
model_name = "PRIVATE5_LSTM_GRU_WORD_PRE_v8(20449_words)_deterministic"

# %%
from torch.utils.data import DataLoader
from tqdm import trange
import json

torch.cuda.set_device(0)

mode = "cv" #cv, train

vaild_f1 = 0

if mode == "cv":
  overall_F1 = []
  for i in range(fold):
    model = simpleNet(len(word_dict))
    # opt = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.5)
    opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
    criteria = torch.nn.BCELoss() 
    model.to(device)
    max_epoch = 5
    history = {'train' : [], 'valid' : []}

    for epoch in range(max_epoch):
        print('CV_' + str(i) + ',', 'Epoch: {}'.format(epoch))
        _run_epoch(trainData_folds[i], epoch, True)
        _run_epoch(validData_folds[i], epoch, False)
        
        save(epoch, model_name + "_" + str(i), cv=True)

        print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

        if epoch > 1:
            overall_F1.append(np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

  print("Final average validation F1 score:", np.mean(overall_F1))
    
else:
  model = simpleNet(len(word_dict))
  opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
  criteria = torch.nn.BCELoss()
  model.to(device)
  max_epoch = 5
  history = {'train' : [], 'valid' : []}

  for epoch in range(max_epoch):
      print('Epoch: {}'.format(epoch))
      _run_epoch(trainData, epoch, True)
      _run_epoch(validData, epoch, False)
      save(epoch, model_name, cv=False)

      print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))
# Out:
# CV_0, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6065722037986132
# CV_0, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6344157927412277
# CV_0, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6674552444026631
# CV_0, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6729572574989966
# CV_0, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.674585628186595
# CV_1, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6006451612903226
# CV_1, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6180101681142107
# CV_1, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.658655265438512
# CV_1, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6783959329286812
# CV_1, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6736595529778195
# CV_2, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.597478176527643
# CV_2, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6286967197611864
# CV_2, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6662616675555497
# CV_2, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6747039538973549
# CV_2, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6732482529839187
# CV_3, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6030097498940229
# CV_3, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6284338478647427
# CV_3, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6548402866350955
# CV_3, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6623775272319584
# CV_3, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.671103802729503
# CV_4, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5806589644843816
# CV_4, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.617754298015941
# CV_4, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6583679489278185
# CV_4, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6644413034636322
# CV_4, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6638863366949506
# CV_5, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5859366375979689
# CV_5, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6127512282381671
# CV_5, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6493652289850058
# CV_5, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6677514040880943
# CV_5, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6785361470606733
# CV_6, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5727623300182666
# CV_6, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6120174540074912
# CV_6, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6515369806469591
# CV_6, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6495756761814946
# CV_6, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6559128094507303
# CV_7, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5872204472843451
# CV_7, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6200481651154319
# CV_7, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6585201224294032
# CV_7, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6670816811060989
# CV_7, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6770840625884997
# CV_8, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5780645161290323
# CV_8, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6105726462924435
# CV_8, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6562255752906871
# CV_8, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6677164055924678
# CV_8, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.674508935496088
# CV_9, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5813127090301005
# CV_9, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6134462168179837
# CV_9, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6468378539565589
# CV_9, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.658247731731602
# CV_9, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6618018278888456
# Final average validation F1 score: 0.6645214134682086

# %%
# model = simpleNet(len(word_dict))
# model.to(device)
# model.load_state_dict(torch.load('model/cv/model_cv_LSTM_GRU_ortho_bias0(word_pre_24971_words)_10Kfold_0.pkl.2'))

# %%
import numpy as np
def SubmitGenerator(prediction, sampleFile, public=True, filename='prediction.csv'):
    sample = pd.read_csv(sampleFile)
    submit = {}
    submit['order_id'] = list(sample.order_id.values)
    redundant = len(sample) - prediction.shape[0]
    if public:
        submit['BACKGROUND'] = list(prediction[:,0]) + [0]*redundant
        submit['OBJECTIVES'] = list(prediction[:,1]) + [0]*redundant
        submit['METHODS'] = list(prediction[:,2]) + [0]*redundant
        submit['RESULTS'] = list(prediction[:,3]) + [0]*redundant
        submit['CONCLUSIONS'] = list(prediction[:,4]) + [0]*redundant
        submit['OTHERS'] = list(prediction[:,5]) + [0]*redundant
    else:
        submit['BACKGROUND'] = [0]*redundant + list(prediction[:,0])
        submit['OBJECTIVES'] = [0]*redundant + list(prediction[:,1])
        submit['METHODS'] = [0]*redundant + list(prediction[:,2])
        submit['RESULTS'] = [0]*redundant + list(prediction[:,3])
        submit['CONCLUSIONS'] = [0]*redundant + list(prediction[:,4])
        submit['OTHERS'] = [0]*redundant + list(prediction[:,5])
    df = pd.DataFrame.from_dict(submit) 
    df.to_csv(filename,index=False)

# %%
os.getcwd()
# Out:
# '/content/Drive/My Drive/labeling_cowork_folder'

# %% [markdown]
# ## 把cv模型load出來predict平均 (config, 基本上前面都run過這裡應該不用run了)

# %%
device='cuda'
fold = 10
model = simpleNet(len(word_dict))
opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
criteria = torch.nn.BCELoss() 
model.to(device)
max_epoch = 5

# %% [markdown]
# ### Apply simple CV emsembling based on validation scores
# ### 記得prediction_sum的維度要改成:
# **(len(task1_sample_submission.csv)-131166, 6)**

# %%
from torch.utils.data import DataLoader

def softmax(x):
    exp_x = np.exp(x)
    softmax_x = exp_x / np.sum(exp_x)
    return softmax_x 

prediction_sum = (131782, 6)  # --> 這邊要改
n_digits = 3
model_nums = 0

# 先讀取cv中每個模型所記錄的validation分數 (取出epoch 3 & 4 -> strated from 0)
# it will be ordered as cv_0_epoch_3 cv_0_epoch_4 ...
valid_scores = {}
for i in range(fold):
    score = pd.read_json("model/cv/history_cv_" + model_name + "_" + str(i) + ".json")
    valid_scores[str(i) + "_3"] = score["valid"].iloc[3]["f1"]
    valid_scores[str(i) + "_4"] = score["valid"].iloc[4]["f1"]

# 利用softmax算出每個模型佔的權重並塞進字典
model_weights_values = softmax(list(valid_scores.values()))
model_ensembling_weights_dict = {key:value for key, value in zip(valid_scores.keys(), model_weights_values)}


for cv in range(fold):
    for ep in range(max_epoch):
        if (ep == 3) or (ep == 4): # 只取epoch 3 & 4 的模型 (started from 0)
            dataloader = DataLoader(dataset=testData,
                                  batch_size=64,
                                  shuffle=False,  # for sent len不要亂
                                  collate_fn=testData.collate_fn,
                                  num_workers=4)
            trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')
            model = simpleNet(len(word_dict))
            model.to(device)
            model.load_state_dict(torch.load('model/cv/model_cv_' + model_name + '_' + str(cv) + '.pkl.' + str(ep) + ''))
            model.train(False)
            prediction = []
            for i, (x, y, sent_len) in trange:
                with torch.no_grad(): # 避免記憶體爆掉，先將grad都設為false
                    o_labels = model(x.to(device))
                    o_labels = (o_labels * 10 ** n_digits).round() / (10 ** n_digits)
                    # o_labels = o_labels.to('cpu')
                    # o_labels = o_labels > 0.4
                    for idx, o_label in enumerate(o_labels):
                        prediction.append(o_label[:sent_len[idx]].to('cpu'))
            prediction = torch.cat(prediction).detach().numpy() # .astype(int)
            
            # 在這裡直接乘上權重
            prediction_sum += prediction * model_ensembling_weights_dict[str(cv) + "_" + str(ep)]
            model_nums += 1

final_prediction = prediction_sum # / model_nums
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-265f4b7774dc> in <module>()
#      48
#      49             # 在這裡直接乘上權重
# ---> 50             prediction_sum += prediction * model_ensembling_weights_dict[str(cv) + "_" + str(ep)]
#      51             model_nums += 1
#      52
#
# ValueError: operands could not be broadcast together with shapes (2,) (131782,6)

# %%
SubmitGenerator(final_prediction,
                'raw_data/task1_sample_submission.csv', 
                False,  # private set 就改false即可
                # 下面名字取private submission以供辨認
                'submission/private_submission(reproduce_test_seed42)_16_LSTM_GRU(word_pre_20449_words)_10Kfold_cv_avg_origin_prob.csv')

# %% [markdown]
# # 跑到這裡即可 -------------- end ---------------------

# %% [markdown]
# ## Predict (not cv mode)

# %%
from torch.utils.data import DataLoader
model.train(False)
dataloader = DataLoader(dataset=testData,
                            batch_size=64,
                            shuffle=False,  # for sent len不要亂
                            collate_fn=testData.collate_fn,
                            num_workers=4)
trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')
prediction = []
for i, (x, y, sent_len) in trange:
    o_labels = model(x.to(device))
    o_labels = o_labels > 0.4
    for idx, o_label in enumerate(o_labels):
        prediction.append(o_label[:sent_len[idx]].to('cpu'))
prediction = torch.cat(prediction).detach().numpy().astype(int)
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…

# %% [markdown]
# # Plot Learning Curve

# %%
import matplotlib.pyplot as plt
import json
# %matplotlib inline

with open('model/history_train.json', 'r') as f:
    history = json.loads(f.read())
    
train_loss = [l['loss'] for l in history['train']]
valid_loss = [l['loss'] for l in history['valid']]
train_f1 = [l['f1'] for l in history['train']]
valid_f1 = [l['f1'] for l in history['valid']]

plt.figure(figsize=(7,5))
plt.title('Loss')
plt.plot(train_loss, label='train')
plt.plot(valid_loss, label='valid')
plt.legend()
plt.show()

plt.figure(figsize=(7,5))
plt.title('F1 Score')
plt.plot(train_f1, label='train')
plt.plot(valid_f1, label='valid')
plt.legend()
plt.show()

print('Best F1 score ', max([[l['f1'], idx] for idx, l in enumerate(history['valid'])]))
# Out:
# Best F1 score  [0.6734478456961903, 4]
