# %% [markdown]
# ## Key inputs for this script
# #### 1.   cv emsembling based on validation score
# #### 2.   Word preprocessing
#     *   判斷字是否為公司名稱
#     *   移除純數字的字
#     *   如果字中有dash，判斷是數字還是縮寫
#     *   字的第一個char如果是大寫且不是句首字，判斷為專有名詞
#     *   移除標點符號
#     *   詞性還原
# #### 3.   psuedo labeling training
#     *   將預測出來的test label當作GT加入訓練
# #### 4.   Modeling
#     *   LSTM * 1 + GRU * 1 (hidden 512, bi-dir) + torch max
#     *   max_len = 64
#     *   default Adam
#     *   gradient norm clipping = 1
#
# ####

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Drive already mounted at /content/Drive; to attempt to forcibly remount, call drive.mount("/content/Drive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from itertools import product

# os.chdir('/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder')
os.chdir('/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder')
os.getcwd()
# Out:
# '/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder'

# %% [markdown]
# # Runtime Environment
# * python >= 3.6
# * pytorch >= 1.0
# * pandas
# * nltk
# * numpy
# * sklearn
# * pickle
# * tqdm
# * json

# %% [markdown]
# # Data processing

# %% [markdown]
# ## 刪除多於資訊 (Remove redundant information)
# 我們在資料集中保留了許多額外資訊供大家使用，但是在這次的教學中我們並沒有用到全部資訊，因此先將多餘的部分先抽走。
# In dataset, we reserved lots of information. But in this tutorial, we don't need them, so we need to discard them.

# %%
import pandas as pd

dataset = pd.read_csv('raw_data/task1_trainset.csv', dtype=str)
dataset.head()
# Out:
#        Id  ...                                             Task 1
# 0  D00001  ...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1  D00002  ...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2  D00003  ...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3  D00004  ...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4  D00005  ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
#
# [5 rows x 7 columns]

# %%
# 句子有一些換行沒處理好
dataset["Abstract"] = dataset["Abstract"].str.replace("- ", "")

dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)

# %% [markdown]
# ## 資料切割  (Partition)
# 在訓練時，我們需要有個方法去檢驗訓練結果的好壞，因此需要將訓練資料切成training/validataion set。
#
# **- Need 5-fold cv to validate training result**

# %%
from sklearn.model_selection import StratifiedKFold, KFold

trainset_folds = []
trainset_folds = []

valset_folds = []
valset_folds = []

tmp_train = {}
tmp_val = {}

X = dataset["Abstract"]
y = dataset["Task 1"]

# 用GROUP K-FOLD分類別? 先改用K-Fold

K_folder = KFold(n_splits=10, random_state=42, shuffle=False)
for i, (train_index, val_index) in enumerate(K_folder.split(X, y)):

    tmp_train['Abstract'] = X[train_index]
    tmp_train['Label'] = y[train_index]

    tmp_val['Abstract'] = X[val_index]
    tmp_val['Label'] = y[val_index]

    # 有一個split會反過來 (Stratified K-Fold)
    # if i == 0:
    #   continue

    trainset_folds.append(pd.DataFrame(data=tmp_train))
    valset_folds.append(pd.DataFrame(data=tmp_val))

    # print("Stratified Train Index:", train_index)
    # print("Stratified Test Index:", test_index)
    # print("Stratified y_train:", y[train_index])
    # print("Stratified y_test:", y[test_index],'\n')

# train_test_split(dataset, test_size=0.2, random_state=42)

# %%
trainset_folds[9]
# Out:
#                                                Abstract                                              Label
# 0     Rapid popularity of Internet of Things (IoT) a...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1     In this paper, we address the problem of compu...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2     High quality upsampling of sparse 3D point clo...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3     Internet is the main source of information now...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4     Automated Facial Expression Recognition (FER) ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
# ...                                                 ...                                                ...
# 6295  Activity detection is a fundamental problem in...  BACKGROUND BACKGROUND OBJECTIVES METHODS METHO...
# 6296  We address the problem of using hand-drawn ske...  BACKGROUND/OBJECTIVES METHODS METHODS METHODS ...
# 6297  This article extends the Generalized Asypmtoti...                         OBJECTIVES METHODS RESULTS
# 6298  We consider generation and comprehension of na...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 6299  The task of classifying videos of natural dyna...  BACKGROUND BACKGROUND OBJECTIVES METHODS CONCL...
#
# [6300 rows x 2 columns]

# %%
def save_k_fold_data(data, name="train_data_fold", fold=10):
  """
  X_data: list of DF
  y_data: list of DF
  """
  for i in range(fold):
    data[i].to_csv("K_fold_data/" + name + "_" + str(i) + ".csv", index=None)
fold=10
# save_k_fold_data(data=trainset_folds, name="train_data_fold", fold=fold)
# save_k_fold_data(data=valset_folds, name="valid_data_fold", fold=fold)

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
trainset, validset = train_test_split(dataset, test_size=0.1, random_state=42)

# trainset.to_csv('train_test_split_data/trainset.csv',index=False)
# validset.to_csv('train_test_split_data/validset.csv',index=False)

# %% [markdown]
# ### For test data (在這裡替換private set的testing data路徑!)

# %%
dataset = pd.read_csv('raw_data/task1_private_testset.csv', dtype=str)  ## -> 路徑在這裡替換

dataset["Abstract"] = dataset["Abstract"].str.replace("- ", "")
dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)
dataset.to_csv('train_test_split_data/private_testset.csv',index=False)

# %% [markdown]
# ### 統計單字 (Count words)
# 在訓練時，不能直接將單字直接餵入model，因為它只看得懂數字，因此我們必須把所有的單字抽取出來，並將它們打上編號，做出一個字典來對它們做轉換。
# We can't feed "word" into model directly, since it can only recognize number. So, we need to know the total number of word, and give every word a unique number.

# %% [markdown]
# 在這裡，我們需要借助`nltk`這個library來幫忙做文字切割。當然，你也可以選擇自己寫規則來切割(通常上不建議搞死自己)。
# 另外，我們也使用了`multiprocessing`來加速處理。
# In here, we split words by using `nltk library`. You can write your own rules and split it by yourself, but you won't want to do that, trust me.
# Also, we use `multiprocessing` to accelerate the process.

# %%
import pandas as pd
from multiprocessing import Pool
from nltk.tokenize import word_tokenize

def tokenize_by_space(sentence):
    return sentence.split(' ')

def collect_words(data_path=None, n_workers=4, dataset=None):
    if dataset is None:
      df = pd.read_csv(data_path, dtype=str)
    else:
      df = dataset
      
        
    sent_list = []
    for i in df.iterrows():
        sent_list += i[1]['Abstract'].split('$$$')

    chunks = [
        ' '.join(sent_list[i:i + len(sent_list) // n_workers])
        for i in range(0, len(sent_list), len(sent_list) // n_workers)
    ]
    with Pool(n_workers) as pool:
        chunks = pool.map_async(word_tokenize, chunks)
        # chunks = pool.map_async(tokenize_by_space, chunks)
        words = set(sum(chunks.get(), []))

    return words

def get_first_word(sentence_list):
    return [sent.split(" ")[0] for sent in sentence_list]

def collect_sentence_first_words(data_path=None, n_workers=4, dataset=None):
    if dataset is None:
      df = pd.read_csv(data_path, dtype=str)
    else:
      df = dataset
    
    first_words = []
    for i in df.iterrows():
        first_words.extend(get_first_word(i[1]['Abstract'].split('$$$')))

    return first_words
  
def get_proprietary(word_list):
    p = []
    for word in word_list:
        if np.sum([w.isupper() for w in word]) >= 2:
            p.append(word)
    return p

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
words = set()
# testset_w = pd.read_csv("train_test_split_data/testset.csv", index_col=None)
# trainset_w = pd.read_csv("train_test_split_data/trainset.csv", index_col=None)
# all_data = pd.concat([trainset_w, testset_w])
words |= collect_words('raw_data/task1_trainset.csv')
# words |= collect_words(dataset=all_data)

# %%
from collections import Counter

first_word_list_train = collect_sentence_first_words("raw_data/task1_trainset.csv")
first_word_list_test = collect_sentence_first_words('raw_data/task1_public_testset.csv')

# 如果詞出現頻率大於1、大寫數目小於2、沒有dash在裡面，才認為是普通的句首字
first_word_list = first_word_list_train + first_word_list_test
first_words_dict = dict(Counter(first_word_list))

first_words = [word for word, freq in first_words_dict.items() if (freq > 1) and 
               (np.sum([w.isupper() for w in word]) < 2) and 
               ('-' not in word)]

# %%
first_words
# Out:
# ['Rapid',
#  'To',
#  'This',
#  'The',
#  'In',
#  'With',
#  'Given',
#  'We',
#  'High',
#  'Our',
#  'Finally,',
#  'Results',
#  'Internet',
#  'These',
#  'That',
#  'There',
#  'Therefore,',
#  'Automated',
#  'Many',
#  'Recently',
#  'Experiments',
#  'It',
#  'Through',
#  'Existing',
#  'Such',
#  'Deep',
#  'Subjective',
#  'Offline',
#  'They',
#  'How',
#  'A',
#  'Any',
#  'Mobile',
#  'Hence,',
#  'Specifically,',
#  'Based',
#  'Inspired',
#  'Though',
#  'Scene',
#  'Combined',
#  'Moreover,',
#  'Generative',
#  'Network',
#  'Numerical',
#  'Dimensionality',
#  'By',
#  'Comparisons',
#  'As',
#  'Successful',
#  'Meanwhile,',
#  'Representation',
#  'However,',
#  'Further,',
#  'For',
#  'Publishing',
#  'Centrality',
#  'Even',
#  'Reconstruction',
#  'Recurrent',
#  'Thus,',
#  'One',
#  'Note',
#  'Combining',
#  'Software',
#  'But,',
#  'Although',
#  'Static',
#  'First,',
#  'Second,',
#  'Third,',
#  'While',
#  'Unfortunately,',
#  'More',
#  'Then,',
#  'On',
#  'Yet',
#  'Indeed,',
#  'If',
#  'Modern',
#  'Spatial',
#  'Recently,',
#  'Few',
#  'Application',
#  'Built',
#  'At',
#  'Several',
#  'Thus',
#  'Power',
#  'Policy',
#  'Relations',
#  'Hence',
#  'Countries',
#  'Furthermore,',
#  'Behavior',
#  'Comparison',
#  'Other',
#  'Both',
#  'Metrics',
#  'Identifying',
#  'Despite',
#  'Efforts',
#  'Experimentally,',
#  'Translating',
#  'Being',
#  'Distribution',
#  'Current',
#  'Analyzing',
#  'When',
#  'Traditionally,',
#  'Each',
#  'Social',
#  'Using',
#  'Thereby,',
#  'An',
#  'Following',
#  'Two',
#  'Convolutional',
#  "'s",
#  'Whether',
#  'Motivated',
#  'Computational',
#  'Acute',
#  'Smart',
#  'Artificial',
#  'Regularizing',
#  'Solar',
#  'Robotic',
#  'Also,',
#  'Feedback',
#  'Firstly,',
#  'Secondly,',
#  'Objects',
#  'Strategies',
#  'Due',
#  'First',
#  'Among',
#  'Previous',
#  'Factorization',
#  'Regarding',
#  'Experimental',
#  'Information',
#  'Most',
#  'Sparse',
#  'However',
#  'Furthermore',
#  'Thanks',
#  'Unlike',
#  'Machine',
#  'Architectures',
#  'During',
#  'Since',
#  'Relaxing',
#  'Here,',
#  'Geometric',
#  'Models',
#  'Secure',
#  'Along',
#  'Interesting',
#  'Objective:',
#  'Main',
#  'Conclusion:',
#  'Going',
#  'Crowdsourcing',
#  'Empirical',
#  'Extreme',
#  'Compared',
#  'Additionally,',
#  'Connection',
#  'Cooperative',
#  'Computer',
#  'But',
#  'So',
#  'Optical',
#  'Conventionally,',
#  'Considering',
#  'Simulation',
#  'Research',
#  'Context:',
#  'Method:',
#  'Results:',
#  'Fortunately,',
#  'Evolution',
#  'Integrating',
#  'Conventional',
#  'Less',
#  'Simulations',
#  'Increasing',
#  'Some',
#  'Neural',
#  'Gaussian,',
#  'Leveraging',
#  'Convergence',
#  'Surprisingly,',
#  'Also',
#  'Consequently,',
#  'From',
#  'Acoustic',
#  'Further',
#  'Noise',
#  'Rather',
#  'Users',
#  'And',
#  'Supervised',
#  'Without',
#  'Zooming',
#  'Localized',
#  'Understanding',
#  'Image',
#  'Algorithms',
#  'Three',
#  'Determining',
#  'Fundamental',
#  'Density',
#  'Motivation:',
#  'Additional',
#  'Availability:',
#  'Traditional',
#  'Physical',
#  'Taking',
#  'Boolean',
#  'Robustness',
#  'Word',
#  'Instead,',
#  'Explaining',
#  'Various',
#  'Four',
#  'System',
#  'Intuitively',
#  'Autonomous',
#  'Standard',
#  'Generalized',
#  'Advanced',
#  'Chemical',
#  'Their',
#  'Code',
#  'Business',
#  'Under',
#  'Learning',
#  'Clinical',
#  'Recent',
#  'Excessive',
#  'Over',
#  '(2)',
#  '(3)',
#  '(4)',
#  '(5)',
#  'Similarly,',
#  'According',
#  'Ranking',
#  'Citations',
#  'Until',
#  'Thompson',
#  'Thirdly,',
#  'Recognizing',
#  'Here',
#  'Collective',
#  'Massive',
#  'Generally,',
#  'All',
#  'Efficiency',
#  'Benefit',
#  'Fuzzy',
#  'Different',
#  'And,',
#  'Because',
#  'Inference',
#  'Multiple',
#  'Computation',
#  'Nevertheless,',
#  'Classifying',
#  'Abstract',
#  'Adversarial',
#  'Instead',
#  'Extensive',
#  'Rate',
#  'Grid',
#  'Chord',
#  'Plenty',
#  'Binary',
#  'Another',
#  'Besides,',
#  'Lastly,',
#  'Building',
#  'After',
#  'Besides',
#  'Then',
#  'Discriminative',
#  'Spatially',
#  'Personal',
#  'Finding',
#  'Together',
#  'Distant',
#  'Surrogate',
#  'Optimal',
#  'Dealing',
#  'Assuming',
#  'Foreground',
#  'Numerous',
#  'Not',
#  'Quality',
#  'Simple',
#  'Genetic',
#  'Majority',
#  'Often',
#  'Super',
#  'Resulting',
#  'Deliberate',
#  'Conversely,',
#  'Estimating',
#  'Wireless',
#  'Clustering',
#  'Cluster',
#  'Optimized',
#  'Effective',
#  'Visualization',
#  'Yet,',
#  'Subsequently,',
#  'Hashing',
#  'Low',
#  'Level',
#  'Simplified',
#  'Monocular',
#  'Synthetic',
#  'Utilizing',
#  'Training',
#  'Weakly',
#  'Rigid',
#  'Integrated',
#  'Comprehensive',
#  'No',
#  'Parallel',
#  'Vulnerability',
#  'Subjects',
#  'Driven',
#  'Approaches',
#  'Applied',
#  'Spoken',
#  'Methods',
#  'Search',
#  'Achieving',
#  'Bearing',
#  'Quantitative',
#  'Namely,',
#  'Qualitative',
#  'Combination',
#  'Higher',
#  'Finally',
#  'Glaucoma',
#  'Estimation',
#  'Speech',
#  'Especially,',
#  'Validated',
#  'Technological',
#  'Differently',
#  'Big',
#  'Examples',
#  'Classification',
#  'Label',
#  'Grounding',
#  'Lossless',
#  'Practical',
#  'Would',
#  'Experts',
#  'Compressed',
#  'Forming',
#  'Type',
#  'Formal',
#  'Analysis',
#  'Industrial',
#  'Once',
#  'Knowledge',
#  'Nowadays',
#  'Questions',
#  'in',
#  'gave',
#  'Monte',
#  'Online',
#  'Scheduling',
#  'Eliminating',
#  'Sentiment',
#  'Control',
#  'Effectively,',
#  'Soon',
#  'Sequential',
#  'Markov',
#  'Generally',
#  'Visualizations',
#  'Suggestions',
#  'Automatic',
#  'Open',
#  'Efficiently',
#  'Improving',
#  'Currently,',
#  'Ontologies',
#  'Extended',
#  'Bayesian',
#  'Alternative',
#  'Diagnosis',
#  'This,',
#  'Surface',
#  'Correlation',
#  'Its',
#  'Head',
#  'Facial',
#  'Now',
#  'Books',
#  'Model',
#  'Concurrently,',
#  'Comparing',
#  'Usually,',
#  'Efficient',
#  'Background:',
#  'Aims:',
#  'Conclusions:',
#  'Modeling',
#  'Complex',
#  'Typically,',
#  'Natural',
#  'Early',
#  'Measuring',
#  'Detailed',
#  'Proxies',
#  'Critical',
#  'Twelve',
#  'Next,',
#  'Anonymous',
#  'Caricature',
#  '(ii)',
#  '(iii)',
#  '(iv)',
#  'Augmented',
#  'Data',
#  'Observing',
#  'Unsupervised',
#  'Requirements',
#  'Apparently,',
#  'Scenarios',
#  'Digital',
#  'Variants',
#  'Samples',
#  'Face',
#  'Actually,',
#  'Community',
#  'Algorithm',
#  'Contracts',
#  'Advances',
#  'Useful',
#  'Quite',
#  'Sensitive',
#  'Individual',
#  'Serious',
#  'Interestingly,',
#  'Resource',
#  'Contrary',
#  'I',
#  'Towards',
#  'Particularly,',
#  'Designing',
#  'Apriori',
#  'Factors',
#  'Considered',
#  'Ambient',
#  'Developing',
#  'Cardiac',
#  'Ablation',
#  'Coupled',
#  'Peak',
#  'Mixture',
#  'Keywords:',
#  'Future',
#  'Random',
#  'Stack',
#  'Persistent',
#  'Still,',
#  'Physically',
#  'Traffic',
#  'Accurate',
#  'Gaussian',
#  'Exponential',
#  'Classical',
#  'Pedestrian',
#  'Nowadays,',
#  'Next',
#  'Proper',
#  'Obtaining',
#  'Exploiting',
#  'Simulators',
#  'Dynamic',
#  'Applying',
#  'Focusing',
#  'Historically,',
#  'Distributed',
#  'Classifiers',
#  'Self',
#  'Preconditioned',
#  'India',
#  'Scripts',
#  'Benchmark',
#  'Depending',
#  'Dense',
#  'Specialized',
#  'Scalable',
#  'Ubiquitous',
#  'Of',
#  'Quantitatively,',
#  'Evaluating',
#  'Presumably,',
#  'Human',
#  'Owing',
#  'Graph',
#  'Importantly,',
#  '"How',
#  '(The',
#  'Cell',
#  'Formulas',
#  'Thereby',
#  'Only',
#  'Departing',
#  'User',
#  'Relational',
#  'Local',
#  'Extending',
#  'Conditions',
#  'Vehicle',
#  'Book',
#  'Creating',
#  'Signals',
#  'Experiment',
#  'Essential',
#  'Survival',
#  'Indirect',
#  'Semantic',
#  'Conditional',
#  'Energy',
#  'Intuitively,',
#  'Relevant',
#  'Relying',
#  'Stream',
#  'Remarkably,',
#  'Blockchain',
#  'Decentralized',
#  'Stochastic',
#  'Bilinear',
#  'Spectral',
#  'Volumetric',
#  'Optimization',
#  'Cloud',
#  'Systems',
#  'Feature',
#  'Theoretically,',
#  'Multimedia',
#  'Reinforcement',
#  'Linear',
#  'Author',
#  'Tested',
#  'Magnetic',
#  'Typical',
#  'Especially',
#  'Theoretical',
#  'when',
#  'Graphs',
#  'graphs',
#  'Quantizers',
#  'Reading',
#  "It's",
#  'Music',
#  'Preliminary',
#  'Improved',
#  'Regardless',
#  'Performance',
#  'Controllers',
#  'Patches',
#  'Discussions',
#  'Segmentation',
#  'Solutions',
#  'Weighted',
#  'Consider',
#  'Making',
#  'Optimizing',
#  'Implementing',
#  'Manual',
#  'Much',
#  '),',
#  'Long',
#  'Orthogonal',
#  'Therefore',
#  'Applicability',
#  'Today',
#  'Value',
#  'Object',
#  'Predicted',
#  'Success',
#  'Differently,',
#  'Augmenting',
#  'Can',
#  'New',
#  'Basic',
#  'Signal',
#  'Detecting',
#  'Manifold',
#  'Letting',
#  'Ultimately,',
#  'Legged',
#  'Either',
#  'Otherwise,',
#  'Correct',
#  'Initially',
#  'Ideas',
#  'Evidence',
#  'Implications',
#  'Conclusions',
#  'Chinese',
#  'Evaluated',
#  'Policies',
#  'Counting',
#  'Getting',
#  'Fractional',
#  'Evolutionary',
#  'Beside',
#  'Privacy',
#  'Querying',
#  'Planning',
#  'Prior',
#  'Multipath',
#  'Gradients',
#  'Beyond',
#  'Working',
#  'Eye',
#  'Foundations',
#  '9,',
#  'Whereas',
#  'Similarity',
#  'Reduction',
#  'Employing',
#  'Restricted',
#  'Binarization',
#  'Diagrammatic',
#  '(2017).',
#  'Like',
#  'Foggy',
#  'Part',
#  'Function',
#  'Poor',
#  'Unmanned',
#  'Offloading',
#  'Analytic',
#  'What',
#  'Adaptability',
#  'Every',
#  'Use',
#  'Contemporary',
#  'Slow',
#  'Nonetheless,',
#  'Testing',
#  'Compositional',
#  'Participants',
#  'Proposals',
#  'Computationally',
#  'Collecting',
#  'Robust',
#  'Cybercrime',
#  'Categorical',
#  'Customers',
#  'People',
#  'Android',
#  'Alternatively,',
#  'Researchers',
#  'Drawing',
#  'Stereo',
#  'Statistical',
#  'Categories',
#  'Wikipedia',
#  'Health',
#  'Objectives:',
#  'Methods:',
#  'Findings:',
#  'Vertex',
#  'Outlier',
#  'Interpretation',
#  'Programmers',
#  'Source',
#  'Growing',
#  'Supporting',
#  'Sampling',
#  'Writing',
#  'Web',
#  'Evaluations',
#  'Visual',
#  'Agents',
#  'Within',
#  'Just',
#  'Aerial',
#  'Predicting',
#  'Extracting',
#  'Text',
#  'Phase',
#  'Relative',
#  'Trajectory',
#  'Explicitly',
#  'Vector',
#  'Delay',
#  'Iris',
#  'Fusion',
#  'Dataset',
#  'Pulse',
#  'Special',
#  'Passive',
#  'Are',
#  'You',
#  'Should',
#  'Virtual',
#  'Biological',
#  'Access',
#  'Overall,',
#  'Lexical',
#  'Close',
#  'b)',
#  'Nodes',
#  'Properties',
#  'Biclustering',
#  'Proposed',
#  'Usefulness',
#  'So,',
#  'Costs',
#  'Objective',
#  'Psychological',
#  'Monoidal',
#  'Urban',
#  'Empirically,',
#  'Proliferation',
#  'Naive',
#  'Similar',
#  'Functioning',
#  'Automatically',
#  'Extracted',
#  'Specially',
#  'Inferring',
#  'Sharing',
#  'Roughly',
#  'Gibbs',
#  'Path',
#  'Verbs',
#  'Related',
#  'Generating',
#  'Particularly',
#  'Missing',
#  'Adversaries',
#  'Similarly',
#  'Controller',
#  'Constructing',
#  'Consistent',
#  'Parameters',
#  'Accuracy',
#  'Later,',
#  'Additionally',
#  'Interaction',
#  'Why',
#  'Named',
#  'Unseen',
#  'Granular',
#  'Her',
#  'Validation',
#  'Embarrassingly',
#  'Basically,',
#  'Molecular',
#  'Recall',
#  'Automating',
#  'Regularity',
#  'Active',
#  'Opportunistic',
#  'Independently',
#  'We,',
#  'Bitcoin',
#  'Cellular',
#  'Liquids',
#  'Key',
#  'Land',
#  'Knowing',
#  'Now,',
#  'Gender',
#  'Decision',
#  'Increased',
#  'Major',
#  'Joint',
#  'Game',
#  'Logical',
#  'Anomaly',
#  'Ideally,',
#  'Process',
#  'Map',
#  'Accordingly,',
#  'Basing',
#  'Advertisers',
#  'Capitalizing',
#  'Will',
#  'Participatory',
#  'Examining',
#  'Overall',
#  'Important',
#  'Classic',
#  'Crucially,',
#  'Breast',
#  'Hematoxylin',
#  'Development',
#  'Defect',
#  'Since,',
#  'Identity',
#  'Humans',
#  'Series',
#  'Later',
#  'Fog',
#  'Analytical',
#  'Tropical',
#  'Applications',
#  'Accelerated',
#  'Which',
#  'Project',
#  'Consumers',
#  'Point',
#  'Aboria',
#  'Everything',
#  'Coexistence',
#  'Scale',
#  'Linked',
#  'Adapted',
#  'Beginning',
#  'Nonnegative',
#  'Upper',
#  'Moving',
#  'Number',
#  'Algorithmic',
#  'Question',
#  'Recognition',
#  'Hierarchical',
#  'Inverse',
#  'Progressive',
#  'Amongst',
#  'Structure',
#  'Notably,',
#  'Notwithstanding,',
#  'Case',
#  'Handwritten',
#  'Enterprise',
#  'Authoring',
#  'Selecting',
#  'Do',
#  'Curiously,',
#  'Language',
#  'Facing',
#  'Nearly',
#  'Evaluation',
#  'Kernel',
#  'Churn',
#  'Anonymization',
#  'Devising',
#  'Availability',
#  'Tasks',
#  'Today,',
#  'Sometimes',
#  'Intelligent',
#  'Neuroblastoma',
#  'Surprisingly',
#  'Complementary',
#  'Across',
#  'Transfer',
#  'Content',
#  'Theories',
#  'Connectivity',
#  'Taken',
#  'Projective',
#  'Probabilities',
#  'Recommender',
#  'Mr.',
#  'Operators',
#  'Six',
#  'Increasingly',
#  'Flow',
#  'Computing',
#  'Disjunctive',
#  'Literature',
#  'Recommendation',
#  'Cases',
#  '(2014)',
#  'Split',
#  '(2017)',
#  'Incorporating',
#  'Very',
#  'Keywords',
#  "Today's",
#  'Bandwidth',
#  'Let',
#  'Frame',
#  'Constraint',
#  'Apart',
#  'Indexing',
#  'Presently,',
#  'Gaining',
#  'Lack',
#  'Issues',
#  'Finite',
#  'Implementation',
#  'Indeed',
#  'Cyber',
#  'Widespread',
#  'Hybrid',
#  'Univariate',
#  'Agile',
#  'Principles',
#  'Smoothed',
#  'Tensegrity',
#  'Discriminant',
#  'Second',
#  'Flexible',
#  'Watermark',
#  'Extraction',
#  'Completeness',
#  'Volume',
#  'Medical',
#  'Used',
#  'Mining',
#  'Message',
#  'Recognising',
#  'Mapping',
#  'Resources',
#  'Single',
#  'Home',
#  'Describing',
#  'Prediction',
#  'Mel',
#  'Everyday',
#  'Assigning',
#  'Approximate',
#  'Deformable',
#  'Discrete',
#  'Characterizing',
#  'Aiming',
#  'Submodular',
#  'Hardware',
#  'Adaptive',
#  'Electronic',
#  'Diffusion',
#  'Videos',
#  'Heretofore,',
#  'Predictive',
#  'Who',
#  'Volunteer',
#  'Redundancy',
#  'Multiagent',
#  'Heuristic',
#  'Fast',
#  'Differing',
#  'Perfect',
#  'Popularity',
#  'Individuals',
#  'Iterative',
#  'Benchmarking',
#  'Previously,',
#  'Fault',
#  'Skin',
#  'Permutation',
#  'Last',
#  'Subject',
#  'Memories',
#  'Multi',
#  'Implemented',
#  'Small',
#  'Varying',
#  'Coherent',
#  'Free',
#  'Impact',
#  'Weather',
#  'Microscopic',
#  'Loop',
#  'Query',
#  'Conversational',
#  'Alongside',
#  'Popular',
#  'Together,',
#  'Symmetric',
#  ';',
#  'There,',
#  'Technically,',
#  'Inside',
#  'Those',
#  '(1)',
#  'Performing',
#  'Concepts',
#  'Methodology',
#  'General',
#  'Papers',
#  'Researchers,',
#  'Terms',
#  'Performances',
#  'Matrix',
#  'Cryptocurrencies',
#  'Outside',
#  'Provably',
#  'Problem',
#  'Mobility',
#  'Allowing',
#  ...]

# %%
words
# Out:
# {'CUB-200-2011',
#  'lowresolution',
#  '53.47',
#  'active-learning-by-learning',
#  'notice',
#  'student',
#  'database-style',
#  'submarine',
#  'held-out',
#  '7.95',
#  'correlational',
#  'prudence',
#  'variational',
#  'Well-definedness',
#  'explainability',
#  'Cooperativeness',
#  'known-plaintext/ciphertext',
#  'suddenly',
#  'stressors',
#  'organisations',
#  'colliding',
#  'Brick',
#  'astrophysics',
#  'zero-copy',
#  'SFNN',
#  'HFL',
#  'vending',
#  'self-documenting',
#  'Relief',
#  'rovers',
#  'vitals',
#  'PH2',
#  'areas',
#  'mined',
#  'non-linearities',
#  'IDNC-based',
#  'ERP-related',
#  'decreases',
#  'Plan',
#  'discrimination',
#  'interweaves',
#  '24000',
#  'bag',
#  'kinetics',
#  'primate',
#  'IBCD',
#  'ISS',
#  'Additional',
#  'multiparty',
#  'graph',
#  'keystroke',
#  'listing',
#  'Cybergeo',
#  'Human-Robot',
#  'frames',
#  'Unifying',
#  'menace',
#  'WGAN',
#  'Dirichlet-type',
#  'intelligences',
#  'subservient',
#  'justifications',
#  'harden',
#  'Dolev-Yao',
#  'attacks',
#  'non-coherent',
#  'RF/VLC',
#  'non-synthetic',
#  'PSPACE-hard',
#  'PSN',
#  'commitment',
#  'what-if',
#  'mutable',
#  'floors',
#  'sticking',
#  'perks',
#  'Eigenvalue',
#  '5x5',
#  'compress',
#  'interchange',
#  'low-rankness',
#  'stronger',
#  're-ranking',
#  'Neville',
#  'BCI',
#  'collapse',
#  'LEDs',
#  'preorder',
#  'RNA-seq',
#  'obtains',
#  'colouring',
#  'dialog',
#  'establishits',
#  'PhD',
#  'LGN',
#  'ResUNet',
#  'dash-cam',
#  'Anticipating',
#  'wanted',
#  'F.',
#  'trimming',
#  'Hakia',
#  '67',
#  'ConvACs',
#  'Emotions',
#  'certifying',
#  'rear-end',
#  'depth-aware',
#  'buoyancy',
#  'RSS',
#  'queuing',
#  'PEGI',
#  'recently-developed',
#  'Erlang',
#  'Dagum',
#  'NOR',
#  'desert',
#  'unattributed',
#  'knot',
#  'MultiNLI',
#  'employing',
#  'explosions',
#  '`generalized',
#  'causes',
#  'Unlocking',
#  'over-segmenting',
#  'moderating',
#  'creep',
#  'NM',
#  'Fermi',
#  'near-copy',
#  'DRX',
#  'MDM',
#  'allocations',
#  'quadratic',
#  'filler-gap',
#  'Nonfunctional',
#  'official',
#  'Maturity',
#  'insightful',
#  'seeding',
#  'malaria',
#  'redistribution',
#  'facto',
#  '4.02',
#  'runtime-based',
#  'bifuzzy',
#  'EUR-USD',
#  'gastrointestinal',
#  'become',
#  'equalizers',
#  'simplest',
#  'Jeffrey',
#  'Razakarivony',
#  'Multi-view',
#  'millimeter-wave',
#  'multi-index',
#  'Expectation-Maximization-like',
#  'world-of-mouth',
#  'List-CVAE',
#  'single-service',
#  'probablities',
#  'eco-visualizations',
#  'PervasiveHealth2015',
#  'replicability/reproducibility',
#  'human-consensus',
#  'electromyogram',
#  'ML-decoders',
#  'tumor',
#  'debugged',
#  'glove',
#  'perceptually-optimized',
#  'shares',
#  'randomized',
#  'forget',
#  'auROC',
#  '109,488',
#  'distress',
#  'category-independent',
#  'Resources',
#  'p-type',
#  'RSD',
#  '538',
#  'Stability',
#  'Sinkhole',
#  'undeciphered',
#  'Excitation',
#  'astronomy',
#  'trading',
#  'multi-model',
#  'unitary',
#  'shoreline',
#  'synergies',
#  'vertex-disjoint',
#  'IDSs',
#  'HYPE',
#  'Recurrent',
#  'together',
#  'large-sized',
#  'scarce-resourced',
#  'neighbour',
#  'Marco',
#  'ReCoNet',
#  'Potentiality',
#  'self-adaptive',
#  'Deliberate',
#  'Semi-supervised',
#  'Standalone',
#  'photo-sharing',
#  'astrocytes',
#  'PINs',
#  'Hilbert',
#  'BUS',
#  'plots',
#  'ROI',
#  'SK-calculus',
#  'auroral',
#  '99.5',
#  'delta++-rule',
#  'programmer',
#  'GPy',
#  'machinery',
#  'multi-grid',
#  'subgame',
#  'thresholding',
#  'RFID',
#  '850',
#  'transmitters',
#  '0.3292',
#  'Cortex',
#  'locally',
#  'demonstrated',
#  'chair',
#  'OAI-PMH',
#  'Reliable',
#  'dire',
#  '`gestures',
#  '484,449',
#  'Gilbert',
#  're-search',
#  '1999',
#  'Rice',
#  '11.8K',
#  'interfere',
#  'expenses',
#  'broadband',
#  '10-channel',
#  'iPPG',
#  'J',
#  'effect',
#  'EPC',
#  'maternal',
#  'comprising',
#  'steered',
#  'two-point',
#  'influencing',
#  'Event-based',
#  'retargeting',
#  'revolutionized',
#  'soft-attention',
#  'signage',
#  'Rejection',
#  'Characteristic-Preserving',
#  'Atrial',
#  'Glabbeek',
#  'winners',
#  'allocators',
#  'row-by-row',
#  'decorrelator',
#  'photometric',
#  'Image',
#  'regionally',
#  'PADA',
#  'supplemented',
#  'alternately',
#  'VisualGenome',
#  'owing',
#  'therein',
#  'integrated',
#  'RACH',
#  'neutral',
#  'QCRI',
#  'lens-based',
#  'critique',
#  'parameter-dependent',
#  'boosts',
#  'software',
#  'refinery',
#  'micro-message',
#  '0.28',
#  'Comparison',
#  'subtleties',
#  'lab',
#  'DSTC2-specific',
#  'storing',
#  'FTA',
#  '2.52',
#  'naturalistic',
#  'splits',
#  'Large-Scale',
#  'caching',
#  'wavetables',
#  'Chesthetica',
#  'violating',
#  'atrioventricular',
#  'Multi-party',
#  'drugs',
#  'defender/administrator',
#  'characters',
#  'pixels/voxels',
#  'formally-grounded',
#  'ChemKED-formatted',
#  'nodal',
#  'multiplier',
#  '2.0',
#  'multi-radius',
#  'linearizations',
#  '21',
#  'nontrivially',
#  'persons',
#  'Arbor',
#  'certifications',
#  'HTM',
#  'Soil',
#  'replanning',
#  '2.5x',
#  'Annealing',
#  'SNRs',
#  'clock',
#  'MPH',
#  'gyrus',
#  'milestone',
#  'discards',
#  'compressors',
#  'VAE',
#  'post-deadline',
#  'schools',
#  'Sarcasm',
#  'Auto-WEKA',
#  'dominations',
#  'John',
#  'strengths',
#  'non-negligible',
#  'Brood',
#  'Grammars',
#  'realizes',
#  'UCP',
#  'discretion',
#  'MCDA',
#  'experiment',
#  'lenis',
#  'ZSL',
#  'keyframe',
#  'Parisi',
#  'DPC',
#  'e-Learning',
#  'Tacotron',
#  'albedo',
#  'sampling/recovery',
#  'recursion',
#  '205000',
#  'OTPS',
#  'liquid',
#  'carry-propagation',
#  'baseline',
#  'surpassed',
#  'preordered',
#  'pleasing',
#  'Computing',
#  'programmatically',
#  'Earth-Mars',
#  'IPI',
#  'PascalVOC',
#  'guarantees',
#  'Benchmarks',
#  'phasor-detective',
#  'many-valued',
#  'GERDAQ',
#  'epipolar',
#  'reordered',
#  'disambiguation',
#  'setbacks',
#  'DCs',
#  'negations',
#  'quo',
#  'chatbot',
#  'KCCA',
#  'ignore',
#  'Time-Series',
#  'text-generating',
#  'nationality',
#  'EPVS',
#  'wake',
#  'MIMRF',
#  'CCUDA',
#  'cohesivity',
#  'POI',
#  'preferable',
#  'rests',
#  'cepstrum',
#  'tissue',
#  'psychophysiologicy',
#  'within-vocabulary',
#  're-conduced',
#  'mask',
#  'MSHMM',
#  'Single-chip',
#  'Members',
#  'dictatorship',
#  'payoff-based',
#  'lookups',
#  'marriage',
#  'Kharitonov',
#  'FPGA-',
#  'hold',
#  'Choquet',
#  "'innocent",
#  'nationwide',
#  'invite',
#  'Arts',
#  'map-unaware',
#  'speeding',
#  'action-',
#  'LiDAR',
#  'warehousing',
#  'DroidScribe',
#  'mindful',
#  'liveness',
#  'morphism',
#  'checkable',
#  'general-purpose',
#  '-training',
#  'pysc2',
#  'multi-part',
#  'VNE',
#  'especial',
#  'Trap5',
#  'little',
#  'imposition',
#  'relinking',
#  'Data-driven',
#  'Size',
#  'limited-buffer',
#  'Daubechies',
#  'bullet',
#  'noticeably',
#  'target-specific',
#  'Conv-LSTM',
#  'CS-factor',
#  'TreeQN',
#  'test-error-rate',
#  'uncover',
#  "DAC-SDC'18",
#  'tape',
#  'Jaccard',
#  'preconditioned',
#  'binocular',
#  'sonic',
#  'foreground/background',
#  'festum',
#  'finite-dimensional',
#  'homomorphic',
#  'non-computing',
#  'sMRI',
#  'undecidable',
#  'glosses',
#  'BI-RADS',
#  'VOT2015',
#  'scratchpad',
#  'tICA',
#  'Singapore',
#  'node-perturbation',
#  'computer-generated',
#  'm.',
#  'seismograms',
#  'Provenance',
#  'assaults',
#  'diagonalise',
#  'SciTail',
#  'privacy',
#  'rolling',
#  'meta-modeling',
#  'Amongst',
#  '//github.com/jiecui/mpact',
#  'propaganda',
#  'cousins',
#  'SPL',
#  'Hodosh',
#  'acid',
#  'Dexteroid',
#  'multicommodity',
#  'path-planning',
#  'ECHO',
#  'OU-MVLP',
#  '63.88',
#  'reassembled',
#  'spatio-statistical',
#  'informative',
#  'Neuroblastoma',
#  'Stereo',
#  'axiomatisation',
#  'Bruynooghe',
#  'QDDS',
#  'IDEAS',
#  'DVB-SH',
#  'residuation',
#  'schatten-p-norm',
#  'Actor-critic',
#  'tlenecks',
#  'candidates',
#  'fuels',
#  'memories',
#  'urban-scale',
#  'collect',
#  'neonate',
#  'multi-type',
#  'LCSE',
#  'strategic',
#  'Uncertainty',
#  'down-',
#  'Arxiv',
#  'vocalisations',
#  'curbing',
#  'Database-as-a-Service',
#  'balance',
#  'rethink',
#  'ANFIS',
#  'reweight',
#  'psycholinguistic',
#  'mentation',
#  'TVAL3',
#  'assorted',
#  'Pre-trained',
#  'Compton',
#  'complex',
#  'kcal/mol',
#  'pro-independence',
#  'nature-inspired',
#  'goals',
#  'single-shot',
#  'starting-point',
#  'majorization-minimization',
#  'ZebraLancer',
#  'accessibility',
#  'top-performing',
#  'unsatisfied',
#  'forced',
#  'CSI',
#  'RNG',
#  'converging',
#  'source-',
#  'mediate',
#  'lane-level',
#  'high-degree',
#  'contradictory',
#  'i',
#  'fanbeam',
#  'harder',
#  'nonexistent',
#  'Hopfield',
#  'biasing',
#  'newly-released',
#  'overlap',
#  'Thomason',
#  'Replication-based',
#  'S-EDPF',
#  'counter-effective',
#  'Parliament',
#  'time-optimality',
#  'Answer',
#  'deception',
#  'SI-SDR',
#  'morphologically',
#  'amateur',
#  'triads',
#  'offerings',
#  'Code-Mixed',
#  'G-SPCC',
#  'current/future',
#  'STRUCTURE',
#  'proposing',
#  'ANOMA',
#  '//goo.gl/RM8jvH',
#  'multivalued',
#  'burnouts',
#  'street',
#  'timelike',
#  'model',
#  'F1-score',
#  'sum-product',
#  'PNP',
#  'transverse-XY',
#  'Encore',
#  'competences',
#  'Latent-Factor',
#  'farmlands',
#  'flip-chip',
#  'AGRIF',
#  'metabolism',
#  'Encoder-decoder',
#  'Equipped',
#  'ion',
#  'RV-PMF',
#  'AV1',
#  '1.82',
#  'planer',
#  'Darwinian',
#  'bitrates',
#  'Discovery',
#  'Paris106k',
#  'DSNS',
#  'Confusional',
#  'steady',
#  'HAN',
#  'enumerators',
#  'Auto',
#  'botnets',
#  'survey-based',
#  'lowd',
#  'debugging',
#  'spin-up',
#  'Jena',
#  'neurosciences',
#  'WLRA',
#  'Birth-Death',
#  'APPA',
#  'BLDC',
#  'CKR',
#  'fine-tuning',
#  'impostor',
#  'RPN',
#  'inpatient',
#  'TemporaL',
#  'redirection',
#  'verifications',
#  'fascinating',
#  'bitangents',
#  'control/normal',
#  'NGWNs',
#  'Landsat',
#  'actionness',
#  'missing-data',
#  'NORB',
#  'quaternion-based',
#  'binarize',
#  'learning/adaption',
#  'reserve',
#  'PRISM',
#  'Infected',
#  'attention-aware',
#  'separation-funnels',
#  'retinopathy',
#  'affordances',
#  'anatomic',
#  'Improving',
#  'EMG',
#  'SOS-CNN',
#  'Robinson-Goforth',
#  'Gamma_f',
#  'energy-dependent',
#  'R/I',
#  'Q2A',
#  'gadget',
#  'contributors',
#  'forth',
#  'culled',
#  'variances',
#  '73.8',
#  'drive',
#  'message-based',
#  'low-priced',
#  'beam',
#  'traceability',
#  'automakers',
#  'Hoc',
#  'isosceles',
#  'describing',
#  'playing',
#  'pseudo-',
#  'spatially-coupled',
#  'github',
#  'datatype',
#  'PMV',
#  'Machines',
#  'lowers',
#  'word-analogy',
#  'A2-RL',
#  'mono-',
#  'Re-speaking',
#  'covariant-contravariant',
#  'Assigning',
#  'parent-like',
#  'foods',
#  'cyber-network',
#  'Overfitting',
#  'ell-adic',
#  'denotational',
#  'rotations',
#  '2x2',
#  '3V',
#  'quanta',
#  'especially',
#  'Galinier',
#  'preferentially',
#  'reassembleable',
#  'word-of-mouth',
#  'LIAN',
#  'poly-algorithm',
#  'enclosed',
#  'well-summarized',
#  'effectively',
#  'excite',
#  '//github.com/miliadis/DeepVideoCS',
#  'Washing',
#  'non-relevant',
#  'Tbps',
#  'aspects',
#  'sharing/publishing',
#  'course-of-action',
#  'shuffling',
#  'sample-to-sample',
#  'Vandermonde',
#  'codes',
#  'cipher-images',
#  'MANETs',
#  'happening',
#  'matrix-vector',
#  'spreads',
#  'Tanenbaum',
#  'Movie',
#  'Spreadsheets',
#  'manchester',
#  'JANUS',
#  'orchestrated',
#  'custom',
#  'browse',
#  'power-delay',
#  'table',
#  '5,000',
#  'intracardiac',
#  'biosignal',
#  'FPTAS',
#  'Inour',
#  '1e-4',
#  'Orthoglide',
#  'M',
#  '`v',
#  'attends',
#  'negatively',
#  'Hierarchical',
#  'D-well-founded',
#  'scar',
#  'RodentStore-built',
#  'sketch-like',
#  'Artists',
#  'Kf',
#  'LUT',
#  'phishing',
#  'denotations',
#  'TPHD',
#  'workstations',
#  'n',
#  'GAN-generated',
#  'Concepts',
#  'clothing',
#  'Sardinian',
#  'PropBank',
#  'throughput-outage',
#  'remember',
#  'connects',
#  'XQuery',
#  'behaviours',
#  'quadrocopters',
#  'nutritional',
#  'unidirectional',
#  'sizing',
#  'Curiously',
#  'multidigit',
#  'Hence',
#  'PDDL+',
#  'Alchemist',
#  'factual',
#  'mantic',
#  '206',
#  'STPC',
#  'viola',
#  'shoulder',
#  'degrades',
#  'Space-Saving',
#  'metro',
#  'noninterference',
#  'mother',
#  'P300',
#  'abruptly-changing',
#  'model-predictive',
#  'ing',
#  'screening',
#  'according',
#  'TT',
#  'error-correcting',
#  'T-splines',
#  'off-line',
#  'prevalently',
#  '1963',
#  'overoptimization',
#  'incorporates',
#  'Advances',
#  'majority',
#  'VIVO',
#  'online.It',
#  'downloadable',
#  'PSFs',
#  'photonics',
#  'dependency-aware',
#  'demystify',
#  'performance.Our',
#  'predictably',
#  'MPCM',
#  'apportionment',
#  'colorectal',
#  'mutilation',
#  'infinite-horizon',
#  'microalgae',
#  'Partitioned',
#  'in-the-',
#  'well-ordered',
#  'RA-UL',
#  'restarting',
#  'm^2-3',
#  'Maryland',
#  'ripple',
#  'inkling',
#  'charging-related',
#  'domestic',
#  'memoryless',
#  'KDevelop',
#  'sixties',
#  'microbiology',
#  'Multi-Dimensional',
#  'regularization-based',
#  'ultra-precision',
#  'CSIQ~and',
#  'lifelong-learning',
#  'webgraphs',
#  'protocol-based',
#  'milling',
#  'pleura',
#  'exceeding',
#  'Sighthound',
#  'Achterberg',
#  'subcircuit',
#  'trustless',
#  'ulcers',
#  'decipher',
#  'Gramians',
#  'machine-',
#  'Composite',
#  'pulse-energy-measuring',
#  'VRP',
#  'buffered',
#  'image-to-image',
#  'Ronneberger',
#  'ABUs',
#  'non-UC',
#  'knowing',
#  'unimportant',
#  'encrypts',
#  'populated',
#  'Template',
#  'min-entropies',
#  'paraphrasing',
#  'multi-layered',
#  'confocal',
#  'degrees-of-freedom-optimal',
#  'V1',
#  'Sparsity',
#  'Cohen',
#  'switch-controller',
#  'Accept/Reject',
#  'Promotion',
#  'DCF',
#  'diversifies',
#  'drawback',
#  'Thresholding',
#  'insidious',
#  'improvised',
#  'Low-rank',
#  'Gauss-Hermite',
#  'becom',
#  'argumentation',
#  'Sobolev-differentiable',
#  'ZSD',
#  "'no",
#  'dependability',
#  'Specific',
#  'deposits',
#  'gain-shape',
#  'Hawaii',
#  'Chua',
#  'communities',
#  'Blahut-Arimoto',
#  'Decision',
#  'KLSH',
#  'lobes',
#  'chal-',
#  'U-trees',
#  'topical',
#  'Chinese-English',
#  'GM-PHD',
#  'diaries',
#  'Epistemological',
#  'rollover',
#  'Independent',
#  'uncovering',
#  'ORBIT',
#  'Sobolev',
#  'throat',
#  'presumptions',
#  'Response',
#  'ICDAR2015',
#  'clock-variable',
#  'Cournot',
#  'sweeps',
#  'Gramian',
#  '0.3',
#  'Deployed',
#  'process-monitoring',
#  'align',
#  'Ordering',
#  'flows/policies',
#  'prosthetic',
#  'unvarying',
#  'Examination',
#  'AM-Softmax',
#  'curating',
#  'to-solution',
#  'DCTCP',
#  'agreement',
#  'b-bit',
#  'ranked',
#  'diagonalises',
#  'cry',
#  'n-gram',
#  'per-domain',
#  'utilised',
#  'curve',
#  'diffusion-weighted',
#  'Hegselmann-Krause',
#  'Zoltan',
#  'length-2',
#  'distributable',
#  'unwinding',
#  'meta-model',
#  'controversiality',
#  'intersection',
#  'jump-start',
#  'XPI',
#  'divergent',
#  'Inversion',
#  'retrievals',
#  'FG456',
#  'matching-based',
#  'artificially',
#  'occupy',
#  'DoF',
#  'centerline',
#  'testbeds',
#  'MBR-based',
#  'equal',
#  'vast',
#  'Verb',
#  'Fundamental',
#  'IMD',
#  'land-estate',
#  'Theft',
#  'clarified',
#  'Long-Tail',
#  'ejected',
#  'semi-formal',
#  'GN-BP',
#  'semi-tutorial',
#  'SparseNN',
#  'phase-2',
#  'Tutte',
#  'martingales',
#  'Ideas',
#  'SDA',
#  'mellitus',
#  '9.6',
#  'Facilitating',
#  'R-MTP',
#  'exceed',
#  'mixture-manifolds',
#  'stitches',
#  'un-known',
#  '267',
#  'recently-increased',
#  'crowdsensing',
#  'Long-Short',
#  'cylindric',
#  ...}

# %% [markdown]
# #### 先獲取詞性後再進行詞性還原

# %%
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
# ref: https://www.itread01.com/content/1545170223.html


def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None


def revert_part_of_speech(tokens):
    tagged_tokens = pos_tag(tokens)  # 獲取單詞詞性
    wnl = WordNetLemmatizer()
    lemmas_sent = []

    for tag in tagged_tokens:
        wordnet_pos = get_wordnet_pos(tag[1]) or wordnet.NOUN
        lemmas_sent.append(wnl.lemmatize(tag[0], pos=wordnet_pos)) # 詞形還原

    return lemmas_sent
  
# 跑在這
words = revert_part_of_speech(words)

# %% [markdown]
# ### 爬品牌名稱來對照

# %%
import requests
from bs4 import BeautifulSoup
import json

r = requests.get("https://brandirectory.com/rankings/global-500-2018") #將網頁資料GET下來
soup = BeautifulSoup(r.text, "html.parser") # 將網頁資料以html.parser
# sel = soup.select("a.tight-text") # 取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
# sel
text = soup.find_all("script", type="application/ld+json")[0]
contents_dict = json.loads(text.contents[0])
# type(contents_dict)
brand_names = [d["item"]["name"] for d in contents_dict["itemListElement"]]
brand_names[:6]
# Out:
# ['Amazon', 'Apple', 'Google', 'Samsung', 'AT&T', 'Microsoft']

# %%
import string
import re

punctuations = ''.join([s for s in string.punctuation if s not in ('<', '>', '-')]) #  斜線冒號留著for Others label

def word_preprocess(word):

  # remove punctuations
  word = word.translate(str.maketrans('', '', punctuations))

  # remove numbers
  if '-' not in word:
    word = re.sub(r'\d+', '', word)

  if '-' in word:
    if (np.sum([w.isdigit() for w in word]) / len(word)) > 0.8:
      word = '<numbers>'
    else:
      word = '<cool-abr>'

  # brands
  if word in brand_names:
    word = '<brand>'

  # proprietary 1
  # if len(word) > 1:
  #   if (list(word)[0] == '(') and (list(word)[-1] == ')'):
  #     word = '<abr>'

  # all uppercase
  if len(word) > 1:
    if (np.sum([w.isupper() for w in word]) >= 1) and (word not in first_words):
      word = '<pry>'
  
  # URL
  if word in ["http", "github", "com"]:
      word = '<url>'


  # lemmatization
  # lemma = nltk.wordnet.WordNetLemmatizer()
  # word = lemma.lemmatize(word)

  # remove single character
  # if len(list(word)) < 2:
  #   word = ""

  return word # .lower() 換成小寫分數差很多?

# %%
from nltk.corpus import stopwords

with Pool() as pool:
  result = pool.map(word_preprocess, words)

words_pre = set(result)

print(stopwords.words('english'))
# words_pre = set([w.lower() for w in words_pre])
# words_pre = words_pre - set(stopwords.words('english'))

words_pre = words_pre - {''}
words_pre
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# {'truck',
#  'lowresolution',
#  'farm',
#  'digitally',
#  'banking',
#  'crystallography',
#  'renormalizerecompose',
#  'Dealing',
#  'notice',
#  'service',
#  'slop',
#  'Verification',
#  'prompted',
#  'speech',
#  'student',
#  'reveals',
#  'kmh',
#  'submarine',
#  'Deterministic',
#  'beautiful',
#  'Replacing',
#  'uplinkdownlink',
#  'confident',
#  'forhe',
#  'grayscale',
#  'prudence',
#  'correlational',
#  'variational',
#  'gigantic',
#  'yardstick',
#  'civil',
#  'psychologically',
#  'explainability',
#  'confront',
#  'workout',
#  'popularly',
#  'healthful',
#  'juridical',
#  'offend',
#  'suddenly',
#  'posets',
#  'labyrinth',
#  'mathematically',
#  'subvert',
#  'unsolvable',
#  'costly',
#  'astrophysics',
#  'paucity',
#  'restless',
#  'assess',
#  'buildingfloor',
#  'synaptic',
#  'nest',
#  'inverse',
#  'meadows',
#  'vitals',
#  'friendly',
#  'gripping',
#  'visual',
#  'metaheuristics',
#  'evasion',
#  'lifeless',
#  'fps',
#  'Expected',
#  'categorization',
#  'juncture',
#  'inflexibility',
#  'weed',
#  'mockups',
#  'wrap',
#  'oftentimes',
#  'imminent',
#  'Achieving',
#  'discrimination',
#  'pressuresaturation',
#  'bag',
#  'kinetics',
#  'confound',
#  'Indeed',
#  'scholar',
#  'minimizers',
#  'polyphonic',
#  'nudging',
#  'gravity',
#  'primate',
#  'cryptosystems',
#  'workloads',
#  'exoplanet',
#  'teacherstudent',
#  'Latent',
#  'Designing',
#  'gentle',
#  'descendant',
#  'analog',
#  'electromagnetic',
#  'microdatabases',
#  'Additional',
#  'multiparty',
#  'graph',
#  'Regularizing',
#  'keystroke',
#  'listing',
#  'anisotropic',
#  'repartition',
#  'entirely',
#  'dumps',
#  'markerless',
#  'ratingassessment',
#  'recede',
#  'menace',
#  'subservient',
#  'harden',
#  'ascend',
#  'Measurements',
#  'concurrent',
#  'regional',
#  'Recently',
#  'bore',
#  'bisection',
#  'multiobjective',
#  'mitigation',
#  'planningstreet',
#  'colonoscopy',
#  'reflexive',
#  'commitment',
#  'Survey',
#  'subscriber',
#  'axiomatic',
#  'match',
#  'redundantcommon',
#  'applied',
#  'suggestive',
#  'mutable',
#  'realism',
#  'meme',
#  'compliance',
#  'compress',
#  'utilize',
#  'buying',
#  'deg',
#  'interchange',
#  'silico',
#  'guarantee',
#  'modus',
#  'expert',
#  'deluge',
#  'ensue',
#  'prostate',
#  'collapse',
#  'preorder',
#  'affined',
#  'click',
#  'fuzzy',
#  'encoding',
#  'extractor',
#  'dialog',
#  'sonar',
#  'establishits',
#  'comprehensible',
#  'grounder',
#  'prevision',
#  'peritumoral',
#  'resection',
#  'Inferences',
#  'trainingnetwork',
#  'Anticipating',
#  'Explicitly',
#  'petition',
#  'Noun',
#  'Checking',
#  'synonymous',
#  'smarter',
#  'dietary',
#  'binary',
#  'Watermark',
#  'collates',
#  'buoyancy',
#  'astonish',
#  'lcc',
#  'Running',
#  'foregroundbackground',
#  'robber',
#  'desert',
#  'moderately',
#  'equation',
#  'airplane',
#  'underserved',
#  'unattributed',
#  'knot',
#  'outlay',
#  'metastability',
#  'polyaniline',
#  'Till',
#  'swath',
#  'strucgauss',
#  'multilinear',
#  'dairy',
#  'meticulously',
#  'reallocate',
#  'Moving',
#  'menu',
#  'haptic',
#  'compulsory',
#  'underlaying',
#  'analyis',
#  'moderating',
#  'creep',
#  'foreigner',
#  'compliant',
#  'backhauls',
#  'implication',
#  'antagonistic',
#  'guesser',
#  'quadratic',
#  'fault',
#  'misbehavior',
#  'overfits',
#  'isotropy',
#  'dominator',
#  'official',
#  'equivalency',
#  'insightful',
#  'geographic',
#  'malaria',
#  'resists',
#  'redistribution',
#  'facto',
#  'carpal',
#  'govern',
#  'rehabilitation',
#  'turnpike',
#  'subproblem',
#  'entrainment',
#  'monosite',
#  'neuropathoglogical',
#  'skate',
#  'bifuzzy',
#  'uncorrelating',
#  'conversation',
#  'leaderboard',
#  'three',
#  'gastrointestinal',
#  'linkability',
#  'become',
#  'incorrect',
#  'wrong',
#  'simplest',
#  'interrelationship',
#  'potentiation',
#  'legally',
#  'nth',
#  'psychiatric',
#  'sensorial',
#  'firstresults',
#  'competitively',
#  'unvisited',
#  'processing',
#  'For',
#  'probablities',
#  'wholeness',
#  'learningadaption',
#  'electromyogram',
#  'tumor',
#  'glove',
#  'T',
#  'multichannel',
#  'needsfor',
#  'econometrics',
#  'slope',
#  'minimally',
#  'Li',
#  'forget',
#  'green',
#  'distress',
#  'disembodied',
#  'nation',
#  'part',
#  'hashtable',
#  'Resources',
#  'disguising',
#  'itemset',
#  'Stability',
#  'undeciphered',
#  'gliding',
#  'ship',
#  'astronomy',
#  'softeware',
#  'unravelings',
#  'grained',
#  'unitary',
#  'be',
#  'hindex',
#  'shoreline',
#  'willingness',
#  'kitchen',
#  'Recurrent',
#  'together',
#  'maximization',
#  'neighbour',
#  'ambiguosly',
#  'specializers',
#  'ratios',
#  'timing',
#  'Deliberate',
#  'vault',
#  'community',
#  'prosodic',
#  'variety',
#  'potentiality',
#  'excess',
#  'miniaturization',
#  'strengthens',
#  'calcium',
#  'metropolitan',
#  'Observations',
#  'brokerage',
#  'neuromodulation',
#  'Optimal',
#  'revolutionary',
#  'circumvent',
#  'peta',
#  'geological',
#  'auroral',
#  'graduality',
#  'Organizations',
#  'programmer',
#  'soundly',
#  'reposting',
#  'bring',
#  'machinery',
#  'subgame',
#  'underpin',
#  'pollution',
#  'thresholding',
#  'preterm',
#  'semiconsonant',
#  'memory',
#  'skeletonization',
#  'The',
#  'Dictionary',
#  'holy',
#  'agnostic',
#  'honor',
#  'revive',
#  'Robust',
#  'quit',
#  'Obviously',
#  'elastic',
#  'codelengths',
#  'locally',
#  'powerspectrum',
#  'chair',
#  'obfuscating',
#  'Sharing',
#  'Reliable',
#  'numeral',
#  'precludes',
#  'transparent',
#  'toxic',
#  'dire',
#  'surveillance',
#  'readapt',
#  'organismal',
#  'quantizes',
#  'supervises',
#  'men',
#  'consequentialist',
#  'Configuring',
#  'decorrelated',
#  'interfere',
#  'impatient',
#  'distinguishable',
#  'broadband',
#  'orthographic',
#  'J',
#  'effect',
#  'output',
#  'guardian',
#  'maternal',
#  'always',
#  'gradual',
#  'river',
#  'comprising',
#  'alternatively',
#  'speculates',
#  'cdf',
#  'confine',
#  'retargeting',
#  'deployment',
#  'turbine',
#  'signage',
#  'stance',
#  'atop',
#  'orientate',
#  'admittance',
#  'incomparable',
#  'syntactically',
#  'Organisations',
#  'aggressiveness',
#  'terrorist',
#  'glucose',
#  'decorrelator',
#  'axiomatizations',
#  'listen',
#  'Necessary',
#  'Pervasive',
#  'photometric',
#  'Containers',
#  'Image',
#  'tetrahedron',
#  'regionally',
#  'alternately',
#  'memetic',
#  'therein',
#  'neutral',
#  'spreadsheet',
#  'arrangements',
#  'insidegreenhouses',
#  'personality',
#  'thousand',
#  'dropshipping',
#  'accommodate',
#  'critique',
#  'rest',
#  'facilitating',
#  'embarrassment',
#  'software',
#  'refinery',
#  'Given',
#  'densification',
#  'Comparison',
#  'worker',
#  'lab',
#  'storing',
#  'mobilize',
#  'hypersurface',
#  'arealatency',
#  'coevolve',
#  'penalty',
#  'arsenal',
#  'naturalistic',
#  'bisimilar',
#  'stochastically',
#  'conjunct',
#  'exploitable',
#  'glass',
#  'square',
#  'mechanic',
#  'wavetables',
#  'demo',
#  'infection',
#  'Verbs',
#  'equitably',
#  'atrioventricular',
#  'dilemma',
#  'point',
#  'indispensable',
#  'bioinspired',
#  'trimap',
#  'undescribed',
#  'Basic',
#  'Home',
#  'duplicate',
#  'shove',
#  'sinus',
#  'should',
#  'nodal',
#  'Ezhil',
#  'expensive',
#  'multiplier',
#  'sink',
#  'reflectance',
#  'analyticity',
#  'electron',
#  'linearizations',
#  'nontrivially',
#  'traverse',
#  'freeware',
#  'replanning',
#  'audiomotor',
#  'shunt',
#  'prevalence',
#  'slip',
#  'quick',
#  'clock',
#  'gyrus',
#  'milestone',
#  'transposition',
#  'misappropriation',
#  'usability',
#  'tradeoff',
#  'ment',
#  'blocklength',
#  'Sarcasm',
#  'Maximally',
#  'Physically',
#  'Teaching',
#  'holotype',
#  'analoghybrid',
#  'interleavers',
#  'torque',
#  'strengths',
#  'Active',
#  'alteration',
#  'Impact',
#  'Grammars',
#  'conservancy',
#  'vacate',
#  'subgroup',
#  'decidability',
#  'discretion',
#  'Generalized',
#  'restore',
#  'intuitionistic',
#  'experiment',
#  'lenis',
#  'keyframe',
#  'Valid',
#  'phenomenology',
#  'albedo',
#  'ocular',
#  'uninterpretability',
#  'Scene',
#  'recursion',
#  'diversity',
#  'Characterizing',
#  'immediacy',
#  'default',
#  'tedious',
#  'bitstrings',
#  'geospatial',
#  'liquid',
#  'resp',
#  'superpixels',
#  'baseline',
#  'equalisation',
#  'unbiasedness',
#  'preordered',
#  'Computing',
#  'programmatically',
#  'effciently',
#  'confounder',
#  'regularizers',
#  'realize',
#  'dominate',
#  'poise',
#  'endangerment',
#  'dispatching',
#  'publisher',
#  'replication',
#  'wheeled',
#  'nanosensors',
#  'bulk',
#  'Benchmarks',
#  'nonzero',
#  'keyframes',
#  'forthcoming',
#  'compositing',
#  'Targeting',
#  'core',
#  'diagrams',
#  'indecision',
#  'fool',
#  'disregard',
#  'epipolar',
#  'unfortunately',
#  'disambiguation',
#  'quo',
#  'debase',
#  'chatbot',
#  'Automata',
#  'reduct',
#  'microblogging',
#  'cooperation',
#  'Instead',
#  'ignore',
#  'final',
#  'githubcommikacuypointnetvlad',
#  'calculates',
#  'enriching',
#  'specialist',
#  'occupancy',
#  'nationality',
#  'drowsiness',
#  'wake',
#  'graphic',
#  'cohesivity',
#  'colorization',
#  'preferable',
#  'attainable',
#  'clause',
#  'Processes',
#  'anomaly',
#  'cepstrum',
#  'tissue',
#  'task',
#  'Associative',
#  'psychophysiologicy',
#  'interferometric',
#  'new',
#  'bust',
#  'mask',
#  'Imaging',
#  'prodromal',
#  'Members',
#  'dictatorship',
#  'mimic',
#  'Contexts',
#  'doze',
#  'Gaussian',
#  'factor',
#  'marriage',
#  'army',
#  'thrive',
#  'indiscernibles',
#  'synthesis',
#  'that',
#  'likewise',
#  'perpendicular',
#  'Normalized',
#  'Variable',
#  'bitssymbol',
#  'hold',
#  'polycrystalline',
#  'enumerated',
#  'woman',
#  'nationwide',
#  'precursor',
#  'invite',
#  'synthesizable',
#  'recency',
#  'geometry',
#  'Chapter',
#  'demolishes',
#  'warehousing',
#  'Text',
#  'categorical',
#  'mindful',
#  'theme',
#  'achievable',
#  'liveness',
#  'nonuniformly',
#  'observe',
#  'hypergraphs',
#  'morphism',
#  'Indexing',
#  'checkable',
#  'quadcopter',
#  'Naive',
#  'transitivity',
#  'indoors',
#  'Strategic',
#  'takeaway',
#  'milk',
#  'synchronize',
#  'when',
#  'Completeness',
#  'revolutionize',
#  'Eigen',
#  'answer',
#  'especial',
#  'little',
#  'imposition',
#  'relinking',
#  'mass',
#  'portray',
#  'Size',
#  'summarise',
#  'Improvements',
#  'progress',
#  'oncogenetic',
#  'bullet',
#  'noticeably',
#  'biologist',
#  'redesigning',
#  'superimposes',
#  'multiconductor',
#  'melt',
#  'mover',
#  'sinusoidal',
#  'Scientists',
#  'uncover',
#  'semivalues',
#  'carcinoma',
#  'aerodynamic',
#  'tape',
#  'Jaccard',
#  'sonic',
#  'binocular',
#  'Proximity',
#  'poisson',
#  'simultaneous',
#  'festum',
#  'attendee',
#  'closeness',
#  'chemical',
#  'markered',
#  'distinctness',
#  'homomorphic',
#  'seasonality',
#  'collector',
#  'Aside',
#  'undecidable',
#  'uniformity',
#  'minor',
#  'eigenmode',
#  'scratchpad',
#  'evaporation',
#  'useless',
#  'One',
#  'hengli',
#  'Provenance',
#  'nonorthogonal',
#  'notebook',
#  'sidelobe',
#  'diagonalise',
#  'unary',
#  'hedge',
#  'Proofs',
#  'prof',
#  'fragment',
#  'privacy',
#  'purely',
#  'ergodic',
#  'Unique',
#  'pseudometric',
#  'extractionselection',
#  'incompatibility',
#  'demapping',
#  'companion',
#  'Multimedia',
#  'whether',
#  'Amongst',
#  'persuasion',
#  'fractal',
#  'propaganda',
#  'thermodynamic',
#  'faithfully',
#  'pitcher',
#  'pragmatist',
#  'specific',
#  'Thereby',
#  'acid',
#  'predict',
#  'multicommodity',
#  'elide',
#  'ministry',
#  'chapter',
#  'elongate',
#  'overshadow',
#  'Children',
#  'nonlinearity',
#  'cord',
#  'None',
#  'period',
#  'Eighty',
#  'Observed',
#  'informative',
#  'Neuroblastoma',
#  'Stereo',
#  'axiomatisation',
#  'Split',
#  'hyperboloid',
#  'noticed',
#  'residuation',
#  'Autonomic',
#  'Biometric',
#  'tlenecks',
#  'memcomputing',
#  'subvectors',
#  'expiry',
#  'maneuverability',
#  'telemetric',
#  'asteroid',
#  'Projection',
#  'eject',
#  'cavity',
#  'harmonization',
#  'currency',
#  'collect',
#  'mouse',
#  'neonate',
#  'facility',
#  'then',
#  'whose',
#  'strategic',
#  'chemist',
#  'Uncertainty',
#  'kinesthetic',
#  'with',
#  'borne',
#  'informetric',
#  'forums',
#  'misclassifications',
#  'Explaining',
#  'youth',
#  'insufficient',
#  'partitionier',
#  'plentiful',
#  'sub',
#  'intension',
#  'balance',
#  'decomposereconstruct',
#  'motorcycle',
#  'detour',
#  'parameterize',
#  'rethink',
#  'Algorithm',
#  'Codes',
#  'halting',
#  'tose',
#  'reweight',
#  'Effectively',
#  'nonplanar',
#  'quadrangulations',
#  'psycholinguistic',
#  'mentation',
#  'daylight',
#  'scopization',
#  'competitor',
#  'Navigating',
#  'doctor',
#  'elope',
#  'concession',
#  'complex',
#  'jitterywobbly',
#  'Note',
#  'parameterise',
#  'veracity',
#  'categorize',
#  'githubcomdcgymiroko',
#  'infrastructural',
#  'efficacious',
#  'retransmissions',
#  'addition',
#  'habitat',
#  'surroundings',
#  'Clustering',
#  'below',
#  'unrealcvgithubio',
#  'quantitative',
#  'accessibility',
#  'Adapting',
#  'unsatisfied',
#  'cumulatively',
#  'mediate',
#  'calculation',
#  'traditional',
#  'apt',
#  'perhaps',
#  'contradictory',
#  'gauge',
#  'fluobactrackerinrialpesfr',
#  'i',
#  'inductivecoinductive',
#  'directivity',
#  'fanbeam',
#  'ambiguously',
#  'harder',
#  'nonexistent',
#  'overlap',
#  'idealized',
#  'exert',
#  'ratifies',
#  'Work',
#  'predictor',
#  'eviction',
#  'authentic',
#  'Answer',
#  'eyeglasses',
#  'deception',
#  'workplace',
#  'morphologically',
#  'amateur',
#  'grown',
#  'astrobiology',
#  'version',
#  'Name',
#  'tradition',
#  'Gistable',
#  'multivalued',
#  'profound',
#  'ownership',
#  'burnouts',
#  'street',
#  'timelike',
#  'reducedsmall',
#  'elasticity',
#  'tenure',
#  'seam',
#  'matcher',
#  'unity',
#  'breakwater',
#  'counter',
#  'thinner',
#  'model',
#  'Chemical',
#  'shift',
#  'incapable',
#  'endurance',
#  'interarea',
#  'Partition',
#  'own',
#  'resampled',
#  'symbiotic',
#  'Volumetric',
#  'competences',
#  'stent',
#  'farmlands',
#  'Exhaustive',
#  'chirplet',
#  'metabolism',
#  'usable',
#  'corruption',
#  'Equipped',
#  'curvelet',
#  'ion',
#  'Weakly',
#  'fisheye',
#  'assessor',
#  'surgery',
#  'thickness',
#  'planer',
#  'facilitate',
#  'bitrates',
#  'actuatorslocations',
#  'thaliana',
#  'angle',
#  'Discovery',
#  'bounce',
#  'informs',
#  'mutationlearning',
#  'impressively',
#  'steady',
#  'Cryptocurrencies',
#  'Further',
#  'habit',
#  'Multicast',
#  'construe',
#  'Practical',
#  'see',
#  'ac',
#  'preset',
#  'Underlying',
#  'botnets',
#  'multithreaded',
#  'apparently',
#  'depart',
#  'deterrent',
#  'lowd',
#  'chromaticity',
#  'quilt',
#  'metascheduling',
#  'How',
#  'replicability',
#  'Modifications',
#  'computationaly',
#  'rover',
#  'openly',
#  'picocell',
#  'result',
#  'double',
#  'Integrated',
#  'macaque',
#  'impostor',
#  'inpatient',
#  'disproportionally',
#  'six',
#  'extent',
#  'redirection',
#  'webometric',
#  'inherent',
#  'arousal',
#  'bitangents',
#  'actionness',
#  'binarize',
#  'saw',
#  'differentiate',
#  'reserve',
#  'primer',
#  'mysterious',
#  'admits',
#  'perceptual',
#  'retinopathy',
#  'backhauled',
#  'affordances',
#  'restatement',
#  'piggyback',
#  'consequential',
#  'anatomic',
#  'Improving',
#  'representation',
#  'seal',
#  'verifier',
#  'documentary',
#  'survive',
#  'incomparability',
#  'gadget',
#  'speedups',
#  'synchrosqueezing',
#  ...}

# %%
len(words_pre)
# Out:
# 15852

# %%
'<pry>' in words_pre
# Out:
# True

# %% [markdown]
# pad: for padding
# unk: for word that didn't in our dicitonary

# %%
PAD_TOKEN = 0
UNK_TOKEN = 1
word_dict = {'<pad>':PAD_TOKEN,'<unk>':UNK_TOKEN}
for word in words_pre:
    word_dict[word]=len(word_dict)

# %%
import pickle
with open('other_data/dicitonary_words_pre_v9_partofspeech.pkl','wb') as f:
    pickle.dump(word_dict, f)

# %%
len(word_dict)
# Out:
# 15854

# %% [markdown]
# ### 資料格式化 (Data formatting)
# 有了字典後，接下來我們要把資料整理成一筆一筆，把input的句子轉成數字，把答案轉成onehot的形式。
# 這裡，我們一樣使用`multiprocessing`來加入進行。
# After building dictionary, that's mapping our sentences into number array, and convert answers to onehot format.

# %%
from tqdm import tqdm_notebook as tqdm
def label_to_onehot(labels):
    """ Convert label to onehot .
        Args:
            labels (string): sentence's labels.
        Return:
            outputs (onehot list): sentence's onehot label.
    """
    label_dict = {'BACKGROUND':0, 'OBJECTIVES':1, 'METHODS':2, 'RESULTS':3, 'CONCLUSIONS':4, 'OTHERS':5}
    onehot = [0,0,0,0,0,0]
    for l in labels.split('/'):
          onehot[label_dict[l]] = 1
    return onehot
        
def sentence_to_indices(sentence, word_dict):
    """ Convert sentence to its word indices.
    Args:
        sentence (str): One string.
    Return:
        indices (list of int): List of word indices.
    """
    # 這邊的字也要前處理~
    return [word_dict.get(word_preprocess(word), UNK_TOKEN) for word in word_tokenize(sentence)]
    
def get_dataset(data_path, word_dict, n_workers=4):
    """ Load data and return dataset for training and validating.

    Args:
        data_path (str): Path to the data.
    """
    dataset = pd.read_csv(data_path, dtype=str)

    results = [None] * n_workers
    with Pool(processes=n_workers) as pool:
        for i in range(n_workers):
            batch_start = (len(dataset) // n_workers) * i
            if i == n_workers - 1:
                batch_end = len(dataset)
            else:
                batch_end = (len(dataset) // n_workers) * (i + 1)
            
            batch = dataset[batch_start: batch_end]
            results[i] = pool.apply_async(preprocess_samples, args=(batch,word_dict))
        
        # 有with基本上不用這個
        pool.close()
        pool.join()

    processed = []
    for result in results:
        processed += result.get()
    return processed

def preprocess_samples(dataset, word_dict):
    """ Worker function.

    Args:
        dataset (list of dict)
    Returns:
        list of processed dict.
    """
    processed = []
    for sample in tqdm(dataset.iterrows(), total=len(dataset)):
        processed.append(preprocess_sample(sample[1], word_dict))

    return processed

def preprocess_sample(data, word_dict):
    """
    Args:
        data (dict)
    Returns:
        dict
    """
    processed = {}
    processed['Abstract'] = [sentence_to_indices(sent, word_dict) for sent in data['Abstract'].split('$$$')]
    if 'Task 1' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Task 1'].split(' ')]
    if 'Label' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Label'].split(' ')]
            
    return processed

# %%
print('[INFO] Start processing trainset...')
train = get_dataset('train_test_split_data/trainset.csv', word_dict, n_workers=4)
print('[INFO] Start processing validset...')
valid = get_dataset('train_test_split_data/validset.csv', word_dict, n_workers=4)

# private_testset
print('[INFO] Start processing private_testset...')
test = get_dataset('train_test_split_data/private_testset.csv', word_dict, n_workers=4)
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing private_testset...

# %% [markdown]
# #### Preprosses K-fold data

# %%
train_folds=[]
valid_folds=[]

for i in range(fold):
  print('[INFO] Start processing trainset...')
  train_folds.append(get_dataset("K_fold_data/" + "train_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
  print('[INFO] Start processing validset...')
  valid_folds.append(get_dataset("K_fold_data/" + "valid_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...

# %% [markdown]
# ## 資料封裝 (Data packing)

# %% [markdown]
# 為了更方便的進行batch training，我們將會借助[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)。
# 而要將資料放入dataloader，我們需要繼承[torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)，撰寫適合這份dataset的class。
# `collate_fn`用於batch data的後處理，在`dataloder`將選出的data放進list後會呼叫collate_fn，而我們會在此把sentence padding到同樣的長度，才能夠放入torch tensor (tensor必須為矩陣)。

# %% [markdown]
# To easily training in batch, we'll use `dataloader`, which is a function built in Pytorch[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)
# To use datalaoder, we need to packing our data into class `dataset` [torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)
# `collate_fn` is used for data processing.

# %%
from torch.utils.data import Dataset
import torch
class AbstractDataset(Dataset):
    def __init__(self, data, pad_idx, max_len = 500):
        self.data = data
        self.pad_idx = pad_idx
        self.max_len = max_len
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]
        
    def collate_fn(self, datas):
        # get max length in this batch
        max_sent = max([len(data['Abstract']) for data in datas])
        max_len = max([min(len(sentence), self.max_len) for data in datas for sentence in data['Abstract']])
        batch_abstract = []
        batch_label = []
        sent_len = []
        for data in datas:
            # padding abstract to make them in same length
            pad_abstract = []
            for sentence in data['Abstract']:
                if len(sentence) > max_len:
                    pad_abstract.append(sentence[:max_len])
                else:
                    pad_abstract.append(sentence+[self.pad_idx]*(max_len-len(sentence)))
            sent_len.append(len(pad_abstract))
            pad_abstract.extend([[self.pad_idx]*max_len]*(max_sent-len(pad_abstract)))
            batch_abstract.append(pad_abstract)
            # gather labels
            if 'Label' in data:
                pad_label = data['Label']
                pad_label.extend([[0]*6]*(max_sent-len(pad_label)))
                
                batch_label.append(pad_label)
        return torch.LongTensor(batch_abstract), torch.FloatTensor(batch_label), sent_len

# %%
trainData = AbstractDataset(train, PAD_TOKEN, max_len=64)
validData = AbstractDataset(valid, PAD_TOKEN, max_len=64)
testData = AbstractDataset(test, PAD_TOKEN, max_len=64)

# %%
trainData_folds = []
validData_folds = []

for i in range(fold):
    trainData_folds.append(AbstractDataset(train_folds[i], PAD_TOKEN, max_len=64))
    validData_folds.append(AbstractDataset(valid_folds[i], PAD_TOKEN, max_len=64))

# %% [markdown]
# # Model

# %% [markdown]
# 資料處理完成後，接下來就是最重要的核心部分：`Model`。
# 此次範例中我們以簡單的一層RNN + 兩層Linear layer作為示範。
# 而為了解決每次的句子長度不一的問題(`linear layer必須是fixed input size`)，因此我們把所有字的hidden_state做平均，讓這一個vector代表這句話。

# %% [markdown]
# In this tutorial, we're going to implement a simple model, which contain one RNN layer and two fully connected layers (Linear layer). Of course you can make it "deep".
# To solve variant sentence length problem (`input size in linear layer must be fixed`), we can average all hidden_states, and become one vector. (Perfect!)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class simpleNet(nn.Module):
    def __init__(self, vocabulary_size):
        super(simpleNet, self).__init__()
        self.embedding_size = 200  # 改embedding
        self.hidden_dim = 512
        self.embedding = nn.Embedding(vocabulary_size, self.embedding_size)
        
        self.sent_lstm = nn.LSTM(self.embedding_size,
                                 self.hidden_dim,
                                 num_layers=1,
                                 bidirectional=True,
                                 batch_first=True,
                                 # dropout=0.5
                                 )
        self.sent_gru = nn.GRU(self.hidden_dim * 2,
                               self.hidden_dim,
                               num_layers=1,
                               bidirectional=True,
                               batch_first=True,
                               # dropout=0.2
                              )
        # 加上LSTM & dropout試試看 & batch norm
        self.batch_norm = nn.BatchNorm1d(self.hidden_dim, momentum=0.5)
        self.l1 = nn.Linear(self.hidden_dim * 2, self.hidden_dim)
        self.l2 = nn.Linear(self.hidden_dim, 6)
        self.dropout = nn.Dropout(0.5)

        # orthogonal initialization
        # for weight in self.sent_lstm.parameters():
        #     if len(weight.size()) > 1:
        #         # print(123)
        #         nn.init.orthogonal_(weight.data)

        # for weight in self.sent_gru.parameters():
        #     if len(weight.size()) > 1:
        #         # print(456)
        #         nn.init.orthogonal_(weight.data)
        
        # # bias initialization
        # for names in self.sent_lstm._all_weights:
        #     for name in filter(lambda n: "bias" in n,  names):
        #         bias = getattr(self.sent_lstm, name)
        #         n = bias.size(0)
        #         start, end = n//4, n//2
        #         bias.data[start:end].fill_(0.)

        # for names in self.sent_gru._all_weights:
        #     for name in filter(lambda n: "bias" in n,  names):
        #         bias = getattr(self.sent_gru, name)
        #         n = bias.size(0)
        #         start, end = n//4, n//2
        #         bias.data[start:end].fill_(0.)

    def forward(self, x):
        x = self.embedding(x)
        # https://discuss.pytorch.org/t/spatial-dropout-in-pytorch/21400
        # https://pytorch.org/docs/stable/nn.html#dropout2d
        # Spatial Dropout after embedding layer
        # x = F.dropout2d(x.permute(0, 2, 1, 3), 0.5).permute(0, 2, 1, 3)
        batch_size, sent_len, word_dim, embed_dim = x.shape
        x = x.view(batch_size, sent_len * word_dim, embed_dim)  # batch, time, features
        x, __ = self.sent_lstm(x)
        # x, __ = self.sent_lstm2(x)
        x, __ = self.sent_gru(x)
        x = x.view(batch_size, sent_len, word_dim, -1)
        x = torch.max(x, dim=2)[0]  # 選整句最大值
        # x = torch.mean(x, dim=2, keepdim=True).squeeze()  # 改成平均
        x = torch.relu(self.l1(x))
        # x = x.permute(0, 2, 1)
        # x = self.batch_norm(x)  # 加一個channel維度?
        # x = x.permute(0, 2, 1)
        # x = self.dropout(x)
        x = torch.sigmoid(self.l2(x))
        return x

# %% [markdown]
# # Training

# %% [markdown]
# 指定使用的運算裝置
# Designate running device.

# %%
import torch

device='cuda' #'cuda'
SEED = 666
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

# %% [markdown]
# 定義一個算分公式, 讓我們在training能快速了解model的效能
# Define score function, let us easily observe model performance while training.

# %%
class F1():
    def __init__(self):
        self.threshold = 0.5
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0
        self.name = 'F1'

    def reset(self):
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0

    def update(self, predicts, groundTruth):
        predicts = predicts > self.threshold
        self.n_precision += torch.sum(predicts).data.item()
        self.n_recall += torch.sum(groundTruth).data.item()
        self.n_corrects += torch.sum(groundTruth.type(torch.uint8) * predicts).data.item()

    def get_score(self):
        recall = self.n_corrects / self.n_recall
        precision = self.n_corrects / (self.n_precision + 1e-20) #prevent divided by zero
        return 2 * (recall * precision) / (recall + precision + 1e-20)

    def print_score(self):
        score = self.get_score()
        return '{:.5f}'.format(score)

# %%
import os
import sys

def _run_epoch(data, epoch, training):
    model.train(training)
    if training:
        description = 'Train'
        # dataset = trainData
        dataset = data
        shuffle = True
    else:
        description = 'Valid'
        # dataset = validData
        dataset = data
        shuffle = False
    dataloader = DataLoader(dataset=dataset,
                            batch_size=64,
                            shuffle=shuffle,
                            collate_fn=dataset.collate_fn,
                            num_workers=4)

    trange = tqdm(enumerate(dataloader), total=len(dataloader), desc=description)
    loss = 0
    f1_score = F1()
    for i, (x, y, sent_len) in trange:
        o_labels, batch_loss = _run_iter(x,y)
        if training:
            opt.zero_grad()
            batch_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
            opt.step()

        loss += batch_loss.item()
        f1_score.update(o_labels.cpu(), y)

        trange.set_postfix(
            loss=loss / (i + 1), f1=f1_score.print_score())
    if training:
        history['train'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})
    else:
        history['valid'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})

def _run_iter(x, y):
    abstract = x.to(device)
    labels = y.to(device)
    # o_labels = model(abstract)
    o_labels = model(abstract)
    l_loss = criteria(o_labels, labels)
    return o_labels, l_loss

def save(epoch, name, cv=False):
    if not os.path.exists('model'):
        os.makedirs('model')
    if not os.path.exists('model/cv'):
        os.makedirs('model/cv')
    if cv:
      torch.save(model.state_dict(), 'model/cv/model_cv_' + name + '.pkl.'+str(epoch))
      with open('model/cv/history_cv_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)
    else:
      torch.save(model.state_dict(), 'model/model_' + name + '.pkl.'+str(epoch))
      with open('model/history_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)

# %% [markdown]
# ## Run Model

# %% [markdown]
# #### 這邊直接run cv mode即可! -> 每次的model_name要調整喔

# %%
model_name = "Private_set_LSTM_GRU_WORD_PRE_v8(15852_words)_ensembling_seed666"

# %%
from torch.utils.data import DataLoader
from tqdm import trange
import json

torch.cuda.set_device(0)

mode = "cv" #cv, train

vaild_f1 = 0

if mode == "cv":
  overall_F1 = []
  for i in range(fold):
    model = simpleNet(len(word_dict))
    # opt = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.5)
    opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
    criteria = torch.nn.BCELoss() 
    model.to(device)
    max_epoch = 5
    history = {'train' : [], 'valid' : []}

    for epoch in range(max_epoch):
        print('CV_' + str(i) + ',', 'Epoch: {}'.format(epoch))
        _run_epoch(trainData_folds[i], epoch, True)
        _run_epoch(validData_folds[i], epoch, False)
        
        save(epoch, model_name + "_" + str(i), cv=True)

        print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

        if epoch > 1:
            overall_F1.append(np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

  print("Final average validation F1 score:", np.mean(overall_F1))
    
else:
  model = simpleNet(len(word_dict))
  opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
  criteria = torch.nn.BCELoss()
  model.to(device)
  max_epoch = 5
  history = {'train' : [], 'valid' : []}

  for epoch in range(max_epoch):
      print('Epoch: {}'.format(epoch))
      _run_epoch(trainData, epoch, True)
      _run_epoch(validData, epoch, False)
      save(epoch, model_name, cv=False)

      print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))
# Out:
# CV_0, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5507589622133706
# CV_0, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5874009998321146
# CV_0, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6449537289139572
# CV_0, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6695688170659433
# CV_0, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6687083200248258
# CV_1, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5669781931464175
# CV_1, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6032700962690416
# CV_1, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6446790442425232
# CV_1, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6553415929337871
# CV_1, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6618110014058891
# CV_2, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6070607896386045
# CV_2, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6309347381491885
# CV_2, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6603354644963015
# CV_2, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6691990831174373
# CV_2, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6754089668132588
# CV_3, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5755900489049544
# CV_3, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6164109032038573
# CV_3, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6602844140688808
# CV_3, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6651664614482532
# CV_3, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6712501436958173
# CV_4, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5566965733434224
# CV_4, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5960348766320003
# CV_4, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6456953209851924
# CV_4, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6569534546429937
# CV_4, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6631783495465171
# CV_5, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5967863690283619
# CV_5, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6296338422122377
# CV_5, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6687637990797191
# CV_5, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6677040624342938
# CV_5, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6675208225304641
# CV_6, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5736792353744354
# CV_6, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.60049948991113
# CV_6, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6320839499749835
# CV_6, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.650340653811168
# CV_6, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6610036248923686
# CV_7, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5837803046556532
# CV_7, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6140489483838723
# CV_7, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6515018906345973
# CV_7, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6609062208310568
# CV_7, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.665749813924817
# CV_8, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5694594012491924
# CV_8, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6007117221569469
# CV_8, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6431830727807082
# CV_8, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6565733851910753
# CV_8, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6653255786021295
# CV_9, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5571683787405092
# CV_9, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5818559123360503
# CV_9, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6300105174016535
# CV_9, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6556417695917722
# CV_9, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6575856159404662
# Final average validation F1 score: 0.658214298034095

# %%
# # memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
# import psutil
# import humanize
# import os
# import GPUtil as GPU
# GPUs = GPU.getGPUs()
# # XXX: only one GPU on Colab and isn’t guaranteed
# gpu = GPUs[0]
# def printm():
#  process = psutil.Process(os.getpid())
#  print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
#  print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7410 sha256=a2d914a4a5f46a92d54b6974ca14d40eb698ec1b8213470278b5fd9129837b56
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.8)
# Requirement already satisfied: humanize in /usr/local/lib/python3.6/dist-packages (0.5.1)
# Gen RAM Free: 2.8 GB  | Proc size: 3.6 GB
# GPU RAM Free: 30MB | Used: 7581MB | Util 100% | Total 7611MB

# %%
import numpy as np
def SubmitGenerator(prediction, sampleFile, public=True, filename='prediction.csv'):
    sample = pd.read_csv(sampleFile)
    submit = {}
    submit['order_id'] = list(sample.order_id.values)
    redundant = len(sample) - prediction.shape[0]
    if public:
        submit['BACKGROUND'] = list(prediction[:,0]) + [0]*redundant
        submit['OBJECTIVES'] = list(prediction[:,1]) + [0]*redundant
        submit['METHODS'] = list(prediction[:,2]) + [0]*redundant
        submit['RESULTS'] = list(prediction[:,3]) + [0]*redundant
        submit['CONCLUSIONS'] = list(prediction[:,4]) + [0]*redundant
        submit['OTHERS'] = list(prediction[:,5]) + [0]*redundant
    else:
        submit['BACKGROUND'] = [0]*redundant + list(prediction[:,0])
        submit['OBJECTIVES'] = [0]*redundant + list(prediction[:,1])
        submit['METHODS'] = [0]*redundant + list(prediction[:,2])
        submit['RESULTS'] = [0]*redundant + list(prediction[:,3])
        submit['CONCLUSIONS'] = [0]*redundant + list(prediction[:,4])
        submit['OTHERS'] = [0]*redundant + list(prediction[:,5])
    df = pd.DataFrame.from_dict(submit) 
    df.to_csv(filename,index=False)

# %%
os.getcwd()
# Out:
# '/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder'

# %%
# SubmitGenerator(prediction,
#                 'raw_data/task1_sample_submission.csv', 
#                 True,
#                 'submission/submission_6_emb200_word_pre_gru_2_layers.csv')

# %% [markdown]
# ## 把cv模型load出來predict平均 (config, 基本上前面都run過這裡應該不用run了)

# %%
# device='cuda'
# fold = 10
# model = simpleNet(len(word_dict))
# opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
# criteria = torch.nn.BCELoss() 
# model.to(device)
# max_epoch = 5

# %% [markdown]
# ### Apply simple CV emsembling based on validation scores
# ### 記得prediction_sum的維度要改成:
# **(len(task1_sample_submission.csv)-131166, 6)**

# %%
sample_sub = pd.read_csv("raw_data/task1_sample_submission.csv", index_col=None)
sample_sub.shape
# Out:
# (262948, 7)

# %%
from torch.utils.data import DataLoader

def softmax(x):
    exp_x = np.exp(x)
    softmax_x = exp_x / np.sum(exp_x)
    return softmax_x 

sample_sub = pd.read_csv("raw_data/task1_sample_submission.csv", index_col=None)

prediction_sum = np.zeros((len(sample_sub)-131166, 6))  # --> 這邊要改
n_digits = 3
model_nums = 0

# 先讀取cv中每個模型所記錄的validation分數 (取出epoch 3 & 4 -> strated from 0)
# it will be ordered as cv_0_epoch_3 cv_0_epoch_4 ...
valid_scores = {}
for i in range(fold):
    score = pd.read_json("model/cv/history_cv_" + model_name + "_" + str(i) + ".json")
    valid_scores[str(i) + "_3"] = score["valid"].iloc[3]["f1"]
    valid_scores[str(i) + "_4"] = score["valid"].iloc[4]["f1"]

# 利用softmax算出每個模型佔的權重並塞進字典
model_weights_values = softmax(list(valid_scores.values()))
model_ensembling_weights_dict = {key:value for key, value in zip(valid_scores.keys(), model_weights_values)}


for cv in range(fold):
    for ep in range(max_epoch):
        if (ep == 3) or (ep == 4): # 只取epoch 3 & 4 的模型 (started from 0)
            dataloader = DataLoader(dataset=testData,
                                  batch_size=64,
                                  shuffle=False,  # for sent len不要亂
                                  collate_fn=testData.collate_fn,
                                  num_workers=4)
            trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')

            model.load_state_dict(torch.load('model/cv/model_cv_' + model_name + '_' + str(cv) + '.pkl.' + str(ep) + ''))
            model.train(False)
            prediction = []
            for i, (x, y, sent_len) in trange:
                with torch.no_grad(): # 避免記憶體爆掉，先將grad都設為false
                    o_labels = model(x.to(device))  
                    o_labels = (o_labels * 10 ** n_digits).round() / (10 ** n_digits)
                    # o_labels = o_labels.to('cpu')
                    # o_labels = o_labels > 0.4
                    for idx, o_label in enumerate(o_labels):
                        prediction.append(o_label[:sent_len[idx]].to('cpu'))
            prediction = torch.cat(prediction).detach().numpy() # .astype(int)
            
            # 在這裡直接乘上權重
            prediction_sum += prediction * model_ensembling_weights_dict[str(cv) + "_" + str(ep)]
            model_nums += 1

final_prediction = prediction_sum # / model_nums
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…

# %%
SubmitGenerator(final_prediction,
                'raw_data/task1_sample_submission.csv', 
                False,  # Private set的話這邊要改False喔!!!!
                # 下面名字自己改
                'submission/submission(ensembling)_' + model_name + '_cv_avg_origin_prob.csv')

# %% [markdown]
# # 跑到這裡即可 -------------- end ---------------------

# %% [markdown]
# ## Predict (no cv model)

# %%
from torch.utils.data import DataLoader
model.train(False)
dataloader = DataLoader(dataset=testData,
                            batch_size=64,
                            shuffle=False,  # for sent len不要亂
                            collate_fn=testData.collate_fn,
                            num_workers=4)
trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')
prediction = []
for i, (x, y, sent_len) in trange:
    o_labels = model(x.to(device))
    o_labels = o_labels > 0.4
    for idx, o_label in enumerate(o_labels):
        prediction.append(o_label[:sent_len[idx]].to('cpu'))
prediction = torch.cat(prediction).detach().numpy().astype(int)
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…

# %% [markdown]
# # Plot Learning Curve

# %%
import matplotlib.pyplot as plt
import json
# %matplotlib inline

with open('model/history_train.json', 'r') as f:
    history = json.loads(f.read())
    
train_loss = [l['loss'] for l in history['train']]
valid_loss = [l['loss'] for l in history['valid']]
train_f1 = [l['f1'] for l in history['train']]
valid_f1 = [l['f1'] for l in history['valid']]

plt.figure(figsize=(7,5))
plt.title('Loss')
plt.plot(train_loss, label='train')
plt.plot(valid_loss, label='valid')
plt.legend()
plt.show()

plt.figure(figsize=(7,5))
plt.title('F1 Score')
plt.plot(train_f1, label='train')
plt.plot(valid_f1, label='valid')
plt.legend()
plt.show()

print('Best F1 score ', max([[l['f1'], idx] for idx, l in enumerate(history['valid'])]))
# Out:
# Best F1 score  [0.6734478456961903, 4]
