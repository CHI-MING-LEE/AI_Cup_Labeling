# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# from google.colab import auth
# auth.authenticate_user()
# from oauth2client.client import GoogleCredentials
# creds = GoogleCredentials.get_application_default()
# import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
# vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p Drive
# !google-drive-ocamlfuse Drive

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/Drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from itertools import product

os.chdir('/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder')
os.getcwd()
# Out:
# '/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder'

# %% [markdown]
# # Runtime Environment
# * python >= 3.6
# * pytorch >= 1.0
# * pandas
# * nltk
# * numpy
# * sklearn
# * pickle
# * tqdm
# * json

# %% [markdown]
# # Data processing

# %% [markdown]
# ## 刪除多於資訊 (Remove redundant information)
# 我們在資料集中保留了許多額外資訊供大家使用，但是在這次的教學中我們並沒有用到全部資訊，因此先將多餘的部分先抽走。
# In dataset, we reserved lots of information. But in this tutorial, we don't need them, so we need to discard them.

# %%
import pandas as pd

dataset = pd.read_csv('raw_data/task1_trainset.csv', dtype=str)
dataset.head()
# Out:
#        Id  ...                                             Task 1
# 0  D00001  ...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1  D00002  ...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2  D00003  ...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3  D00004  ...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4  D00005  ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
#
# [5 rows x 7 columns]

# %%
dataset["Categories"].value_counts()
# Out:
# cs.CV                         821
# cs.CL                         334
# cs.IT/math.IT                 323
# cs.NI                         198
# cs.LG/stat.ML                 191
#                              ...
# quant-ph/cs.DS/cs.ET/cs.SE      1
# cs.AI/cs.IR/stat.ML             1
# math.LO/cs.AI/cs.LO             1
# cs.CV/math.DS                   1
# cs.MM/cs.IT/math.IT             1
# Name: Categories, Length: 1729, dtype: int64

# %%
dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)

# %% [markdown]
# ## 資料切割  (Partition)
# 在訓練時，我們需要有個方法去檢驗訓練結果的好壞，因此需要將訓練資料切成training/validataion set。
#
# **- Need 5-fold cv to validate training result**

# %%
from sklearn.model_selection import StratifiedKFold, KFold

trainset_folds = []
trainset_folds = []

valset_folds = []
valset_folds = []

tmp_train = {}
tmp_val = {}

X = dataset["Abstract"]
y = dataset["Task 1"]

# 用GROUP K-FOLD分類別? 先改用K-Fold

stratified_folder = KFold(n_splits=10, random_state=42, shuffle=False)
for i, (train_index, val_index) in enumerate(stratified_folder.split(X, y)):

    tmp_train['Abstract'] = X[train_index]
    tmp_train['Label'] = y[train_index]

    tmp_val['Abstract'] = X[val_index]
    tmp_val['Label'] = y[val_index]

    # 有一個split會反過來 (Stratified K-Fold)
    # if i == 0:
    #   continue

    trainset_folds.append(pd.DataFrame(data=tmp_train))
    valset_folds.append(pd.DataFrame(data=tmp_val))

    # print("Stratified Train Index:", train_index)
    # print("Stratified Test Index:", test_index)
    # print("Stratified y_train:", y[train_index])
    # print("Stratified y_test:", y[test_index],'\n')

# train_test_split(dataset, test_size=0.2, random_state=42)

# %%
trainset_folds[9]
# Out:
#                                                Abstract                                              Label
# 0     Rapid popularity of Internet of Things (IoT) a...  BACKGROUND OBJECTIVES METHODS METHODS RESULTS ...
# 1     In this paper, we address the problem of compu...  OBJECTIVES OTHERS METHODS/RESULTS RESULTS RESULTS
# 2     High quality upsampling of sparse 3D point clo...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 3     Internet is the main source of information now...  BACKGROUND BACKGROUND BACKGROUND OBJECTIVES OB...
# 4     Automated Facial Expression Recognition (FER) ...  BACKGROUND BACKGROUND BACKGROUND BACKGROUND ME...
# ...                                                 ...                                                ...
# 6295  Activity detection is a fundamental problem in...  BACKGROUND BACKGROUND OBJECTIVES METHODS METHO...
# 6296  We address the problem of using hand-drawn ske...  BACKGROUND/OBJECTIVES METHODS METHODS METHODS ...
# 6297  This article extends the Generalized Asypmtoti...                         OBJECTIVES METHODS RESULTS
# 6298  We consider generation and comprehension of na...  BACKGROUND OBJECTIVES METHODS METHODS METHODS ...
# 6299  The task of classifying videos of natural dyna...  BACKGROUND BACKGROUND OBJECTIVES METHODS CONCL...
#
# [6300 rows x 2 columns]

# %%
def save_k_fold_data(data, name="train_data_fold", fold=5):
  """
  X_data: list of DF
  y_data: list of DF
  """
  for i in range(fold):
    data[i].to_csv("K_fold_data/" + name + "_" + str(i) + ".csv", index=None)
fold=10
save_k_fold_data(data=trainset_folds, name="train_data_fold", fold=fold)
save_k_fold_data(data=valset_folds, name="valid_data_fold", fold=fold)

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
trainset, validset = train_test_split(dataset, test_size=0.1, random_state=42)

trainset.to_csv('train_test_split_data/trainset.csv',index=False)
validset.to_csv('train_test_split_data/validset.csv',index=False)

# %%
trainset
# Out:
#           Id  ...                                             Task 1
# 5944  D05945  ...  BACKGROUND BACKGROUND BACKGROUND/OBJECTIVES ME...
# 5129  D05130  ...  BACKGROUND BACKGROUND OBJECTIVES/METHODS METHO...
# 1149  D01150  ...  BACKGROUND OBJECTIVES OBJECTIVES METHODS METHO...
# 6783  D06784  ...  CONCLUSIONS METHODS BACKGROUND BACKGROUND BACK...
# 6832  D06833  ...  BACKGROUND OBJECTIVES/METHODS METHODS METHODS/...
# ...      ...  ...                                                ...
# 3772  D03773  ...  OBJECTIVES BACKGROUND OTHERS BACKGROUND BACKGR...
# 5191  D05192  ...  OBJECTIVES OBJECTIVES OBJECTIVES OBJECTIVES OB...
# 5226  D05227  ...                 OBJECTIVES METHODS/RESULTS RESULTS
# 5390  D05391  ...  BACKGROUND BACKGROUND OBJECTIVES METHODS METHO...
# 860   D00861  ...  BACKGROUND METHODS METHODS RESULTS METHODS RES...
#
# [6300 rows x 3 columns]

# %%
trainset.iloc[100]["Abstract"].split("$$$")
# Out:
# ['We present a new family of one-coincidence sequence sets suitable for frequency hopping code division multiple access (FH-CDMA) systems with dispersed (low density) sequence elements.',
#  'These sets are derived from one-coincidence prime sequence sets, such that for each one-coincidence prime sequence set there is a new one-coincidence set comprised of sequences with dispersed sequence elements, required in some circumstances, for FH-CDMA systems.',
#  'Getting rid of crowdedness of sequence elements is achieved by doubling the size of the sequence element alphabet.',
#  'In addition, this doubling process eases control over the distance between adjacent sequence elements.',
#  'Properties of the new sets are discussed.']

# %%
trainset.iloc[100]["Task 1"]
# Out:
# 'RESULTS METHODS OBJECTIVES/METHODS OBJECTIVES RESULTS'

# %% [markdown]
# ### For test data

# %%
dataset = pd.read_csv('raw_data/task1_public_testset.csv', dtype=str)
dataset.drop('Title',axis=1,inplace=True)
dataset.drop('Categories',axis=1,inplace=True)
dataset.drop('Created Date',axis=1, inplace=True)
dataset.drop('Authors',axis=1,inplace=True)
dataset.to_csv('train_test_split_data/testset.csv',index=False)

# %% [markdown]
# ### 統計單字 (Count words)
# 在訓練時，不能直接將單字直接餵入model，因為它只看得懂數字，因此我們必須把所有的單字抽取出來，並將它們打上編號，做出一個字典來對它們做轉換。
# We can't feed "word" into model directly, since it can only recognize number. So, we need to know the total number of word, and give every word a unique number.

# %% [markdown]
# 在這裡，我們需要借助`nltk`這個library來幫忙做文字切割。當然，你也可以選擇自己寫規則來切割(通常上不建議搞死自己)。
# 另外，我們也使用了`multiprocessing`來加速處理。
# In here, we split words by using `nltk library`. You can write your own rules and split it by yourself, but you won't want to do that, trust me.
# Also, we use `multiprocessing` to accelerate the process.

# %%
import pandas as pd
from multiprocessing import Pool
from nltk.tokenize import word_tokenize
def collect_words(data_path, n_workers=4):
    df = pd.read_csv(data_path, dtype=str)
        
    sent_list = []
    for i in df.iterrows():
        sent_list += i[1]['Abstract'].split('$$$')

    chunks = [
        ' '.join(sent_list[i:i + len(sent_list) // n_workers])
        for i in range(0, len(sent_list), len(sent_list) // n_workers)
    ]
    with Pool(n_workers) as pool:
        chunks = pool.map_async(word_tokenize, chunks)
        words = set(sum(chunks.get(), []))

    return words

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
words = set()
words |= collect_words('raw_data/task1_trainset.csv')

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))

words = set([w.lower() for w in words])

words = words - set(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
import string
import re

def word_preprocess(word):
  # remove numbers
  if '-' not in word:
    word = re.sub(r'\d+', '', word)

  # remove punctuations
  word = word.translate(str.maketrans('', '', string.punctuation))

  # lemmatization
  # lemma = nltk.wordnet.WordNetLemmatizer()
  # word = lemma.lemmatize(word)

  # remove single character
  if len(list(word)) < 2:
    word = ""

  return word

# %%
lemma = nltk.wordnet.WordNetLemmatizer()
lemma.lemmatize('investigated')
lemma.lemmatize('was')
# Out:
# 'wa'

# %%
with Pool() as pool:
  result = pool.map(word_preprocess, words)

words_pre = set(result)
words_pre = words_pre - {''}
words_pre
# Out:
# {'matejka',
#  'pircsi',
#  'individually',
#  'orientable',
#  'filterbank',
#  'nt',
#  'baggingboosting',
#  'trifocal',
#  'duplex',
#  'wbsn',
#  'fitnesslinked',
#  'boundary',
#  'psychometrika',
#  'decides',
#  'leftinvariant',
#  'lexemes',
#  'hasting',
#  'playing',
#  'supermodular',
#  'iva',
#  'tosophisticated',
#  'tightened',
#  'cuttlefish',
#  'peano',
#  'hardelish',
#  'tubempc',
#  'frequencydependent',
#  'digitaldomain',
#  'affinevarying',
#  'invited',
#  'biophysicallyinspired',
#  'recstep',
#  'ssignal',
#  'gror',
#  'damping',
#  'dynamicallyintroduced',
#  'canvas',
#  'constanttoconstant',
#  'scrutinize',
#  'proposes',
#  'homes',
#  'idealized',
#  'ncclbased',
#  'nrflthe',
#  'preisis',
#  '8thfive',
#  'population',
#  'diseases',
#  'rmnns',
#  'nonplayer',
#  'accept',
#  'foveated',
#  'nodetopic',
#  'carliniwagner',
#  'eventb',
#  'evaluate',
#  'rfidbased',
#  'nullspace',
#  'therapists',
#  'roblot',
#  'unprecedented',
#  'multibody',
#  'fluctuation',
#  'antiisis',
#  'neverending',
#  'socalled',
#  'she',
#  'switching',
#  'raf',
#  'nielsen',
#  '294fold',
#  'skillset',
#  'centrist',
#  'crossed',
#  'precursor',
#  'stateless',
#  'contradiction',
#  'conceived',
#  'jamali',
#  'salomaa',
#  'cognitively',
#  'radiomicsdriven',
#  'bonomo',
#  'antijamming',
#  'oocytes',
#  'hurricane',
#  'ytf',
#  'apoe',
#  'inattention',
#  'kshell',
#  'satire',
#  'zalando',
#  'clientserver',
#  'look',
#  'curating',
#  'hypergeometric',
#  '1bit',
#  'perseverance',
#  'constructed',
#  'spitkovsky',
#  'targets',
#  'tools',
#  'eyeblink',
#  'complexityperformance',
#  'shipped',
#  'sigmalogpsim',
#  'agentcentric',
#  'securityprivacy',
#  'fsa',
#  'newsroom',
#  'vplane',
#  'aircloak',
#  'occurrences',
#  'treelevel',
#  'notoriouslyhard',
#  'phoc',
#  'warn',
#  'virtualworld',
#  'postictal',
#  'shearlets',
#  'aluminum',
#  'diffeomorphisms',
#  'rapidlyexploring',
#  'convnet',
#  'classicalentanglement',
#  'slowing',
#  'eventbased',
#  'nation',
#  'keysounds',
#  'autocompletes',
#  'reshaping',
#  'tunings',
#  'reducedorder',
#  'idft',
#  'provenance',
#  'termdocument',
#  'computersupported',
#  'localizations',
#  'parttime',
#  'paritycheck',
#  'proofoflocation',
#  'dwmbased',
#  'classconditional',
#  'kharitonov',
#  'engages',
#  'regularisation',
#  'nonsparse',
#  'direction',
#  'ethereum',
#  'polyadic',
#  'polyp',
#  'ridethrough',
#  'bpso',
#  'vertical',
#  'floors',
#  'exemplify',
#  'unetbased',
#  'armv8m',
#  'contextoriented',
#  'stylized',
#  'highlytailored',
#  'nontransfer',
#  'spectrumblind',
#  'straight',
#  'sesr',
#  'historyregister',
#  'shedding',
#  'ascendancy',
#  'inhospital',
#  '3gram',
#  'uniquenesses',
#  'texttospeech',
#  'monads',
#  'downtown',
#  'tmm',
#  'cnlbased',
#  'postulating',
#  'expertdesigned',
#  'nowadays',
#  'bmc',
#  'karc',
#  'subarrays',
#  'ultrareliable',
#  'heads',
#  'reinforcement',
#  'glms',
#  'photovoltaic',
#  'loses',
#  'spdm',
#  'steinchernoff',
#  'governing',
#  'rsquared',
#  'test',
#  'kagan',
#  'levenshtein',
#  'reorganized',
#  'ambient',
#  'studentuser',
#  'copula',
#  'genomic',
#  'prosecution',
#  'primacy',
#  'darksight',
#  'coroutine',
#  'soms',
#  'hyperbolas',
#  'european',
#  'fieldwork',
#  'demanddriven',
#  'hyperfeatures',
#  'cgan',
#  'supraconstant',
#  'vsmhmms',
#  'swipt',
#  'udsfs',
#  'classpreserving',
#  'equiwidth',
#  'cookie',
#  'biplane',
#  'antileaks',
#  'tell',
#  'toeplitzmatrix',
#  '3dstacked',
#  'parsers',
#  'voxels',
#  'linux',
#  'outsourcing',
#  'outback',
#  'involved',
#  'neurophysiology',
#  'crlb',
#  'delivering',
#  'solicit',
#  'hololens',
#  'devanur',
#  'mirror',
#  'dtsp',
#  'reducedcomplexity',
#  'spreadsheet',
#  'inaccessible',
#  'reshuffling',
#  'creep',
#  'ethical',
#  'vbl',
#  'prism',
#  'libratus',
#  'cutelimination',
#  'especially',
#  'icerestoring',
#  'injects',
#  'fallout',
#  'grids',
#  'deceiving',
#  'answerdependent',
#  'visiting',
#  'ostrovsky',
#  'sinr',
#  'countriesproducts',
#  'pressing',
#  'quasicyclic',
#  'present',
#  'rectifier',
#  'columnwise',
#  'multiset',
#  'regionthe',
#  'unit',
#  'stamp',
#  'conj',
#  'hence',
#  'selforganized',
#  'probabilistic',
#  'dexter',
#  'phenomenon',
#  'isotropic',
#  'interviews',
#  'topography',
#  'crysl',
#  'simulable',
#  'fosmidbased',
#  'mined',
#  'ues',
#  'ambition',
#  'discord',
#  'tibia',
#  'faultfinding',
#  'establishits',
#  'unicycle',
#  'nephrology',
#  'docsis',
#  'syntheticlooking',
#  'devclean',
#  'vegetationlandscape',
#  'irestnet',
#  'obfuscating',
#  'sideinformation',
#  'hypergraphs',
#  'kicks',
#  'authenticates',
#  'pestspecific',
#  'globalshutter',
#  'codecoverage',
#  'pec',
#  'stringsource',
#  'noncompetitive',
#  'secret',
#  'repairman',
#  'signify',
#  'weld',
#  'compressed',
#  'intend',
#  'electroluminescence',
#  'tomato',
#  'bangla',
#  'discusses',
#  'theorycentric',
#  'unique',
#  'hsm',
#  'kappa',
#  'backgrounds',
#  'pseudometrics',
#  'miou',
#  'grapheme',
#  'alveolar',
#  'hoc',
#  'gradually',
#  'grounded',
#  'cohesiveness',
#  'formalised',
#  'rins',
#  'multitenancy',
#  'succeeded',
#  'exposing',
#  'corrolary',
#  'cs',
#  'spanish',
#  'haar',
#  'mavs',
#  'subprograms',
#  'established',
#  'interpersonally',
#  'bto',
#  'dsrnet',
#  'afra',
#  'unedited',
#  'send',
#  'paid',
#  'replaces',
#  'crucial',
#  'zynq',
#  'oaipmh',
#  'homologous',
#  'parallelizability',
#  'proper',
#  'tpot',
#  'spilling',
#  'certify',
#  'sun',
#  'pseudocosts',
#  'analysis',
#  'overthink',
#  'average',
#  'must',
#  'skipping',
#  'dualmoleculebased',
#  'lizorkin',
#  'searchretrieval',
#  'phish',
#  'lowconfidence',
#  'timelapse',
#  'loop',
#  'chaining',
#  'rampshape',
#  'fueled',
#  'multiaction',
#  'silent',
#  'controlling',
#  'githubcomdcgymiroko',
#  'nonfungible',
#  'offsets',
#  'deletion',
#  'declared',
#  'finitestate',
#  'enclosing',
#  'replicationbased',
#  'haars',
#  'timehorizon',
#  'localist',
#  'bacterial',
#  'coherencebased',
#  'detailed',
#  'immediacy',
#  'architectureenhanced',
#  'mspec',
#  'create',
#  'catalunya',
#  'preferentialattachmenttype',
#  'addressing',
#  'mmpe',
#  'trivia',
#  'visualisation',
#  'preprocess',
#  'acks',
#  'restarting',
#  'aoptimal',
#  'bz',
#  'indicatorbased',
#  'unparalleled',
#  'cloudshadow',
#  'qos',
#  'freeze',
#  'softly',
#  'vein',
#  'controllyapunov',
#  'summons',
#  'airfoils',
#  'whitepaper',
#  'fog',
#  'hiv',
#  'logarithmicsize',
#  'classifierregressor',
#  'conceptories',
#  'raidnc',
#  'viruses',
#  'synoptic',
#  'pessimistic',
#  'emergence',
#  'intentionnet',
#  'autumn',
#  'pajek',
#  'acceleratinghindering',
#  'teach',
#  'selfmonitor',
#  'lago',
#  'utilizes',
#  'palliate',
#  'pypy',
#  'gpower',
#  'ipnsaf',
#  'chattering',
#  'interactse',
#  'conservancy',
#  'meteorpl',
#  'appointed',
#  'lengthening',
#  'hypergroups',
#  'retraction',
#  'inkling',
#  'lategadolinium',
#  'conductivity',
#  'rangedependent',
#  'applied',
#  'nanet',
#  'threetask',
#  'detected',
#  'infinitehorizon',
#  'upfront',
#  'largetime',
#  'central',
#  'decimation',
#  'potentially',
#  'tedious',
#  'aft',
#  'minterm',
#  'mathematically',
#  'universal',
#  'teleoperation',
#  'hins',
#  'dfe',
#  'offending',
#  'degreesoffreedom',
#  'awaiting',
#  'supporters',
#  'iqcs',
#  'airbnb',
#  'dynamicprogramming',
#  'formulated',
#  'erdal',
#  'multiclass',
#  'compressive',
#  'thedirect',
#  'metamodeling',
#  'xie',
#  'systematized',
#  'offcube',
#  'megabytes',
#  'corresponds',
#  'perceptrons',
#  'memetics',
#  'embodiedqa',
#  'emphasis',
#  'dexterous',
#  'anonymization',
#  'timetrader',
#  'epsilonloops',
#  'perceptron',
#  'every',
#  'disney',
#  'elsewhere',
#  'mutationselection',
#  'whoever',
#  'seams',
#  'katz',
#  'officer',
#  'predpatt',
#  'symmetrized',
#  'adiabatic',
#  'trucking',
#  'subtractions',
#  'mimo',
#  'genes',
#  'handler',
#  'hlsgenerated',
#  'containment',
#  'windowsx',
#  'canbus',
#  'pixelization',
#  'arrive',
#  'institutional',
#  'encryptions',
#  'etc',
#  'quasiperiodic',
#  'rank1',
#  'unions',
#  'fbm',
#  'sui',
#  'uncovered',
#  'implicitexplicit',
#  'oscillation',
#  'parameterizedgraph',
#  'conversation',
#  'handfoot',
#  'maximally',
#  'actuated',
#  'reflections',
#  'hitters',
#  'users',
#  'emergencyrelated',
#  'powerrestricted',
#  'unsure',
#  'wasted',
#  'kondacswatrous',
#  'action',
#  'awarding',
#  'unicriterion',
#  'adaptive',
#  'siamese',
#  'retrenchment',
#  'noncommutative',
#  '7360class',
#  'outlook',
#  'ntorus',
#  'posting',
#  'interleaving',
#  'tacit',
#  'multielement',
#  'independently',
#  'catheter',
#  'kimura',
#  'comprising',
#  'readeraware',
#  'githubcomdeepscalesqueezenet',
#  'bsmm',
#  'bottles',
#  'opinionspreferences',
#  'uncomputability',
#  'organising',
#  'vggnet',
#  'piranashvilitype',
#  'materialization',
#  'heartbeats',
#  'hst',
#  'surely',
#  'country',
#  'imagescope',
#  'multienergy',
#  'latedeciders',
#  'excluding',
#  'deeprank',
#  'correlationcoherency',
#  'di',
#  'signalcognitive',
#  'cliquefinding',
#  'jadmm',
#  'arbor',
#  'disassortative',
#  'neuromorphic',
#  'toffoli',
#  'bob',
#  'geared',
#  'cofounded',
#  'classification',
#  'mazurkiewicz',
#  'isizulu',
#  'languages',
#  'diffuser',
#  'hydrophone',
#  'rectifiedcorrelations',
#  'worldcat',
#  'functionfunction',
#  'infringes',
#  'money',
#  'navrenrl',
#  'microsystem',
#  'mischief',
#  'magnatagatune',
#  'oftheart',
#  'interblock',
#  'physicsbuedupankajmmlnotebookshtml',
#  'cement',
#  'win',
#  'hpd',
#  'parallelepipeds',
#  'founsure',
#  'crosspatient',
#  'dccs',
#  'thesis',
#  'kitchen',
#  'equivalence',
#  'ageing',
#  'consult',
#  'tps',
#  'leakresilient',
#  'droidscribe',
#  'strategic',
#  'weapon',
#  'cycling',
#  'plantwide',
#  'terrestrial',
#  'onestep',
#  'zerocrossings',
#  'times',
#  'storm',
#  'hinfinity',
#  'sight',
#  'solidworks',
#  'superficial',
#  'promotional',
#  'paige',
#  'verb',
#  'critic',
#  'cmcwpm',
#  'ablebodied',
#  'effect',
#  'zorder',
#  'ultrasonic',
#  'ters',
#  'paleoclimate',
#  'auc',
#  'isbsg',
#  'dyadic',
#  'powertemperature',
#  'minhash',
#  'reworked',
#  'ampk',
#  'dynamicgem',
#  'payment',
#  'intuitionisticconstructive',
#  'chunklevel',
#  'ridematching',
#  'breakers',
#  'stirmark',
#  'termweighted',
#  'cybercomponent',
#  'ontoseg',
#  'furui',
#  'provability',
#  'outstanding',
#  'wholebrain',
#  'divisibility',
#  'bundleadjustment',
#  'reflectivity',
#  'sfcs',
#  'multirelay',
#  'indicating',
#  'detailing',
#  'rateoptimal',
#  'ux',
#  'ordinations',
#  'workers',
#  'plausibility',
#  'helios',
#  'parametrizing',
#  'concerned',
#  'fabsearch',
#  'categorisation',
#  'buttons',
#  'beings',
#  'posteditor',
#  'properly',
#  'nlg',
#  'chess',
#  'appraisal',
#  'firstcome',
#  'expectationmaximum',
#  'homage',
#  'organizational',
#  'math',
#  'comprehend',
#  'multibond',
#  'eukaryotes',
#  'lesionlevel',
#  'fem',
#  'plot',
#  'defectors',
#  'warmup',
#  'sustain',
#  'plotkin',
#  'ljf',
#  'wavetables',
#  'startup',
#  '10machine',
#  'antdsr',
#  'occupantparticipant',
#  'millerrabin',
#  'manycores',
#  'hopes',
#  'timeindependent',
#  'moder',
#  'ahonen',
#  'visuoproprioceptive',
#  'timed',
#  'openvocabulary',
#  'mocassin',
#  'sorter',
#  'keyshots',
#  'obligations',
#  'mapreduce',
#  'genuineness',
#  'applicabilities',
#  'efws',
#  'csim',
#  'assupervised',
#  'mikolov',
#  'shannon',
#  'personnet',
#  'corpusbased',
#  'mace',
#  'favorable',
#  'pyramidal',
#  'forecasted',
#  'nonmotorized',
#  'mrlda',
#  'nakagamim',
#  'serves',
#  'permissions',
#  'augments',
#  'softmax',
#  'gzsl',
#  'coincidence',
#  'normalisations',
#  'fibonaccilike',
#  'mrfs',
#  'cylindric',
#  'confusion',
#  'stringing',
#  'rarer',
#  'verifications',
#  'modern',
#  'mains',
#  'mimiciii',
#  'costmetric',
#  'ccnn',
#  'entertainment',
#  'dfms',
#  'wakes',
#  'shadow',
#  'sparsespectrum',
#  'depression',
#  'datapoint',
#  'lockable',
#  'bx',
#  'remotecontrol',
#  'iparaphrasing',
#  'therefrom',
#  'teachings',
#  'prognostics',
#  'forcible',
#  'multiplication',
#  'onset',
#  'synopsis',
#  'federation',
#  'welldesigned',
#  'nielson',
#  'sinkhole',
#  'fluid',
#  'mutated',
#  'receiverdriven',
#  'skew',
#  'repovs',
#  'narrow',
#  'erased',
#  'eliminating',
#  'jquery',
#  'imdbwiki101',
#  'nonneutral',
#  'stubborn',
#  'themed',
#  'witnessing',
#  'reactiondiffusion',
#  'windows',
#  'sumrates',
#  'weaklysupervised',
#  'homomorphically',
#  'smallworldness',
#  'eit',
#  'mcrahns',
#  'pkummd',
#  'sequencelike',
#  'reclassification',
#  'youth',
#  '10',
#  '4point',
#  'ecsq',
#  'pedestrians',
#  'ufd',
#  'hirsch',
#  'vlsaf',
#  'wrapper',
#  'cardinal',
#  'nanoworld',
#  'meta',
#  'superrationality',
#  'classbased',
#  'genprog',
#  'demerit',
#  'adc',
#  'prosthetics',
#  'loose',
#  'debian',
#  'studentteacher',
#  'loadng',
#  'depletion',
#  'ran',
#  'scribble',
#  'anomalous',
#  'sick',
#  'amplifier',
#  'doubleedged',
#  'timedependent',
#  'simulation',
#  'stacked',
#  'sdss',
#  'quality',
#  'nongold',
#  'costperformance',
#  'bowman',
#  'equiangular',
#  'armv',
#  'pinpoint',
#  'million',
#  'popularly',
#  'scns',
#  'appearancebased',
#  'ccrb',
#  'fidus',
#  'falling',
#  'sabased',
#  'ade',
#  'accessing',
#  'sampergonzalez',
#  'superhuman',
#  'formulating',
#  'unproblematic',
#  'elongated',
#  'referrals',
#  'pretreatment',
#  'unstructured',
#  'distantlysupervised',
#  'nonkey',
#  'lis',
#  'manuscript',
#  'resourceallocation',
#  '1best',
#  'splunk',
#  'bpfo',
#  'mlc',
#  'neuronalbirth',
#  'seminar',
#  'nonlombard',
#  'kung',
#  'unneeded',
#  'readers',
#  'sideoutput',
#  'substructures',
#  'deontic',
#  'touted',
#  'kernelizedcov',
#  'nonoutput',
#  'misty',
#  'scraped',
#  '18vector',
#  'groupby',
#  'representativeness',
#  'ecmp',
#  'latentfactor',
#  'vertexes',
#  'computeronly',
#  'markovgibbs',
#  'powerefficient',
#  'strive',
#  'vials',
#  'slu',
#  'urgency',
#  'devicesswitches',
#  'grasps',
#  'qcqp',
#  'mented',
#  'fusions',
#  'neer',
#  'oversampling',
#  'reconciles',
#  'validated',
#  '2letter',
#  'terrible',
#  'brainwide',
#  'quorum',
#  'bugmitigation',
#  'cater',
#  'dcmac',
#  'curriculum',
#  'lengthnormalized',
#  'nsgaii',
#  'pnns',
#  'percentile',
#  'neuralnetworkbased',
#  'ecosystem',
#  'stopping',
#  'lipreading',
#  'closedworld',
#  'arppath',
#  'lineargaussian',
#  'antithetic',
#  'treat',
#  'coinduction',
#  'casts',
#  'vine',
#  'system',
#  'autophagy',
#  'ratemap',
#  'greatly',
#  'mayo',
#  'meantimetorepair',
#  'weibo',
#  'clarifying',
#  'journalers',
#  'moebius',
#  'fmifslssvmids',
#  'top10',
#  'wellcharacterized',
#  'registering',
#  'humanlevel',
#  'holevo',
#  'california',
#  'ccns',
#  'tautology',
#  'instabilities',
#  'pathogen',
#  'periodicity',
#  'terminologists',
#  'instancespecific',
#  'ssig',
#  'pseudonymity',
#  'smic',
#  'visavis',
#  'recon',
#  'stars',
#  'nips',
#  'commuting',
#  'paying',
#  'lowergranularity',
#  'sciences',
#  'lstmbased',
#  'ceilings',
#  'oversensing',
#  'sss',
#  'poly',
#  'losing',
#  'expertise',
#  'tourist',
#  'actionness',
#  'unlearned',
#  'routerlike',
#  'selectivity',
#  'groupequivariant',
#  'versa',
#  'aachen',
#  'vayanos',
#  'davidson',
#  'torrents',
#  'implication',
#  'cj',
#  'wellperforming',
#  'widespread',
#  'segmention',
#  'validations',
#  'overflows',
#  'ehrs',
#  'oma',
#  'geometrybased',
#  'drivingstepping',
#  ...}

# %%
len(words_pre)
# Out:
# 33989

# %% [markdown]
# pad: for padding
# unk: for word that didn't in our dicitonary

# %%
PAD_TOKEN = 0
UNK_TOKEN = 1
word_dict = {'<pad>':PAD_TOKEN,'<unk>':UNK_TOKEN}
for word in words_pre:
    word_dict[word]=len(word_dict)

# %%
import pickle
with open('other_data/dicitonary_words_pre.pkl','wb') as f:
    pickle.dump(word_dict, f)

# %%
len(word_dict)
# Out:
# 33991

# %% [markdown]
# ### 資料格式化 (Data formatting)
# 有了字典後，接下來我們要把資料整理成一筆一筆，把input的句子轉成數字，把答案轉成onehot的形式。
# 這裡，我們一樣使用`multiprocessing`來加入進行。
# After building dictionary, that's mapping our sentences into number array, and convert answers to onehot format.

# %%
from tqdm import tqdm_notebook as tqdm
def label_to_onehot(labels):
    """ Convert label to onehot .
        Args:
            labels (string): sentence's labels.
        Return:
            outputs (onehot list): sentence's onehot label.
    """
    label_dict = {'BACKGROUND':0, 'OBJECTIVES':1, 'METHODS':2, 'RESULTS':3, 'CONCLUSIONS':4, 'OTHERS':5}
    onehot = [0,0,0,0,0,0]
    for l in labels.split('/'):
        onehot[label_dict[l]] = 1
    return onehot
        
def sentence_to_indices(sentence, word_dict):
    """ Convert sentence to its word indices.
    Args:
        sentence (str): One string.
    Return:
        indices (list of int): List of word indices.
    """
    return [word_dict.get(word.lower(), UNK_TOKEN) for word in word_tokenize(sentence)]
    
def get_dataset(data_path, word_dict, n_workers=4):
    """ Load data and return dataset for training and validating.

    Args:
        data_path (str): Path to the data.
    """
    dataset = pd.read_csv(data_path, dtype=str)

    results = [None] * n_workers
    with Pool(processes=n_workers) as pool:
        for i in range(n_workers):
            batch_start = (len(dataset) // n_workers) * i
            if i == n_workers - 1:
                batch_end = len(dataset)
            else:
                batch_end = (len(dataset) // n_workers) * (i + 1)
            
            batch = dataset[batch_start: batch_end]
            results[i] = pool.apply_async(preprocess_samples, args=(batch,word_dict))
        
        # 有with基本上不用這個
        pool.close()
        pool.join()

    processed = []
    for result in results:
        processed += result.get()
    return processed

def preprocess_samples(dataset, word_dict):
    """ Worker function.

    Args:
        dataset (list of dict)
    Returns:
        list of processed dict.
    """
    processed = []
    for sample in tqdm(dataset.iterrows(), total=len(dataset)):
        processed.append(preprocess_sample(sample[1], word_dict))

    return processed

def preprocess_sample(data, word_dict):
    """
    Args:
        data (dict)
    Returns:
        dict
    """
    processed = {}
    processed['Abstract'] = [sentence_to_indices(sent, word_dict) for sent in data['Abstract'].split('$$$')]
    if 'Task 1' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Task 1'].split(' ')]
    if 'Label' in data:
        processed['Label'] = [label_to_onehot(label) for label in data['Label'].split(' ')]
    
    return processed

# %%
print('[INFO] Start processing trainset...')
train = get_dataset('train_test_split_data/trainset.csv', word_dict, n_workers=4)
print('[INFO] Start processing validset...')
valid = get_dataset('train_test_split_data/validset.csv', word_dict, n_workers=4)
print('[INFO] Start processing testset...')
test = get_dataset('train_test_split_data/testset.csv', word_dict, n_workers=4)
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing testset...

# %% [markdown]
# #### Preprosses K-fold data

# %%
train_folds=[]
valid_folds=[]

for i in range(fold):
  print('[INFO] Start processing trainset...')
  train_folds.append(get_dataset("K_fold_data/" + "train_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
  print('[INFO] Start processing validset...')
  valid_folds.append(get_dataset("K_fold_data/" + "valid_data_fold_" + str(i) + ".csv", word_dict, n_workers=4))
# Out:
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...
#
#
#
#
# [INFO] Start processing trainset...
#
#
#
#
# [INFO] Start processing validset...

# %%
type(train[0])
# Out:
# dict

# %% [markdown]
# ## 資料封裝 (Data packing)

# %% [markdown]
# 為了更方便的進行batch training，我們將會借助[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)。
# 而要將資料放入dataloader，我們需要繼承[torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)，撰寫適合這份dataset的class。
# `collate_fn`用於batch data的後處理，在`dataloder`將選出的data放進list後會呼叫collate_fn，而我們會在此把sentence padding到同樣的長度，才能夠放入torch tensor (tensor必須為矩陣)。

# %% [markdown]
# To easily training in batch, we'll use `dataloader`, which is a function built in Pytorch[torch.utils.data.DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader)
# To use datalaoder, we need to packing our data into class `dataset` [torch.utils.data.Dataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset)
# `collate_fn` is used for data processing.

# %%
from torch.utils.data import Dataset
import torch
class AbstractDataset(Dataset):
    def __init__(self, data, pad_idx, max_len = 500):
        self.data = data
        self.pad_idx = pad_idx
        self.max_len = max_len
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]
        
    def collate_fn(self, datas):
        # get max length in this batch
        max_sent = max([len(data['Abstract']) for data in datas])
        max_len = max([min(len(sentence), self.max_len) for data in datas for sentence in data['Abstract']])
        batch_abstract = []
        batch_label = []
        sent_len = []
        for data in datas:
            # padding abstract to make them in same length
            pad_abstract = []
            for sentence in data['Abstract']:
                if len(sentence) > max_len:
                    pad_abstract.append(sentence[:max_len])
                else:
                    pad_abstract.append(sentence+[self.pad_idx]*(max_len-len(sentence)))
            sent_len.append(len(pad_abstract))
            pad_abstract.extend([[self.pad_idx]*max_len]*(max_sent-len(pad_abstract)))
            batch_abstract.append(pad_abstract)
            # gather labels
            if 'Label' in data:
                pad_label = data['Label']
                pad_label.extend([[0]*6]*(max_sent-len(pad_label)))
                
                batch_label.append(pad_label)
        return torch.LongTensor(batch_abstract), torch.FloatTensor(batch_label), sent_len

# %%
# TODO: 改max_len
trainData = AbstractDataset(train, PAD_TOKEN, max_len=64)
validData = AbstractDataset(valid, PAD_TOKEN, max_len=64)
testData = AbstractDataset(test, PAD_TOKEN, max_len=64)

# %%
## 5 fold data

trainData_folds = []
validData_folds = []

for i in range(fold):
  trainData_folds.append(AbstractDataset(train_folds[i], PAD_TOKEN, max_len=64))
  validData_folds.append(AbstractDataset(valid_folds[i], PAD_TOKEN, max_len=64))

# %% [markdown]
# # Model

# %% [markdown]
# 資料處理完成後，接下來就是最重要的核心部分：`Model`。
# 此次範例中我們以簡單的一層RNN + 兩層Linear layer作為示範。
# 而為了解決每次的句子長度不一的問題(`linear layer必須是fixed input size`)，因此我們把所有字的hidden_state做平均，讓這一個vector代表這句話。

# %% [markdown]
# In this tutorial, we're going to implement a simple model, which contain one RNN layer and two fully connected layers (Linear layer). Of course you can make it "deep".
# To solve variant sentence length problem (`input size in linear layer must be fixed`), we can average all hidden_states, and become one vector. (Perfect!)

# %%
import torch.nn as nn
import torch.nn.functional as F

class simpleNet(nn.Module):
    def __init__(self, vocabulary_size):
        super(simpleNet, self).__init__()
        self.embedding_size = 200  # 改embedding
        self.hidden_dim = 512
        self.embedding = nn.Embedding(vocabulary_size, self.embedding_size)
        self.sent_rnn = nn.GRU(self.embedding_size,
                               self.hidden_dim,
                               num_layers=1,
                               bidirectional=True,
                               batch_first=True,
                               # dropout=0.3
                              )

        # 加上LSTM & dropout試試看 & batch norm
        self.batch_norm = nn.BatchNorm1d(self.hidden_dim, momentum=0.5)
        self.l1 = nn.Linear(self.hidden_dim * 2, self.hidden_dim)
        self.l2 = nn.Linear(self.hidden_dim, 6)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.embedding(x)
        batch_size, sent_len, word_dim, embed_dim = x.shape
        x = x.view(batch_size, sent_len * word_dim, embed_dim)
        x, __ = self.sent_rnn(x)
        x = x.view(batch_size, sent_len, word_dim, -1)
        x = torch.max(x, dim=2)[0]  # 選整句最大值
        # x = torch.mean(x, dim=2, keepdim=True).squeeze()  # 改成平均
        x = torch.relu(self.l1(x))
        # x = x.permute(0, 2, 1)
        # x = self.batch_norm(x)  # 加一個channel維度?
        # x = x.permute(0, 2, 1)
        # x = self.dropout(x)
        x = torch.sigmoid(self.l2(x))
        return x

# %%
from torch.utils.data import DataLoader

dataloader = DataLoader(dataset=trainData,
                            batch_size=64,
                            shuffle=True,
                            collate_fn=trainData.collate_fn,
                            num_workers=4)

for (x, y, sent_len) in dataloader:
   
   break

# %%
snet = simpleNet(len(word_dict))

# %%
x.shape
# Out:
# torch.Size([64, 12, 64])

# %%
x = snet.embedding(x)
x = torch.mean(x, dim=3, keepdim=True).squeeze()
x = snet.embedding_2(x)
# batch_size, sent_len, word_dim, embed_dim = x.shape
x.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-154-17bfae391c8c> in <module>()
#       1 x = snet.embedding(x)
#       2 x = torch.mean(x, dim=3, keepdim=True).squeeze()
# ----> 3 x = snet.embedding_2(x)
#       4 # batch_size, sent_len, word_dim, embed_dim = x.shape
#       5 x.shape
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     112         return F.embedding(
#     113             input, self.weight, self.padding_idx, self.max_norm,
# --> 114             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     115
#     116     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1482         # remove once script supports set_grad_enabled
#    1483         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1484     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1485
#    1486
#
# RuntimeError: Expected tensor for argument #1 'indices' to have scalar type Long; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
x = snet.embedding(x)
# torch.mean(x, dim=3, keepdim=True).squeeze().shape
b , s, w, e = x.shape
b , s, w, e
# Out:
# torch.Size([64, 13, 64])

# %%
x = x.view(b, s * w, e)
x, __ = snet.sent_rnn(x)
x = x.view(b, s, w, -1)
print(x.shape)
x = torch.max(x, dim=2)[0]  # TODO: 改成平均
print(x.shape)
x = torch.relu(snet.l1(x))
print(x.shape)
# Out:
# torch.Size([64, 15, 64, 1024])
# torch.Size([64, 15, 1024])
# torch.Size([64, 15, 512])

# %%
x = x.view(b, s * w, e)
x, __ = snet.sent_rnn(x)
x = x.view(b, s, w, -1)
print(x.shape)
# Out:
# torch.Size([64, 13, 64, 1024])

# %%
x.view(b, s*w, -1).shape
# Out:
# torch.Size([64, 832, 1024])

# %%
torch.mean(x.view(b, s, w, -1), dim=2, keepdim=True).squeeze().shape
# Out:
# torch.Size([64, 13, 1024])

# %%
x = torch.mean(x, dim=2)[0]  # TODO: 改成平均
print(x.shape)
x = torch.relu(snet.l1(x))
print(x.shape)
# Out:
# torch.Size([64, 16, 8])

# %%
x = x.permute(0, 2, 1)
x.shape
# Out:
# torch.Size([64, 512, 15])

# %%
x = snet.batch_norm(x)  # 加一個channel維度?
x = x.permute(0, 2, 1)
x.shape
# Out:
# torch.Size([64, 15, 512])

# %%
print(simpleNet(len(word_dict)))
# Out:
# simpleNet(
#   (embedding): Embedding(31184, 200)
#   (sent_rnn): GRU(200, 512, num_layers=2, batch_first=True, bidirectional=True)
#   (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.5, affine=True, track_running_stats=True)
#   (l1): Linear(in_features=1024, out_features=512, bias=True)
#   (l2): Linear(in_features=512, out_features=6, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# # Training

# %% [markdown]
# 指定使用的運算裝置
# Designate running device.

# %%
device='cuda' #'cuda'

# %% [markdown]
# 定義一個算分公式, 讓我們在training能快速了解model的效能
# Define score function, let us easily observe model performance while training.

# %%
class F1():
    def __init__(self):
        self.threshold = 0.5
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0
        self.name = 'F1'

    def reset(self):
        self.n_precision = 0
        self.n_recall = 0
        self.n_corrects = 0

    def update(self, predicts, groundTruth):
        predicts = predicts > self.threshold
        self.n_precision += torch.sum(predicts).data.item()
        self.n_recall += torch.sum(groundTruth).data.item()
        self.n_corrects += torch.sum(groundTruth.type(torch.uint8) * predicts).data.item()

    def get_score(self):
        recall = self.n_corrects / self.n_recall
        precision = self.n_corrects / (self.n_precision + 1e-20) #prevent divided by zero
        return 2 * (recall * precision) / (recall + precision + 1e-20)

    def print_score(self):
        score = self.get_score()
        return '{:.5f}'.format(score)

# %%
import os
def _run_epoch(data, epoch, training):
    model.train(training)
    if training:
        description = 'Train'
        # dataset = trainData
        dataset = data
        shuffle = True
    else:
        description = 'Valid'
        # dataset = validData
        dataset = data
        shuffle = False
    dataloader = DataLoader(dataset=dataset,
                            batch_size=64,
                            shuffle=shuffle,
                            collate_fn=dataset.collate_fn,
                            num_workers=4)

    trange = tqdm(enumerate(dataloader), total=len(dataloader), desc=description)
    loss = 0
    f1_score = F1()
    for i, (x, y, sent_len) in trange:
        o_labels, batch_loss = _run_iter(x,y)
        if training:
            opt.zero_grad()
            batch_loss.backward()
            opt.step()

        loss += batch_loss.item()
        f1_score.update(o_labels.cpu(), y)

        trange.set_postfix(
            loss=loss / (i + 1), f1=f1_score.print_score())
    if training:
        history['train'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})
    else:
        history['valid'].append({'f1':f1_score.get_score(), 'loss':loss/ len(trange)})

def _run_iter(x, y):
    abstract = x.to(device)
    labels = y.to(device)
    o_labels = model(abstract)
    l_loss = criteria(o_labels, labels)
    return o_labels, l_loss

def save(epoch, name, cv=False):
    if not os.path.exists('model'):
        os.makedirs('model')
    if not os.path.exists('model/cv'):
        os.makedirs('model/cv')
    if cv:
      torch.save(model.state_dict(), 'model/cv/model_cv_' + name + '.pkl.'+str(epoch))
      with open('model/cv/history_cv_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)
    else:
      torch.save(model.state_dict(), 'model/model_' + name + '.pkl.'+str(epoch))
      with open('model/history_' + name + '.json', 'w') as f:
          json.dump(history, f, indent=4)

# %% [markdown]
# ## Run Model

# %%
from torch.utils.data import DataLoader
from tqdm import trange
import json

mode = "cv" #cv, train

vaild_f1 = 0
name = "gru_layer1_emb200_wordpre_10Kfold"

if mode == "cv":
  overall_F1 = []
  for i in range(fold):
    model = simpleNet(len(word_dict))
    opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
    criteria = torch.nn.BCELoss() 
    model.to(device)
    max_epoch = 5
    history = {'train' : [], 'valid' : []}

    for epoch in range(max_epoch):
        print('CV_' + str(i) + ',', 'Epoch: {}'.format(epoch))
        _run_epoch(trainData_folds[i], epoch, True)
        _run_epoch(validData_folds[i], epoch, False)
        
        save(epoch, name + "_" + str(i), cv=True)

        print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

        if epoch > 1:
          overall_F1.append(np.mean([f1['f1'] for f1 in history['valid'][-2:]]))

  print("Final average validation F1 score:", np.mean(overall_F1))
    
else:
  model = simpleNet(len(word_dict))
  opt = torch.optim.Adam(model.parameters(), betas=(0.9, 0.999))
  criteria = torch.nn.BCELoss()
  model.to(device)
  max_epoch = 5
  history = {'train' : [], 'valid' : []}

  for epoch in range(max_epoch):
      print('Epoch: {}'.format(epoch))
      _run_epoch(trainData, epoch, True)
      _run_epoch(validData, epoch, False)
      save(epoch, name, cv=False)

      print("average last 2 validation F1 score:", np.mean([f1['f1'] for f1 in history['valid'][-2:]]))
# Out:
# CV_0, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5851546827156583
# CV_0, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6206819165212278
# CV_0, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6645376213654347
# CV_0, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6818823327427225
# CV_0, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6802065680940845
# CV_1, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5647731018569387
# CV_1, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6012485108863197
# CV_1, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.652060299534645
# CV_1, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6663285447362501
# CV_1, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6709561647258195
# CV_2, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6119290703922622
# CV_2, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6348423406824154
# CV_2, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6649365924869053
# CV_2, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6755492975050359
# CV_2, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6756353366718701
# CV_3, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.614679854242582
# CV_3, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6301705583030999
# CV_3, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6480195741365662
# CV_3, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6625996485032454
# CV_3, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6665556641755185
# CV_4, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5813041683862981
# CV_4, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6007165049345156
# CV_4, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6311690367462043
# CV_4, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.65687615909101
# CV_4, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6651252678025019
# CV_5, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6268119564130761
# CV_5, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6363248073533099
# CV_5, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6600131876090785
# CV_5, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6754357046161528
# CV_5, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6740835924651982
# CV_6, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5848246991104135
# CV_6, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6095290880232114
# CV_6, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6462382189177112
# CV_6, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6594892147320315
# CV_6, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6653662649905236
# CV_7, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6114970301016813
# CV_7, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.626402911778857
# CV_7, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6413739997056839
# CV_7, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6574532862499266
# CV_7, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6724672566295948
# CV_8, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.599443241571296
# CV_8, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6225386368654364
# CV_8, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6505337698389864
# CV_8, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6603451525507389
# CV_8, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6709969788519637
# CV_9, Epoch: 0
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.5921879830980109
# CV_9, Epoch: 1
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6101688465832701
# CV_9, Epoch: 2
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.641025354117581
# CV_9, Epoch: 3
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.6549433341912873
# CV_9, Epoch: 4
# HBox(children=(IntProgress(value=0, description='Train', max=99, style=ProgressStyle(description_width='initia…
# HBox(children=(IntProgress(value=0, description='Valid', max=11, style=ProgressStyle(description_width='initia…
# average last 2 validation F1 score: 0.659070504030302
# Final average validation F1 score: 0.6617091309271526

# %%
model = simpleNet(len(word_dict))
model.to(device)
model.load_state_dict(torch.load('model/cv/model_cv_gru_layer1_emb200_wordpre_10Kfold_0.pkl.2'))
# model.load_state_dict(torch.load('model/cv/model_cv_gru_layer1_no_stopw_with_cat_4.pkl.2'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Predict

# %%
from torch.utils.data import DataLoader
model.train(False)
dataloader = DataLoader(dataset=testData,
                            batch_size=64,
                            shuffle=False,  # for sent len不要亂
                            collate_fn=testData.collate_fn,
                            num_workers=4)
trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')
prediction = []
for i, (x, y, sent_len) in trange:
    o_labels = model(x.to(device))
    o_labels = o_labels > 0.4
    for idx, o_label in enumerate(o_labels):
        prediction.append(o_label[:sent_len[idx]].to('cpu'))
prediction = torch.cat(prediction).detach().numpy().astype(int)
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…

# %%
label_dict = {'BACKGROUND':0, 'OBJECTIVES':1, 'METHODS':2, 'RESULTS':3, 'CONCLUSIONS':4, 'OTHERS':5}

# %%
reversed_word_dict = {value: key for key, value in word_dict.items()}
[reversed_word_dict[idx] for idx in x[idx][2].numpy()]
# Out:
# ['specific',
#  'algorithms',
#  'for',
#  'the',
#  'three',
#  'examples',
#  'are',
#  'derived',
#  'and',
#  'numerical',
#  'demonstrations',
#  'are',
#  'presented',
#  '<unk>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>',
#  '<pad>']

# %%
o_label
# Out:
# tensor([[ True, False, False, False, False, False],
#         [False,  True,  True, False, False, False],
#         [False, False, False,  True, False, False],
#         [False, False, False,  True, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False],
#         [False, False, False, False, False, False]], device='cuda:0')

# %%
prediction[0]
# Out:
# array([1, 0, 0, 0, 0, 0])

# %%
import numpy as np
def SubmitGenerator(prediction, sampleFile, public=True, filename='prediction.csv'):
    sample = pd.read_csv(sampleFile)
    submit = {}
    submit['order_id'] = list(sample.order_id.values)
    redundant = len(sample) - prediction.shape[0]
    if public:
        submit['BACKGROUND'] = list(prediction[:,0]) + [0]*redundant
        submit['OBJECTIVES'] = list(prediction[:,1]) + [0]*redundant
        submit['METHODS'] = list(prediction[:,2]) + [0]*redundant
        submit['RESULTS'] = list(prediction[:,3]) + [0]*redundant
        submit['CONCLUSIONS'] = list(prediction[:,4]) + [0]*redundant
        submit['OTHERS'] = list(prediction[:,5]) + [0]*redundant
    else:
        submit['BACKGROUND'] = [0]*redundant + list(prediction[:,0])
        submit['OBJECTIVES'] = [0]*redundant + list(prediction[:,1])
        submit['METHODS'] = [0]*redundant + list(prediction[:,2])
        submit['RESULTS'] = [0]*redundant + list(prediction[:,3])
        submit['CONCLUSIONS'] = [0]*redundant + list(prediction[:,4])
        submit['OTHERS'] = [0]*redundant + list(prediction[:,5])
    df = pd.DataFrame.from_dict(submit) 
    df.to_csv(filename,index=False)

# %%
os.getcwd()
# Out:
# '/content/Drive/My Drive/Colab Notebooks/2019_AI_CUP_LABELING/labeling_cowork_folder'

# %%
SubmitGenerator(prediction,
                'raw_data/task1_sample_submission.csv', 
                True,
                'submission/submission_6_emb200_word_pre_gru_2_layers.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-58769f23b660> in <module>()
# ----> 1 SubmitGenerator(prediction,
#       2                 'raw_data/task1_sample_submission.csv',
#       3                 True,
#       4                 'submission/submission_6_emb200_word_pre_gru_2_layers.csv')
#
# NameError: name 'SubmitGenerator' is not defined

# %% [markdown]
# ## 把cv模型load出來predict平均

# %%
model.load_state_dict(torch.load('model/cv/model_cv_gru_layer1_emb200_wordpre_for_cv_avf_0.pkl.3'))
# Out:
# <All keys matched successfully>

# %%
fold
# Out:
# 10

# %%
from torch.utils.data import DataLoader

prediction_sum = np.zeros((131166, 6))
n_digits = 3
model_nums = 0

for cv in range(fold):
  for ep in range(max_epoch):
    if (ep == 2) or (ep == 3): # 只取epoch 2 & 3 的模型 (started from 0)
      dataloader = DataLoader(dataset=testData,
                            batch_size=64,
                            shuffle=False,  # for sent len不要亂
                            collate_fn=testData.collate_fn,
                            num_workers=4)
      trange = tqdm(enumerate(dataloader), total=len(dataloader), desc='Predict')

      model.load_state_dict(torch.load('model/cv/model_cv_gru_layer1_emb200_wordpre_10Kfold_' + str(cv) + '.pkl.' + str(ep) + ''))
      model.train(False)
      prediction = []
      for i, (x, y, sent_len) in trange:
        with torch.no_grad(): # 避免記憶體爆掉，先將grad都設為false
          o_labels = model(x.to(device))  
          o_labels = (o_labels * 10 ** n_digits).round() / (10 ** n_digits)
          # o_labels = o_labels.to('cpu')
          # o_labels = o_labels > 0.4
          for idx, o_label in enumerate(o_labels):
              prediction.append(o_label[:sent_len[idx]].to('cpu'))
      prediction = torch.cat(prediction).detach().numpy() # .astype(int)
      
      prediction_sum += prediction
      model_nums += 1

final_prediction = prediction_sum / model_nums
# Out:
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…
# HBox(children=(IntProgress(value=0, description='Predict', max=313, style=ProgressStyle(description_width='ini…

# %%
SubmitGenerator(final_prediction,
                'raw_data/task1_sample_submission.csv', 
                True,
                'submission/submission_9_cv_avg_origin_prob.csv')

# %% [markdown]
# # Plot Learning Curve

# %%
import matplotlib.pyplot as plt
import json
# %matplotlib inline

with open('model/history_train.json', 'r') as f:
    history = json.loads(f.read())
    
train_loss = [l['loss'] for l in history['train']]
valid_loss = [l['loss'] for l in history['valid']]
train_f1 = [l['f1'] for l in history['train']]
valid_f1 = [l['f1'] for l in history['valid']]

plt.figure(figsize=(7,5))
plt.title('Loss')
plt.plot(train_loss, label='train')
plt.plot(valid_loss, label='valid')
plt.legend()
plt.show()

plt.figure(figsize=(7,5))
plt.title('F1 Score')
plt.plot(train_f1, label='train')
plt.plot(valid_f1, label='valid')
plt.legend()
plt.show()

print('Best F1 score ', max([[l['f1'], idx] for idx, l in enumerate(history['valid'])]))
# Out:
# Best F1 score  [0.6734478456961903, 4]
